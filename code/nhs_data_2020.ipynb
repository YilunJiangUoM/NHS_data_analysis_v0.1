# %% [markdown]
# # Import packages and define folder path

# %%
import csv
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.ticker import FuncFormatter
import seaborn as sns

# modify folder path
folder_path = 'Your folder path'

# %% [markdown]
# # Import CSV file
#
# # Month/Year: 01/2020
#
# Exclusion:
#
#             1. Home Visit & Unknown
#             2. More than 28 Days & Unknown / Data Issue

# %%
csv_name = 'CCG_CSV_Jan_20.csv'
file_path = folder_path + csv_name
dataframe = pd.read_csv(file_path)
dataframe.drop('CCG_CODE', axis=1, inplace=True)
dataframe.drop('CCG_ONS_CODE', axis=1, inplace=True)
dataframe.drop('STP_ONS_CODE', axis=1, inplace=True)
dataframe.drop('HCP_TYPE', axis=1, inplace=True)
#dataframe.drop('REGION_ONS_CODE', axis=1, inplace=True)

# %% [markdown]
# ## Data filtering & Analysis

# %%
# dna: did not attend
# f2f: face-to-face
# remote: Video Conference/Online & Telephone

remote_attended_tmp = dataframe[(dataframe['APPT_STATUS'] == 'Attended') 
                                & (dataframe['APPT_MODE'] != 'Home Visit') 
                                & (dataframe['APPT_MODE'] != 'Face-to-Face') 
                                & (dataframe['APPT_MODE'] != 'Unknown') 
                                & (dataframe['TIME_BETWEEN_BOOK_AND_APPT'] !='More than 28 Days')
                                & (dataframe['TIME_BETWEEN_BOOK_AND_APPT'] !='Unknown / Data Issue')
                                ]

remote_dna_tmp = dataframe[(dataframe['APPT_STATUS'] == 'DNA') 
                                & (dataframe['APPT_MODE'] != 'Home Visit') 
                                & (dataframe['APPT_MODE'] != 'Face-to-Face') 
                                & (dataframe['APPT_MODE'] != 'Unknown') 
                                & (dataframe['TIME_BETWEEN_BOOK_AND_APPT'] !='More than 28 Days')
                                & (dataframe['TIME_BETWEEN_BOOK_AND_APPT'] !='Unknown / Data Issue')
                                ]['COUNT_OF_APPOINTMENTS']

f2f_attended_tmp = dataframe[(dataframe['APPT_STATUS'] == 'Attended') 
                            & (dataframe['APPT_MODE'] == 'Face-to-Face')
                            & (dataframe['TIME_BETWEEN_BOOK_AND_APPT'] !='More than 28 Days')
                            & (dataframe['TIME_BETWEEN_BOOK_AND_APPT'] !='Unknown / Data Issue')                    
                            ]['COUNT_OF_APPOINTMENTS']

f2f_dna_tmp = dataframe[(dataframe['APPT_STATUS'] == 'DNA') 
                        & (dataframe['APPT_MODE'] == 'Face-to-Face') 
                        & (dataframe['TIME_BETWEEN_BOOK_AND_APPT'] !='More than 28 Days')
                        & (dataframe['TIME_BETWEEN_BOOK_AND_APPT'] !='Unknown / Data Issue')
                        ]['COUNT_OF_APPOINTMENTS']


# drop na

remote_attended_tmp = remote_attended_tmp.dropna()
remote_dna_tmp = remote_dna_tmp.dropna()
f2f_attended_tmp = f2f_attended_tmp.dropna()
f2f_dna_tmp = f2f_attended_tmp.dropna()

#count, mean, max, min, 5th, 10th, 25th, 50th, 75th, 90th, 95th
print('-------------------------------------------------')
print('Data description of attended remote consultation in 2020/01:')
print(remote_attended_tmp[['CCG_NAME', 'Appointment_Date', 'COUNT_OF_APPOINTMENTS']]
      .describe(percentiles=[.05, .10, .25, .50, .75, .90, .95]))
print('-------------------------------------------------')
print('Minimum:')
print(remote_attended_tmp[['CCG_NAME', 'Appointment_Date', 'COUNT_OF_APPOINTMENTS']].min())
print('-------------------------------------------------')
print('Maximum:')
print(remote_attended_tmp[['CCG_NAME', 'Appointment_Date', 'COUNT_OF_APPOINTMENTS']].max())
print('-------------------------------------------------')
# Out:
# -------------------------------------------------
# Data description of attended remote consultation in 2020/01:
#        COUNT_OF_APPOINTMENTS
# count           42363.000000
# mean               85.192645
# std               252.613350
# min                 1.000000
# 5%                  1.000000
# 10%                 1.000000
# 25%                 4.000000
# 50%                14.000000
# 75%                50.000000
# 90%               181.000000
# 95%               398.000000
# max              3808.000000
# -------------------------------------------------
# Minimum:
# CCG_NAME                 NHS Barnsley CCG
# Appointment_Date                01JAN2020
# COUNT_OF_APPOINTMENTS                   1
# dtype: object
# -------------------------------------------------
# Maximum:
# CCG_NAME                 NHS Wirral CCG
# Appointment_Date              31JAN2020
# COUNT_OF_APPOINTMENTS              3808
# dtype: object
# -------------------------------------------------

# %% [markdown]
# # Month/Year: 02/2020
#
# Exclusion:
#
#             1. Home Visit & Unknown
#             2. More than 28 Days & Unknown / Data Issue

# %%
csv_name = 'CCG_CSV_Feb_20.csv'
file_path = folder_path + csv_name
dataframe = pd.read_csv(file_path)
dataframe.drop('CCG_CODE', axis=1, inplace=True)
dataframe.drop('CCG_ONS_CODE', axis=1, inplace=True)
dataframe.drop('STP_ONS_CODE', axis=1, inplace=True)
dataframe.drop('HCP_TYPE', axis=1, inplace=True)
dataframe.drop('REGION_ONS_CODE', axis=1, inplace=True)

# %% [markdown]
# ## Data filtering & Analysis

# %%
# dna: did not attend
# f2f: face-to-face
# remote: Video Conference/Online & Telephone

remote_attended_tmp = dataframe[(dataframe['APPT_STATUS'] == 'Attended') 
                                & (dataframe['APPT_MODE'] != 'Home Visit') 
                                & (dataframe['APPT_MODE'] != 'Face-to-Face') 
                                & (dataframe['APPT_MODE'] != 'Unknown') 
                                & (dataframe['TIME_BETWEEN_BOOK_AND_APPT'] !='More than 28 Days')
                                & (dataframe['TIME_BETWEEN_BOOK_AND_APPT'] !='Unknown / Data Issue')
                                ]

remote_dna_tmp = dataframe[(dataframe['APPT_STATUS'] == 'DNA') 
                                & (dataframe['APPT_MODE'] != 'Home Visit') 
                                & (dataframe['APPT_MODE'] != 'Face-to-Face') 
                                & (dataframe['APPT_MODE'] != 'Unknown') 
                                & (dataframe['TIME_BETWEEN_BOOK_AND_APPT'] !='More than 28 Days')
                                & (dataframe['TIME_BETWEEN_BOOK_AND_APPT'] !='Unknown / Data Issue')
                                ]['COUNT_OF_APPOINTMENTS']

f2f_attended_tmp = dataframe[(dataframe['APPT_STATUS'] == 'Attended') 
                            & (dataframe['APPT_MODE'] == 'Face-to-Face')
                            & (dataframe['TIME_BETWEEN_BOOK_AND_APPT'] !='More than 28 Days')
                            & (dataframe['TIME_BETWEEN_BOOK_AND_APPT'] !='Unknown / Data Issue')                    
                            ]['COUNT_OF_APPOINTMENTS']

f2f_dna_tmp = dataframe[(dataframe['APPT_STATUS'] == 'DNA') 
                        & (dataframe['APPT_MODE'] == 'Face-to-Face') 
                        & (dataframe['TIME_BETWEEN_BOOK_AND_APPT'] !='More than 28 Days')
                        & (dataframe['TIME_BETWEEN_BOOK_AND_APPT'] !='Unknown / Data Issue')
                        ]['COUNT_OF_APPOINTMENTS']

# drop na

remote_attended_tmp = remote_attended_tmp.dropna()
remote_dna_tmp = remote_dna_tmp.dropna()
f2f_attended_tmp = f2f_attended_tmp.dropna()
f2f_dna_tmp = f2f_attended_tmp.dropna()

#count, min, max, 5th, 10th, 25th, 50th, 75th, 90th, 95th
print('-------------------------------------------------')
print('Data description of attended remote consultation in 2020/02:')
print(remote_attended_tmp[['CCG_NAME', 'Appointment_Date', 'COUNT_OF_APPOINTMENTS']]
      .describe(percentiles=[.05, .10, .25, .50, .75, .90, .95]))
print('-------------------------------------------------')
print('Minimum:')
print(remote_attended_tmp[['CCG_NAME', 'Appointment_Date', 'COUNT_OF_APPOINTMENTS']].min())
print('-------------------------------------------------')
print('Maximum:')
print(remote_attended_tmp[['CCG_NAME', 'Appointment_Date', 'COUNT_OF_APPOINTMENTS']].max())
print('-------------------------------------------------')
# Out:
# -------------------------------------------------
# Data description of attended remote consultation in 2020/02:
#        COUNT_OF_APPOINTMENTS
# count           39597.000000
# mean               81.744072
# std               243.854799
# min                 1.000000
# 5%                  1.000000
# 10%                 1.000000
# 25%                 4.000000
# 50%                14.000000
# 75%                48.000000
# 90%               175.000000
# 95%               366.000000
# max              3589.000000
# -------------------------------------------------
# Minimum:
# CCG_NAME                 NHS Barnsley CCG
# Appointment_Date                01FEB2020
# COUNT_OF_APPOINTMENTS                   1
# dtype: object
# -------------------------------------------------
# Maximum:
# CCG_NAME                 NHS Wirral CCG
# Appointment_Date              29FEB2020
# COUNT_OF_APPOINTMENTS              3589
# dtype: object
# -------------------------------------------------

# %% [markdown]
# # Month/Year: 03/2020
#
# Exclusion:
#
#             1. Home Visit & Unknown
#             2. More than 28 Days & Unknown / Data Issue

# %%
csv_name = 'CCG_CSV_Mar_20.csv'
file_path = folder_path + csv_name
dataframe = pd.read_csv(file_path)
dataframe.drop('CCG_CODE', axis=1, inplace=True)
dataframe.drop('CCG_ONS_CODE', axis=1, inplace=True)
dataframe.drop('STP_ONS_CODE', axis=1, inplace=True)
dataframe.drop('HCP_TYPE', axis=1, inplace=True)
dataframe.drop('REGION_ONS_CODE', axis=1, inplace=True)

# %% [markdown]
# ## Data filtering & Analysis

# %%
# dna: did not attend
# f2f: face-to-face
# remote: Video Conference/Online & Telephone

remote_attended_tmp = dataframe[(dataframe['APPT_STATUS'] == 'Attended') 
                                & (dataframe['APPT_MODE'] != 'Home Visit') 
                                & (dataframe['APPT_MODE'] != 'Face-to-Face') 
                                & (dataframe['APPT_MODE'] != 'Unknown') 
                                & (dataframe['TIME_BETWEEN_BOOK_AND_APPT'] !='More than 28 Days')
                                & (dataframe['TIME_BETWEEN_BOOK_AND_APPT'] !='Unknown / Data Issue')
                                ]

remote_dna_tmp = dataframe[(dataframe['APPT_STATUS'] == 'DNA') 
                                & (dataframe['APPT_MODE'] != 'Home Visit') 
                                & (dataframe['APPT_MODE'] != 'Face-to-Face') 
                                & (dataframe['APPT_MODE'] != 'Unknown') 
                                & (dataframe['TIME_BETWEEN_BOOK_AND_APPT'] !='More than 28 Days')
                                & (dataframe['TIME_BETWEEN_BOOK_AND_APPT'] !='Unknown / Data Issue')
                                ]['COUNT_OF_APPOINTMENTS']

f2f_attended_tmp = dataframe[(dataframe['APPT_STATUS'] == 'Attended') 
                            & (dataframe['APPT_MODE'] == 'Face-to-Face')
                            & (dataframe['TIME_BETWEEN_BOOK_AND_APPT'] !='More than 28 Days')
                            & (dataframe['TIME_BETWEEN_BOOK_AND_APPT'] !='Unknown / Data Issue')                    
                            ]['COUNT_OF_APPOINTMENTS']

f2f_dna_tmp = dataframe[(dataframe['APPT_STATUS'] == 'DNA') 
                        & (dataframe['APPT_MODE'] == 'Face-to-Face') 
                        & (dataframe['TIME_BETWEEN_BOOK_AND_APPT'] !='More than 28 Days')
                        & (dataframe['TIME_BETWEEN_BOOK_AND_APPT'] !='Unknown / Data Issue')
                        ]['COUNT_OF_APPOINTMENTS']

# drop na

remote_attended_tmp = remote_attended_tmp.dropna()
remote_dna_tmp = remote_dna_tmp.dropna()
f2f_attended_tmp = f2f_attended_tmp.dropna()
f2f_dna_tmp = f2f_attended_tmp.dropna()

#count, min, max, 5th, 10th, 25th, 50th, 75th, 90th, 95th
print('-------------------------------------------------')
print('Data description of attended remote consultation in 2020/03:')
print(remote_attended_tmp[['CCG_NAME', 'Appointment_Date', 'COUNT_OF_APPOINTMENTS']]
      .describe(percentiles=[.05, .10, .25, .50, .75, .90, .95]))
print('-------------------------------------------------')
print('Minimum:')
print(remote_attended_tmp[['CCG_NAME', 'Appointment_Date', 'COUNT_OF_APPOINTMENTS']].min())
print('-------------------------------------------------')
print('Maximum:')
print(remote_attended_tmp[['CCG_NAME', 'Appointment_Date', 'COUNT_OF_APPOINTMENTS']].max())
print('-------------------------------------------------')
# Out:
# -------------------------------------------------
# Data description of attended remote consultation in 2020/03:
#        COUNT_OF_APPOINTMENTS
# count           43259.000000
# mean              143.173166
# std               454.530822
# min                 1.000000
# 5%                  1.000000
# 10%                 2.000000
# 25%                 5.000000
# 50%                21.000000
# 75%                87.000000
# 90%               304.000000
# 95%               657.000000
# max             10188.000000
# -------------------------------------------------
# Minimum:
# CCG_NAME                 NHS Barnsley CCG
# Appointment_Date                01MAR2020
# COUNT_OF_APPOINTMENTS                   1
# dtype: object
# -------------------------------------------------
# Maximum:
# CCG_NAME                 NHS Wirral CCG
# Appointment_Date              31MAR2020
# COUNT_OF_APPOINTMENTS             10188
# dtype: object
# -------------------------------------------------

# %% [markdown]
# # Month/Year: 04/2020
#
# Exclusion:
#
#             1. Home Visit & Unknown
#             2. More than 28 Days & Unknown / Data Issue

# %%
csv_name = 'CCG_CSV_Apr_20.csv'
file_path = folder_path + csv_name
dataframe = pd.read_csv(file_path)
dataframe.drop('CCG_CODE', axis=1, inplace=True)
dataframe.drop('CCG_ONS_CODE', axis=1, inplace=True)
dataframe.drop('STP_ONS_CODE', axis=1, inplace=True)
dataframe.drop('HCP_TYPE', axis=1, inplace=True)
dataframe.drop('REGION_ONS_CODE', axis=1, inplace=True)

# %% [markdown]
# ## Data filtering & Analysis

# %%
# dna: did not attend
# f2f: face-to-face
# remote: Video Conference/Online & Telephone

remote_attended_tmp = dataframe[(dataframe['APPT_STATUS'] == 'Attended') 
                                & (dataframe['APPT_MODE'] != 'Home Visit') 
                                & (dataframe['APPT_MODE'] != 'Face-to-Face') 
                                & (dataframe['APPT_MODE'] != 'Unknown') 
                                & (dataframe['TIME_BETWEEN_BOOK_AND_APPT'] !='More than 28 Days')
                                & (dataframe['TIME_BETWEEN_BOOK_AND_APPT'] !='Unknown / Data Issue')
                                ]

remote_dna_tmp = dataframe[(dataframe['APPT_STATUS'] == 'DNA') 
                                & (dataframe['APPT_MODE'] != 'Home Visit') 
                                & (dataframe['APPT_MODE'] != 'Face-to-Face') 
                                & (dataframe['APPT_MODE'] != 'Unknown') 
                                & (dataframe['TIME_BETWEEN_BOOK_AND_APPT'] !='More than 28 Days')
                                & (dataframe['TIME_BETWEEN_BOOK_AND_APPT'] !='Unknown / Data Issue')
                                ]['COUNT_OF_APPOINTMENTS']

f2f_attended_tmp = dataframe[(dataframe['APPT_STATUS'] == 'Attended') 
                            & (dataframe['APPT_MODE'] == 'Face-to-Face')
                            & (dataframe['TIME_BETWEEN_BOOK_AND_APPT'] !='More than 28 Days')
                            & (dataframe['TIME_BETWEEN_BOOK_AND_APPT'] !='Unknown / Data Issue')                    
                            ]['COUNT_OF_APPOINTMENTS']

f2f_dna_tmp = dataframe[(dataframe['APPT_STATUS'] == 'DNA') 
                        & (dataframe['APPT_MODE'] == 'Face-to-Face') 
                        & (dataframe['TIME_BETWEEN_BOOK_AND_APPT'] !='More than 28 Days')
                        & (dataframe['TIME_BETWEEN_BOOK_AND_APPT'] !='Unknown / Data Issue')
                        ]['COUNT_OF_APPOINTMENTS']

# drop na

remote_attended_tmp = remote_attended_tmp.dropna()
remote_dna_tmp = remote_dna_tmp.dropna()
f2f_attended_tmp = f2f_attended_tmp.dropna()
f2f_dna_tmp = f2f_attended_tmp.dropna()

#count, min, max, 5th, 10th, 25th, 50th, 75th, 90th, 95th
print('-------------------------------------------------')
print('Data description of attended remote consultation in 2020/04:')
print(remote_attended_tmp[['CCG_NAME', 'Appointment_Date', 'COUNT_OF_APPOINTMENTS']]
      .describe(percentiles=[.05, .10, .25, .50, .75, .90, .95]))
print('-------------------------------------------------')
print('Minimum:')
print(remote_attended_tmp[['CCG_NAME', 'Appointment_Date', 'COUNT_OF_APPOINTMENTS']].min())
print('-------------------------------------------------')
print('Maximum:')
print(remote_attended_tmp[['CCG_NAME', 'Appointment_Date', 'COUNT_OF_APPOINTMENTS']].max())
print('-------------------------------------------------')
# Out:
# -------------------------------------------------
# Data description of attended remote consultation in 2020/04:
#        COUNT_OF_APPOINTMENTS
# count           36687.000000
# mean              195.487530
# std               620.346254
# min                 1.000000
# 5%                  1.000000
# 10%                 2.000000
# 25%                 5.000000
# 50%                21.000000
# 75%               102.000000
# 90%               447.000000
# 95%               969.400000
# max             11200.000000
# -------------------------------------------------
# Minimum:
# CCG_NAME                 NHS Barnsley CCG
# Appointment_Date                01APR2020
# COUNT_OF_APPOINTMENTS                   1
# dtype: object
# -------------------------------------------------
# Maximum:
# CCG_NAME                 NHS Wirral CCG
# Appointment_Date              30APR2020
# COUNT_OF_APPOINTMENTS             11200
# dtype: object
# -------------------------------------------------

# %% [markdown]
# # Month/Year: 05/2020
#
# Exclusion:
#
#             1. Home Visit & Unknown
#             2. More than 28 Days & Unknown / Data Issue

# %%
csv_name = 'CCG_CSV_May_20.csv'
file_path = folder_path + csv_name
dataframe = pd.read_csv(file_path)
dataframe.drop('CCG_CODE', axis=1, inplace=True)
dataframe.drop('CCG_ONS_CODE', axis=1, inplace=True)
dataframe.drop('STP_ONS_CODE', axis=1, inplace=True)
dataframe.drop('HCP_TYPE', axis=1, inplace=True)
dataframe.drop('REGION_ONS_CODE', axis=1, inplace=True)

# %% [markdown]
# ## Data filtering & Analysis

# %%
# dna: did not attend
# f2f: face-to-face
# remote: Video Conference/Online & Telephone

remote_attended_tmp = dataframe[(dataframe['APPT_STATUS'] == 'Attended') 
                                & (dataframe['APPT_MODE'] != 'Home Visit') 
                                & (dataframe['APPT_MODE'] != 'Face-to-Face') 
                                & (dataframe['APPT_MODE'] != 'Unknown') 
                                & (dataframe['TIME_BETWEEN_BOOK_AND_APPT'] !='More than 28 Days')
                                & (dataframe['TIME_BETWEEN_BOOK_AND_APPT'] !='Unknown / Data Issue')
                                ]

remote_dna_tmp = dataframe[(dataframe['APPT_STATUS'] == 'DNA') 
                                & (dataframe['APPT_MODE'] != 'Home Visit') 
                                & (dataframe['APPT_MODE'] != 'Face-to-Face') 
                                & (dataframe['APPT_MODE'] != 'Unknown') 
                                & (dataframe['TIME_BETWEEN_BOOK_AND_APPT'] !='More than 28 Days')
                                & (dataframe['TIME_BETWEEN_BOOK_AND_APPT'] !='Unknown / Data Issue')
                                ]['COUNT_OF_APPOINTMENTS']

f2f_attended_tmp = dataframe[(dataframe['APPT_STATUS'] == 'Attended') 
                            & (dataframe['APPT_MODE'] == 'Face-to-Face')
                            & (dataframe['TIME_BETWEEN_BOOK_AND_APPT'] !='More than 28 Days')
                            & (dataframe['TIME_BETWEEN_BOOK_AND_APPT'] !='Unknown / Data Issue')                    
                            ]['COUNT_OF_APPOINTMENTS']

f2f_dna_tmp = dataframe[(dataframe['APPT_STATUS'] == 'DNA') 
                        & (dataframe['APPT_MODE'] == 'Face-to-Face') 
                        & (dataframe['TIME_BETWEEN_BOOK_AND_APPT'] !='More than 28 Days')
                        & (dataframe['TIME_BETWEEN_BOOK_AND_APPT'] !='Unknown / Data Issue')
                        ]['COUNT_OF_APPOINTMENTS']

# drop na

remote_attended_tmp = remote_attended_tmp.dropna()
remote_dna_tmp = remote_dna_tmp.dropna()
f2f_attended_tmp = f2f_attended_tmp.dropna()
f2f_dna_tmp = f2f_attended_tmp.dropna()

#count, min, max, 5th, 10th, 25th, 50th, 75th, 90th, 95th
print('-------------------------------------------------')
print('Data description of attended remote consultation in 2020/05:')
print(remote_attended_tmp[['CCG_NAME', 'Appointment_Date', 'COUNT_OF_APPOINTMENTS']]
      .describe(percentiles=[.05, .10, .25, .50, .75, .90, .95]))
print('-------------------------------------------------')
print('Minimum:')
print(remote_attended_tmp[['CCG_NAME', 'Appointment_Date', 'COUNT_OF_APPOINTMENTS']].min())
print('-------------------------------------------------')
print('Maximum:')
print(remote_attended_tmp[['CCG_NAME', 'Appointment_Date', 'COUNT_OF_APPOINTMENTS']].max())
print('-------------------------------------------------')
# Out:
# -------------------------------------------------
# Data description of attended remote consultation in 2020/05:
#        COUNT_OF_APPOINTMENTS
# count           34156.000000
# mean              217.757759
# std               666.995638
# min                 1.000000
# 5%                  1.000000
# 10%                 1.000000
# 25%                 5.000000
# 50%                19.000000
# 75%               126.000000
# 90%               517.000000
# 95%              1074.000000
# max             11226.000000
# -------------------------------------------------
# Minimum:
# CCG_NAME                 NHS Barnsley CCG
# Appointment_Date                01MAY2020
# COUNT_OF_APPOINTMENTS                   1
# dtype: object
# -------------------------------------------------
# Maximum:
# CCG_NAME                 NHS Wirral CCG
# Appointment_Date              31MAY2020
# COUNT_OF_APPOINTMENTS             11226
# dtype: object
# -------------------------------------------------

# %% [markdown]
# # Month/Year: 06/2020
#
# Exclusion:
#
#             1. Home Visit & Unknown
#             2. More than 28 Days & Unknown / Data Issue

# %%
csv_name = 'CCG_CSV_Jun_20.csv'
file_path = folder_path + csv_name
dataframe = pd.read_csv(file_path)
dataframe.drop('CCG_CODE', axis=1, inplace=True)
dataframe.drop('CCG_ONS_CODE', axis=1, inplace=True)
dataframe.drop('STP_ONS_CODE', axis=1, inplace=True)
dataframe.drop('HCP_TYPE', axis=1, inplace=True)
dataframe.drop('REGION_ONS_CODE', axis=1, inplace=True)

# %% [markdown]
# ## Data filtering & Analysis

# %%
# dna: did not attend
# f2f: face-to-face
# remote: Video Conference/Online & Telephone

remote_attended_tmp = dataframe[(dataframe['APPT_STATUS'] == 'Attended') 
                                & (dataframe['APPT_MODE'] != 'Home Visit') 
                                & (dataframe['APPT_MODE'] != 'Face-to-Face') 
                                & (dataframe['APPT_MODE'] != 'Unknown') 
                                & (dataframe['TIME_BETWEEN_BOOK_AND_APPT'] !='More than 28 Days')
                                & (dataframe['TIME_BETWEEN_BOOK_AND_APPT'] !='Unknown / Data Issue')
                                ]

remote_dna_tmp = dataframe[(dataframe['APPT_STATUS'] == 'DNA') 
                                & (dataframe['APPT_MODE'] != 'Home Visit') 
                                & (dataframe['APPT_MODE'] != 'Face-to-Face') 
                                & (dataframe['APPT_MODE'] != 'Unknown') 
                                & (dataframe['TIME_BETWEEN_BOOK_AND_APPT'] !='More than 28 Days')
                                & (dataframe['TIME_BETWEEN_BOOK_AND_APPT'] !='Unknown / Data Issue')
                                ]['COUNT_OF_APPOINTMENTS']

f2f_attended_tmp = dataframe[(dataframe['APPT_STATUS'] == 'Attended') 
                            & (dataframe['APPT_MODE'] == 'Face-to-Face')
                            & (dataframe['TIME_BETWEEN_BOOK_AND_APPT'] !='More than 28 Days')
                            & (dataframe['TIME_BETWEEN_BOOK_AND_APPT'] !='Unknown / Data Issue')                    
                            ]['COUNT_OF_APPOINTMENTS']

f2f_dna_tmp = dataframe[(dataframe['APPT_STATUS'] == 'DNA') 
                        & (dataframe['APPT_MODE'] == 'Face-to-Face') 
                        & (dataframe['TIME_BETWEEN_BOOK_AND_APPT'] !='More than 28 Days')
                        & (dataframe['TIME_BETWEEN_BOOK_AND_APPT'] !='Unknown / Data Issue')
                        ]['COUNT_OF_APPOINTMENTS']

# drop na

remote_attended_tmp = remote_attended_tmp.dropna()
remote_dna_tmp = remote_dna_tmp.dropna()
f2f_attended_tmp = f2f_attended_tmp.dropna()
f2f_dna_tmp = f2f_attended_tmp.dropna()

#count, min, max, 5th, 10th, 25th, 50th, 75th, 90th, 95th
print('-------------------------------------------------')
print('Data description of attended remote consultation in 2020/06:')
print(remote_attended_tmp[['CCG_NAME', 'Appointment_Date', 'COUNT_OF_APPOINTMENTS']]
      .describe(percentiles=[.05, .10, .25, .50, .75, .90, .95]))
print('-------------------------------------------------')
print('Minimum:')
print(remote_attended_tmp[['CCG_NAME', 'Appointment_Date', 'COUNT_OF_APPOINTMENTS']].min())
print('-------------------------------------------------')
print('Maximum:')
print(remote_attended_tmp[['CCG_NAME', 'Appointment_Date', 'COUNT_OF_APPOINTMENTS']].max())
print('-------------------------------------------------')
# Out:
# -------------------------------------------------
# Data description of attended remote consultation in 2020/06:
#        COUNT_OF_APPOINTMENTS
# count           39076.000000
# mean              239.970954
# std               699.597085
# min                 1.000000
# 5%                  1.000000
# 10%                 2.000000
# 25%                 5.000000
# 50%                23.000000
# 75%               149.000000
# 90%               598.500000
# 95%              1158.250000
# max             11093.000000
# -------------------------------------------------
# Minimum:
# CCG_NAME                 NHS Barnsley CCG
# Appointment_Date                01JUN2020
# COUNT_OF_APPOINTMENTS                   1
# dtype: object
# -------------------------------------------------
# Maximum:
# CCG_NAME                 NHS Wirral CCG
# Appointment_Date              30JUN2020
# COUNT_OF_APPOINTMENTS             11093
# dtype: object
# -------------------------------------------------

# %% [markdown]
# # Month/Year: 07/2020
#
# Exclusion:
#
#             1. Home Visit & Unknown
#             2. More than 28 Days & Unknown / Data Issue

# %%
csv_name = 'CCG_CSV_Jul_20.csv'
file_path = folder_path + csv_name
dataframe = pd.read_csv(file_path)
dataframe.drop('CCG_CODE', axis=1, inplace=True)
dataframe.drop('CCG_ONS_CODE', axis=1, inplace=True)
dataframe.drop('STP_ONS_CODE', axis=1, inplace=True)
dataframe.drop('HCP_TYPE', axis=1, inplace=True)
dataframe.drop('REGION_ONS_CODE', axis=1, inplace=True)

# %% [markdown]
# ## Data filtering & Analysis

# %%
# dna: did not attend
# f2f: face-to-face
# remote: Video Conference/Online & Telephone

remote_attended_tmp = dataframe[(dataframe['APPT_STATUS'] == 'Attended') 
                                & (dataframe['APPT_MODE'] != 'Home Visit') 
                                & (dataframe['APPT_MODE'] != 'Face-to-Face') 
                                & (dataframe['APPT_MODE'] != 'Unknown') 
                                & (dataframe['TIME_BETWEEN_BOOK_AND_APPT'] !='More than 28 Days')
                                & (dataframe['TIME_BETWEEN_BOOK_AND_APPT'] !='Unknown / Data Issue')
                                ]

remote_dna_tmp = dataframe[(dataframe['APPT_STATUS'] == 'DNA') 
                                & (dataframe['APPT_MODE'] != 'Home Visit') 
                                & (dataframe['APPT_MODE'] != 'Face-to-Face') 
                                & (dataframe['APPT_MODE'] != 'Unknown') 
                                & (dataframe['TIME_BETWEEN_BOOK_AND_APPT'] !='More than 28 Days')
                                & (dataframe['TIME_BETWEEN_BOOK_AND_APPT'] !='Unknown / Data Issue')
                                ]['COUNT_OF_APPOINTMENTS']

f2f_attended_tmp = dataframe[(dataframe['APPT_STATUS'] == 'Attended') 
                            & (dataframe['APPT_MODE'] == 'Face-to-Face')
                            & (dataframe['TIME_BETWEEN_BOOK_AND_APPT'] !='More than 28 Days')
                            & (dataframe['TIME_BETWEEN_BOOK_AND_APPT'] !='Unknown / Data Issue')                    
                            ]['COUNT_OF_APPOINTMENTS']

f2f_dna_tmp = dataframe[(dataframe['APPT_STATUS'] == 'DNA') 
                        & (dataframe['APPT_MODE'] == 'Face-to-Face') 
                        & (dataframe['TIME_BETWEEN_BOOK_AND_APPT'] !='More than 28 Days')
                        & (dataframe['TIME_BETWEEN_BOOK_AND_APPT'] !='Unknown / Data Issue')
                        ]['COUNT_OF_APPOINTMENTS']

# drop na

remote_attended_tmp = remote_attended_tmp.dropna()
remote_dna_tmp = remote_dna_tmp.dropna()
f2f_attended_tmp = f2f_attended_tmp.dropna()
f2f_dna_tmp = f2f_attended_tmp.dropna()

#count, min, max, 5th, 10th, 25th, 50th, 75th, 90th, 95th
print('-------------------------------------------------')
print('Data description of attended remote consultation in 2020/07:')
print(remote_attended_tmp[['CCG_NAME', 'Appointment_Date', 'COUNT_OF_APPOINTMENTS']]
      .describe(percentiles=[.05, .10, .25, .50, .75, .90, .95]))
print('-------------------------------------------------')
print('Minimum:')
print(remote_attended_tmp[['CCG_NAME', 'Appointment_Date', 'COUNT_OF_APPOINTMENTS']].min())
print('-------------------------------------------------')
print('Maximum:')
print(remote_attended_tmp[['CCG_NAME', 'Appointment_Date', 'COUNT_OF_APPOINTMENTS']].max())
print('-------------------------------------------------')
# Out:
# -------------------------------------------------
# Data description of attended remote consultation in 2020/07:
#        COUNT_OF_APPOINTMENTS
# count           43793.000000
# mean              220.015459
# std               629.228755
# min                 1.000000
# 5%                  1.000000
# 10%                 2.000000
# 25%                 5.000000
# 50%                26.000000
# 75%               147.000000
# 90%               534.000000
# 95%              1052.000000
# max             10437.000000
# -------------------------------------------------
# Minimum:
# CCG_NAME                 NHS Barnsley CCG
# Appointment_Date                01JUL2020
# COUNT_OF_APPOINTMENTS                   1
# dtype: object
# -------------------------------------------------
# Maximum:
# CCG_NAME                 NHS Wirral CCG
# Appointment_Date              31JUL2020
# COUNT_OF_APPOINTMENTS             10437
# dtype: object
# -------------------------------------------------

# %% [markdown]
# # Month/Year: 08/2020
#
# Exclusion:
#
#             1. Home Visit & Unknown
#             2. More than 28 Days & Unknown / Data Issue

# %%
csv_name = 'CCG_CSV_Aug_20.csv'
file_path = folder_path + csv_name
dataframe = pd.read_csv(file_path)
dataframe.drop('CCG_CODE', axis=1, inplace=True)
dataframe.drop('CCG_ONS_CODE', axis=1, inplace=True)
dataframe.drop('STP_ONS_CODE', axis=1, inplace=True)
dataframe.drop('HCP_TYPE', axis=1, inplace=True)
dataframe.drop('REGION_ONS_CODE', axis=1, inplace=True)

# %% [markdown]
# ## Data filtering & Analysis

# %%
# dna: did not attend
# f2f: face-to-face
# remote: Video Conference/Online & Telephone

remote_attended_tmp = dataframe[(dataframe['APPT_STATUS'] == 'Attended') 
                                & (dataframe['APPT_MODE'] != 'Home Visit') 
                                & (dataframe['APPT_MODE'] != 'Face-to-Face') 
                                & (dataframe['APPT_MODE'] != 'Unknown') 
                                & (dataframe['TIME_BETWEEN_BOOK_AND_APPT'] !='More than 28 Days')
                                & (dataframe['TIME_BETWEEN_BOOK_AND_APPT'] !='Unknown / Data Issue')
                                ]

remote_dna_tmp = dataframe[(dataframe['APPT_STATUS'] == 'DNA') 
                                & (dataframe['APPT_MODE'] != 'Home Visit') 
                                & (dataframe['APPT_MODE'] != 'Face-to-Face') 
                                & (dataframe['APPT_MODE'] != 'Unknown') 
                                & (dataframe['TIME_BETWEEN_BOOK_AND_APPT'] !='More than 28 Days')
                                & (dataframe['TIME_BETWEEN_BOOK_AND_APPT'] !='Unknown / Data Issue')
                                ]['COUNT_OF_APPOINTMENTS']

f2f_attended_tmp = dataframe[(dataframe['APPT_STATUS'] == 'Attended') 
                            & (dataframe['APPT_MODE'] == 'Face-to-Face')
                            & (dataframe['TIME_BETWEEN_BOOK_AND_APPT'] !='More than 28 Days')
                            & (dataframe['TIME_BETWEEN_BOOK_AND_APPT'] !='Unknown / Data Issue')                    
                            ]['COUNT_OF_APPOINTMENTS']

f2f_dna_tmp = dataframe[(dataframe['APPT_STATUS'] == 'DNA') 
                        & (dataframe['APPT_MODE'] == 'Face-to-Face') 
                        & (dataframe['TIME_BETWEEN_BOOK_AND_APPT'] !='More than 28 Days')
                        & (dataframe['TIME_BETWEEN_BOOK_AND_APPT'] !='Unknown / Data Issue')
                        ]['COUNT_OF_APPOINTMENTS']

# drop na

remote_attended_tmp = remote_attended_tmp.dropna()
remote_dna_tmp = remote_dna_tmp.dropna()
f2f_attended_tmp = f2f_attended_tmp.dropna()
f2f_dna_tmp = f2f_attended_tmp.dropna()

#count, min, max, 5th, 10th, 25th, 50th, 75th, 90th, 95th
print('-------------------------------------------------')
print('Data description of attended remote consultation in 2020/08:')
print(remote_attended_tmp[['CCG_NAME', 'Appointment_Date', 'COUNT_OF_APPOINTMENTS']]
      .describe(percentiles=[.05, .10, .25, .50, .75, .90, .95]))
print('-------------------------------------------------')
print('Minimum:')
print(remote_attended_tmp[['CCG_NAME', 'Appointment_Date', 'COUNT_OF_APPOINTMENTS']].min())
print('-------------------------------------------------')
print('Maximum:')
print(remote_attended_tmp[['CCG_NAME', 'Appointment_Date', 'COUNT_OF_APPOINTMENTS']].max())
print('-------------------------------------------------')
# Out:
# -------------------------------------------------
# Data description of attended remote consultation in 2020/08:
#        COUNT_OF_APPOINTMENTS
# count           40349.000000
# mean              206.166894
# std               605.165345
# min                 1.000000
# 5%                  1.000000
# 10%                 2.000000
# 25%                 5.000000
# 50%                26.000000
# 75%               136.000000
# 90%               481.000000
# 95%               959.000000
# max             10106.000000
# -------------------------------------------------
# Minimum:
# CCG_NAME                 NHS Barnsley CCG
# Appointment_Date                01AUG2020
# COUNT_OF_APPOINTMENTS                   1
# dtype: object
# -------------------------------------------------
# Maximum:
# CCG_NAME                 NHS Wirral CCG
# Appointment_Date              31AUG2020
# COUNT_OF_APPOINTMENTS             10106
# dtype: object
# -------------------------------------------------

# %% [markdown]
# # Month/Year: 09/2020
#
# Exclusion:
#
#             1. Home Visit & Unknown
#             2. More than 28 Days & Unknown / Data Issue

# %%
csv_name = 'CCG_CSV_Sep_20.csv'
file_path = folder_path + csv_name
dataframe = pd.read_csv(file_path)
dataframe.drop('CCG_CODE', axis=1, inplace=True)
dataframe.drop('CCG_ONS_CODE', axis=1, inplace=True)
dataframe.drop('STP_ONS_CODE', axis=1, inplace=True)
dataframe.drop('HCP_TYPE', axis=1, inplace=True)
dataframe.drop('REGION_ONS_CODE', axis=1, inplace=True)

# %% [markdown]
# ## Data filtering & Analysis

# %%
# dna: did not attend
# f2f: face-to-face
# remote: Video Conference/Online & Telephone

remote_attended_tmp = dataframe[(dataframe['APPT_STATUS'] == 'Attended') 
                                & (dataframe['APPT_MODE'] != 'Home Visit') 
                                & (dataframe['APPT_MODE'] != 'Face-to-Face') 
                                & (dataframe['APPT_MODE'] != 'Unknown') 
                                & (dataframe['TIME_BETWEEN_BOOK_AND_APPT'] !='More than 28 Days')
                                & (dataframe['TIME_BETWEEN_BOOK_AND_APPT'] !='Unknown / Data Issue')
                                ]

remote_dna_tmp = dataframe[(dataframe['APPT_STATUS'] == 'DNA') 
                                & (dataframe['APPT_MODE'] != 'Home Visit') 
                                & (dataframe['APPT_MODE'] != 'Face-to-Face') 
                                & (dataframe['APPT_MODE'] != 'Unknown') 
                                & (dataframe['TIME_BETWEEN_BOOK_AND_APPT'] !='More than 28 Days')
                                & (dataframe['TIME_BETWEEN_BOOK_AND_APPT'] !='Unknown / Data Issue')
                                ]['COUNT_OF_APPOINTMENTS']

f2f_attended_tmp = dataframe[(dataframe['APPT_STATUS'] == 'Attended') 
                            & (dataframe['APPT_MODE'] == 'Face-to-Face')
                            & (dataframe['TIME_BETWEEN_BOOK_AND_APPT'] !='More than 28 Days')
                            & (dataframe['TIME_BETWEEN_BOOK_AND_APPT'] !='Unknown / Data Issue')                    
                            ]['COUNT_OF_APPOINTMENTS']

f2f_dna_tmp = dataframe[(dataframe['APPT_STATUS'] == 'DNA') 
                        & (dataframe['APPT_MODE'] == 'Face-to-Face') 
                        & (dataframe['TIME_BETWEEN_BOOK_AND_APPT'] !='More than 28 Days')
                        & (dataframe['TIME_BETWEEN_BOOK_AND_APPT'] !='Unknown / Data Issue')
                        ]['COUNT_OF_APPOINTMENTS']

# drop na

remote_attended_tmp = remote_attended_tmp.dropna()
remote_dna_tmp = remote_dna_tmp.dropna()
f2f_attended_tmp = f2f_attended_tmp.dropna()
f2f_dna_tmp = f2f_attended_tmp.dropna()

#count, min, max, 5th, 10th, 25th, 50th, 75th, 90th, 95th
print('-------------------------------------------------')
print('Data description of attended remote consultation in 2020/09:')
print(remote_attended_tmp[['CCG_NAME', 'Appointment_Date', 'COUNT_OF_APPOINTMENTS']]
      .describe(percentiles=[.05, .10, .25, .50, .75, .90, .95]))
print('-------------------------------------------------')
print('Minimum:')
print(remote_attended_tmp[['CCG_NAME', 'Appointment_Date', 'COUNT_OF_APPOINTMENTS']].min())
print('-------------------------------------------------')
print('Maximum:')
print(remote_attended_tmp[['CCG_NAME', 'Appointment_Date', 'COUNT_OF_APPOINTMENTS']].max())
print('-------------------------------------------------')
# Out:
# -------------------------------------------------
# Data description of attended remote consultation in 2020/09:
#        COUNT_OF_APPOINTMENTS
# count           44402.000000
# mean              219.623643
# std               638.661463
# min                 1.000000
# 5%                  1.000000
# 10%                 2.000000
# 25%                 6.000000
# 50%                31.000000
# 75%               146.000000
# 90%               521.000000
# 95%              1020.000000
# max             10544.000000
# -------------------------------------------------
# Minimum:
# CCG_NAME                 NHS Barnsley CCG
# Appointment_Date                01SEP2020
# COUNT_OF_APPOINTMENTS                   1
# dtype: object
# -------------------------------------------------
# Maximum:
# CCG_NAME                 NHS Wirral CCG
# Appointment_Date              30SEP2020
# COUNT_OF_APPOINTMENTS             10544
# dtype: object
# -------------------------------------------------

# %% [markdown]
# # Month/Year: 10/2020
#
# Exclusion:
#
#             1. Home Visit & Unknown
#             2. More than 28 Days & Unknown / Data Issue

# %%
csv_name = 'CCG_CSV_Oct_20.csv'
file_path = folder_path + csv_name
dataframe = pd.read_csv(file_path)
dataframe.drop('CCG_CODE', axis=1, inplace=True)
dataframe.drop('CCG_ONS_CODE', axis=1, inplace=True)
dataframe.drop('STP_ONS_CODE', axis=1, inplace=True)
dataframe.drop('HCP_TYPE', axis=1, inplace=True)
dataframe.drop('REGION_ONS_CODE', axis=1, inplace=True)

# %% [markdown]
# ## Data filtering & Analysis

# %%
# dna: did not attend
# f2f: face-to-face
# remote: Video Conference/Online & Telephone

remote_attended_tmp = dataframe[(dataframe['APPT_STATUS'] == 'Attended') 
                                & (dataframe['APPT_MODE'] != 'Home Visit') 
                                & (dataframe['APPT_MODE'] != 'Face-to-Face') 
                                & (dataframe['APPT_MODE'] != 'Unknown') 
                                & (dataframe['TIME_BETWEEN_BOOK_AND_APPT'] !='More than 28 Days')
                                & (dataframe['TIME_BETWEEN_BOOK_AND_APPT'] !='Unknown / Data Issue')
                                ]

remote_dna_tmp = dataframe[(dataframe['APPT_STATUS'] == 'DNA') 
                                & (dataframe['APPT_MODE'] != 'Home Visit') 
                                & (dataframe['APPT_MODE'] != 'Face-to-Face') 
                                & (dataframe['APPT_MODE'] != 'Unknown') 
                                & (dataframe['TIME_BETWEEN_BOOK_AND_APPT'] !='More than 28 Days')
                                & (dataframe['TIME_BETWEEN_BOOK_AND_APPT'] !='Unknown / Data Issue')
                                ]['COUNT_OF_APPOINTMENTS']

f2f_attended_tmp = dataframe[(dataframe['APPT_STATUS'] == 'Attended') 
                            & (dataframe['APPT_MODE'] == 'Face-to-Face')
                            & (dataframe['TIME_BETWEEN_BOOK_AND_APPT'] !='More than 28 Days')
                            & (dataframe['TIME_BETWEEN_BOOK_AND_APPT'] !='Unknown / Data Issue')                    
                            ]['COUNT_OF_APPOINTMENTS']

f2f_dna_tmp = dataframe[(dataframe['APPT_STATUS'] == 'DNA') 
                        & (dataframe['APPT_MODE'] == 'Face-to-Face') 
                        & (dataframe['TIME_BETWEEN_BOOK_AND_APPT'] !='More than 28 Days')
                        & (dataframe['TIME_BETWEEN_BOOK_AND_APPT'] !='Unknown / Data Issue')
                        ]['COUNT_OF_APPOINTMENTS']

# drop na

remote_attended_tmp = remote_attended_tmp.dropna()
remote_dna_tmp = remote_dna_tmp.dropna()
f2f_attended_tmp = f2f_attended_tmp.dropna()
f2f_dna_tmp = f2f_attended_tmp.dropna()

#count, min, max, 5th, 10th, 25th, 50th, 75th, 90th, 95th
print('-------------------------------------------------')
print('Data description of attended remote consultation in 2020/10:')
print(remote_attended_tmp[['CCG_NAME', 'Appointment_Date', 'COUNT_OF_APPOINTMENTS']]
      .describe(percentiles=[.05, .10, .25, .50, .75, .90, .95]))
print('-------------------------------------------------')
print('Minimum:')
print(remote_attended_tmp[['CCG_NAME', 'Appointment_Date', 'COUNT_OF_APPOINTMENTS']].min())
print('-------------------------------------------------')
print('Maximum:')
print(remote_attended_tmp[['CCG_NAME', 'Appointment_Date', 'COUNT_OF_APPOINTMENTS']].max())
print('-------------------------------------------------')
# Out:
# -------------------------------------------------
# Data description of attended remote consultation in 2020/10:
#        COUNT_OF_APPOINTMENTS
# count           45245.000000
# mean              211.922710
# std               613.574128
# min                 1.000000
# 5%                  1.000000
# 10%                 2.000000
# 25%                 6.000000
# 50%                30.000000
# 75%               140.000000
# 90%               506.600000
# 95%               992.000000
# max             10476.000000
# -------------------------------------------------
# Minimum:
# CCG_NAME                 NHS Barnsley CCG
# Appointment_Date                01OCT2020
# COUNT_OF_APPOINTMENTS                   1
# dtype: object
# -------------------------------------------------
# Maximum:
# CCG_NAME                 NHS Wirral CCG
# Appointment_Date              31OCT2020
# COUNT_OF_APPOINTMENTS             10476
# dtype: object
# -------------------------------------------------

# %% [markdown]
# # Month/Year: 11/2020
#
# Exclusion:
#
#             1. Home Visit & Unknown
#             2. More than 28 Days & Unknown / Data Issue

# %%
csv_name = 'CCG_CSV_Nov_20.csv'
file_path = folder_path + csv_name
dataframe = pd.read_csv(file_path)
dataframe.drop('CCG_CODE', axis=1, inplace=True)
dataframe.drop('CCG_ONS_CODE', axis=1, inplace=True)
dataframe.drop('STP_ONS_CODE', axis=1, inplace=True)
dataframe.drop('HCP_TYPE', axis=1, inplace=True)
dataframe.drop('REGION_ONS_CODE', axis=1, inplace=True)

# %% [markdown]
# ## Data filtering & Analysis

# %%
# dna: did not attend
# f2f: face-to-face
# remote: Video Conference/Online & Telephone

remote_attended_tmp = dataframe[(dataframe['APPT_STATUS'] == 'Attended') 
                                & (dataframe['APPT_MODE'] != 'Home Visit') 
                                & (dataframe['APPT_MODE'] != 'Face-to-Face') 
                                & (dataframe['APPT_MODE'] != 'Unknown') 
                                & (dataframe['TIME_BETWEEN_BOOK_AND_APPT'] !='More than 28 Days')
                                & (dataframe['TIME_BETWEEN_BOOK_AND_APPT'] !='Unknown / Data Issue')
                                ]

remote_dna_tmp = dataframe[(dataframe['APPT_STATUS'] == 'DNA') 
                                & (dataframe['APPT_MODE'] != 'Home Visit') 
                                & (dataframe['APPT_MODE'] != 'Face-to-Face') 
                                & (dataframe['APPT_MODE'] != 'Unknown') 
                                & (dataframe['TIME_BETWEEN_BOOK_AND_APPT'] !='More than 28 Days')
                                & (dataframe['TIME_BETWEEN_BOOK_AND_APPT'] !='Unknown / Data Issue')
                                ]['COUNT_OF_APPOINTMENTS']

f2f_attended_tmp = dataframe[(dataframe['APPT_STATUS'] == 'Attended') 
                            & (dataframe['APPT_MODE'] == 'Face-to-Face')
                            & (dataframe['TIME_BETWEEN_BOOK_AND_APPT'] !='More than 28 Days')
                            & (dataframe['TIME_BETWEEN_BOOK_AND_APPT'] !='Unknown / Data Issue')                    
                            ]['COUNT_OF_APPOINTMENTS']

f2f_dna_tmp = dataframe[(dataframe['APPT_STATUS'] == 'DNA') 
                        & (dataframe['APPT_MODE'] == 'Face-to-Face') 
                        & (dataframe['TIME_BETWEEN_BOOK_AND_APPT'] !='More than 28 Days')
                        & (dataframe['TIME_BETWEEN_BOOK_AND_APPT'] !='Unknown / Data Issue')
                        ]['COUNT_OF_APPOINTMENTS']

# drop na

remote_attended_tmp = remote_attended_tmp.dropna()
remote_dna_tmp = remote_dna_tmp.dropna()
f2f_attended_tmp = f2f_attended_tmp.dropna()
f2f_dna_tmp = f2f_attended_tmp.dropna()

#count, min, max, 5th, 10th, 25th, 50th, 75th, 90th, 95th
print('-------------------------------------------------')
print('Data description of attended remote consultation in 2020/11:')
print(remote_attended_tmp[['CCG_NAME', 'Appointment_Date', 'COUNT_OF_APPOINTMENTS']]
      .describe(percentiles=[.05, .10, .25, .50, .75, .90, .95]))
print('-------------------------------------------------')
print('Minimum:')
print(remote_attended_tmp[['CCG_NAME', 'Appointment_Date', 'COUNT_OF_APPOINTMENTS']].min())
print('-------------------------------------------------')
print('Maximum:')
print(remote_attended_tmp[['CCG_NAME', 'Appointment_Date', 'COUNT_OF_APPOINTMENTS']].max())
print('-------------------------------------------------')
# Out:
# -------------------------------------------------
# Data description of attended remote consultation in 2020/11:
#        COUNT_OF_APPOINTMENTS
# count           42911.000000
# mean              222.936496
# std               639.740459
# min                 1.000000
# 5%                  1.000000
# 10%                 2.000000
# 25%                 6.000000
# 50%                33.000000
# 75%               151.000000
# 90%               529.000000
# 95%              1037.000000
# max             10570.000000
# -------------------------------------------------
# Minimum:
# CCG_NAME                 NHS Barnsley CCG
# Appointment_Date                01NOV2020
# COUNT_OF_APPOINTMENTS                   1
# dtype: object
# -------------------------------------------------
# Maximum:
# CCG_NAME                 NHS Wirral CCG
# Appointment_Date              30NOV2020
# COUNT_OF_APPOINTMENTS             10570
# dtype: object
# -------------------------------------------------

# %% [markdown]
# # Month/Year: 12/2020
#
# Exclusion:
#
#             1. Home Visit & Unknown
#             2. More than 28 Days & Unknown / Data Issue

# %%
csv_name = 'CCG_CSV_Dec_20.csv'
file_path = folder_path + csv_name
dataframe = pd.read_csv(file_path)
dataframe.drop('CCG_CODE', axis=1, inplace=True)
dataframe.drop('CCG_ONS_CODE', axis=1, inplace=True)
dataframe.drop('STP_ONS_CODE', axis=1, inplace=True)
dataframe.drop('HCP_TYPE', axis=1, inplace=True)
dataframe.drop('REGION_ONS_CODE', axis=1, inplace=True)

# %% [markdown]
# ## Data filtering & Analysis

# %%
# dna: did not attend
# f2f: face-to-face
# remote: Video Conference/Online & Telephone

remote_attended_tmp = dataframe[(dataframe['APPT_STATUS'] == 'Attended') 
                                & (dataframe['APPT_MODE'] != 'Home Visit') 
                                & (dataframe['APPT_MODE'] != 'Face-to-Face') 
                                & (dataframe['APPT_MODE'] != 'Unknown') 
                                & (dataframe['TIME_BETWEEN_BOOK_AND_APPT'] !='More than 28 Days')
                                & (dataframe['TIME_BETWEEN_BOOK_AND_APPT'] !='Unknown / Data Issue')
                                ]

remote_dna_tmp = dataframe[(dataframe['APPT_STATUS'] == 'DNA') 
                                & (dataframe['APPT_MODE'] != 'Home Visit') 
                                & (dataframe['APPT_MODE'] != 'Face-to-Face') 
                                & (dataframe['APPT_MODE'] != 'Unknown') 
                                & (dataframe['TIME_BETWEEN_BOOK_AND_APPT'] !='More than 28 Days')
                                & (dataframe['TIME_BETWEEN_BOOK_AND_APPT'] !='Unknown / Data Issue')
                                ]['COUNT_OF_APPOINTMENTS']

f2f_attended_tmp = dataframe[(dataframe['APPT_STATUS'] == 'Attended') 
                            & (dataframe['APPT_MODE'] == 'Face-to-Face')
                            & (dataframe['TIME_BETWEEN_BOOK_AND_APPT'] !='More than 28 Days')
                            & (dataframe['TIME_BETWEEN_BOOK_AND_APPT'] !='Unknown / Data Issue')                    
                            ]['COUNT_OF_APPOINTMENTS']

f2f_dna_tmp = dataframe[(dataframe['APPT_STATUS'] == 'DNA') 
                        & (dataframe['APPT_MODE'] == 'Face-to-Face') 
                        & (dataframe['TIME_BETWEEN_BOOK_AND_APPT'] !='More than 28 Days')
                        & (dataframe['TIME_BETWEEN_BOOK_AND_APPT'] !='Unknown / Data Issue')
                        ]['COUNT_OF_APPOINTMENTS']

# drop na

remote_attended_tmp = remote_attended_tmp.dropna()
remote_dna_tmp = remote_dna_tmp.dropna()
f2f_attended_tmp = f2f_attended_tmp.dropna()
f2f_dna_tmp = f2f_attended_tmp.dropna()

#count, min, max, 5th, 10th, 25th, 50th, 75th, 90th, 95th
print('-------------------------------------------------')
print('Data description of attended remote consultation in 2020/12:')
print(remote_attended_tmp[['CCG_NAME', 'Appointment_Date', 'COUNT_OF_APPOINTMENTS']]
      .describe(percentiles=[.05, .10, .25, .50, .75, .90, .95]))
print('-------------------------------------------------')
print('Minimum:')
print(remote_attended_tmp[['CCG_NAME', 'Appointment_Date', 'COUNT_OF_APPOINTMENTS']].min())
print('-------------------------------------------------')
print('Maximum:')
print(remote_attended_tmp[['CCG_NAME', 'Appointment_Date', 'COUNT_OF_APPOINTMENTS']].max())
print('-------------------------------------------------')
# Out:
# -------------------------------------------------
# Data description of attended remote consultation in 2020/12:
#        COUNT_OF_APPOINTMENTS
# count           42329.000000
# mean              210.530842
# std               609.407784
# min                 1.000000
# 5%                  1.000000
# 10%                 2.000000
# 25%                 6.000000
# 50%                34.000000
# 75%               141.000000
# 90%               486.000000
# 95%               966.000000
# max             10219.000000
# -------------------------------------------------
# Minimum:
# CCG_NAME                 NHS Barnsley CCG
# Appointment_Date                01DEC2020
# COUNT_OF_APPOINTMENTS                   1
# dtype: object
# -------------------------------------------------
# Maximum:
# CCG_NAME                 NHS Wirral CCG
# Appointment_Date              31DEC2020
# COUNT_OF_APPOINTMENTS             10219
# dtype: object
# -------------------------------------------------
