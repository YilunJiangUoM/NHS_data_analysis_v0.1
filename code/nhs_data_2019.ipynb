# %% [markdown]
# # Import packages

# %%
import csv
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.ticker import FuncFormatter
import seaborn as sns

# modify folder path
folder_path = 'Your folder path'

# %% [markdown]
# # Import CSV file
#
# # Month/Year: 01/2019
#
# Exclusion:
#
#             1. Home Visit & Unknown
#             2. More than 28 Days & Unknown / Data Issue

# %%
csv_name = 'CCG_CSV_Jan_19.csv'
file_path = folder_path + csv_name
dataframe = pd.read_csv(file_path)
dataframe.drop('CCG_CODE', axis=1, inplace=True)
dataframe.drop('CCG_ONS_CODE', axis=1, inplace=True)
dataframe.drop('STP_CODE', axis=1, inplace=True)
dataframe.drop('HCP_TYPE', axis=1, inplace=True)
dataframe.drop('REGION_ONS_CODE', axis=1, inplace=True)

# %% [markdown]
# ## Data filtering & Analysis

# %%
# dna: did not attend
# f2f: face-to-face
# remote: Video Conference/Online & Telephone

remote_attended_tmp = dataframe[(dataframe['APPT_STATUS'] == 'Attended') 
                                & (dataframe['APPT_MODE'] != 'Home Visit') 
                                & (dataframe['APPT_MODE'] != 'Face-to-Face') 
                                & (dataframe['APPT_MODE'] != 'Unknown') 
                                & (dataframe['TIME_BETWEEN_BOOK_AND_APPT'] !='More than 28 Days')
                                & (dataframe['TIME_BETWEEN_BOOK_AND_APPT'] !='Unknown / Data Issue')
                                ]

remote_dna_tmp = dataframe[(dataframe['APPT_STATUS'] == 'DNA') 
                                & (dataframe['APPT_MODE'] != 'Home Visit') 
                                & (dataframe['APPT_MODE'] != 'Face-to-Face') 
                                & (dataframe['APPT_MODE'] != 'Unknown') 
                                & (dataframe['TIME_BETWEEN_BOOK_AND_APPT'] !='More than 28 Days')
                                & (dataframe['TIME_BETWEEN_BOOK_AND_APPT'] !='Unknown / Data Issue')
                                ]['COUNT_OF_APPOINTMENTS']

f2f_attended_tmp = dataframe[(dataframe['APPT_STATUS'] == 'Attended') 
                            & (dataframe['APPT_MODE'] == 'Face-to-Face')
                            & (dataframe['TIME_BETWEEN_BOOK_AND_APPT'] !='More than 28 Days')
                            & (dataframe['TIME_BETWEEN_BOOK_AND_APPT'] !='Unknown / Data Issue')                    
                            ]['COUNT_OF_APPOINTMENTS']

f2f_dna_tmp = dataframe[(dataframe['APPT_STATUS'] == 'DNA') 
                        & (dataframe['APPT_MODE'] == 'Face-to-Face') 
                        & (dataframe['TIME_BETWEEN_BOOK_AND_APPT'] !='More than 28 Days')
                        & (dataframe['TIME_BETWEEN_BOOK_AND_APPT'] !='Unknown / Data Issue')
                        ]['COUNT_OF_APPOINTMENTS']


# drop na
print(len(remote_attended_tmp))
remote_attended_tmp = remote_attended_tmp.dropna()
print(len(remote_attended_tmp))
remote_dna_tmp = remote_dna_tmp.dropna()
f2f_attended_tmp = f2f_attended_tmp.dropna()
f2f_dna_tmp = f2f_attended_tmp.dropna()

#count, mean, max, min, 5th, 10th, 25th, 50th, 75th, 90th, 95th
print('-------------------------------------------------')
print('Data description of attended remote consultation in 2019/01:')
print(remote_attended_tmp[['CCG_NAME', 'Appointment_Date', 'COUNT_OF_APPOINTMENTS']]
      .describe(percentiles=[.05, .10, .25, .50, .75, .90, .95]))
print('-------------------------------------------------')
print('Minimum:')
print(remote_attended_tmp[['CCG_NAME', 'Appointment_Date', 'COUNT_OF_APPOINTMENTS']].min())
print('-------------------------------------------------')
print('Maximum:')
print(remote_attended_tmp[['CCG_NAME', 'Appointment_Date', 'COUNT_OF_APPOINTMENTS']].max())
print('-------------------------------------------------')
# Out:
# 59288
# 59288
# -------------------------------------------------
# Data description of attended remote consultation in 2019/01:
#        COUNT_OF_APPOINTMENTS
# count           59288.000000
# mean               58.259159
# std               161.983473
# min                 1.000000
# 5%                  1.000000
# 10%                 1.000000
# 25%                 3.000000
# 50%                10.000000
# 75%                40.000000
# 90%               139.000000
# 95%               283.000000
# max              3889.000000
# -------------------------------------------------
# Minimum:
# CCG_NAME                 NHS Airedale Wharfedale and Craven CCG
# Appointment_Date                                      01JAN2019
# COUNT_OF_APPOINTMENTS                                         1
# dtype: object
# -------------------------------------------------
# Maximum:
# CCG_NAME                 NHS Wyre Forest CCG
# Appointment_Date                   31JAN2019
# ...

# %% [markdown]
# # Month/Year: 02/2019
#
# Exclusion:
#
#             1. Home Visit & Unknown
#             2. More than 28 Days & Unknown / Data Issue

# %%
csv_name = 'CCG_CSV_Feb_19.csv'
file_path = folder_path + csv_name
dataframe = pd.read_csv(file_path)
dataframe.drop('CCG_CODE', axis=1, inplace=True)
dataframe.drop('CCG_ONS_CODE', axis=1, inplace=True)
dataframe.drop('STP_CODE', axis=1, inplace=True)
dataframe.drop('HCP_TYPE', axis=1, inplace=True)
dataframe.drop('REGION_ONS_CODE', axis=1, inplace=True)

# %% [markdown]
# ## Data filtering & Analysis

# %%
# dna: did not attend
# f2f: face-to-face
# remote: Video Conference/Online & Telephone

remote_attended_tmp = dataframe[(dataframe['APPT_STATUS'] == 'Attended') 
                                & (dataframe['APPT_MODE'] != 'Home Visit') 
                                & (dataframe['APPT_MODE'] != 'Face-to-Face') 
                                & (dataframe['APPT_MODE'] != 'Unknown') 
                                & (dataframe['TIME_BETWEEN_BOOK_AND_APPT'] !='More than 28 Days')
                                & (dataframe['TIME_BETWEEN_BOOK_AND_APPT'] !='Unknown / Data Issue')
                                ]

remote_dna_tmp = dataframe[(dataframe['APPT_STATUS'] == 'DNA') 
                                & (dataframe['APPT_MODE'] != 'Home Visit') 
                                & (dataframe['APPT_MODE'] != 'Face-to-Face') 
                                & (dataframe['APPT_MODE'] != 'Unknown') 
                                & (dataframe['TIME_BETWEEN_BOOK_AND_APPT'] !='More than 28 Days')
                                & (dataframe['TIME_BETWEEN_BOOK_AND_APPT'] !='Unknown / Data Issue')
                                ]['COUNT_OF_APPOINTMENTS']

f2f_attended_tmp = dataframe[(dataframe['APPT_STATUS'] == 'Attended') 
                            & (dataframe['APPT_MODE'] == 'Face-to-Face')
                            & (dataframe['TIME_BETWEEN_BOOK_AND_APPT'] !='More than 28 Days')
                            & (dataframe['TIME_BETWEEN_BOOK_AND_APPT'] !='Unknown / Data Issue')                    
                            ]['COUNT_OF_APPOINTMENTS']

f2f_dna_tmp = dataframe[(dataframe['APPT_STATUS'] == 'DNA') 
                        & (dataframe['APPT_MODE'] == 'Face-to-Face') 
                        & (dataframe['TIME_BETWEEN_BOOK_AND_APPT'] !='More than 28 Days')
                        & (dataframe['TIME_BETWEEN_BOOK_AND_APPT'] !='Unknown / Data Issue')
                        ]['COUNT_OF_APPOINTMENTS']


# drop na
remote_attended_tmp = remote_attended_tmp.dropna()
remote_dna_tmp = remote_dna_tmp.dropna()
f2f_attended_tmp = f2f_attended_tmp.dropna()
f2f_dna_tmp = f2f_attended_tmp.dropna()

#count, mean, max, min, 5th, 10th, 25th, 50th, 75th, 90th, 95th
print('-------------------------------------------------')
print('Data description of attended remote consultation in 2019/02:')
print(remote_attended_tmp[['CCG_NAME', 'Appointment_Date', 'COUNT_OF_APPOINTMENTS']]
      .describe(percentiles=[.05, .10, .25, .50, .75, .90, .95]))
print('-------------------------------------------------')
print('Minimum:')
print(remote_attended_tmp[['CCG_NAME', 'Appointment_Date', 'COUNT_OF_APPOINTMENTS']].min())
print('-------------------------------------------------')
print('Maximum:')
print(remote_attended_tmp[['CCG_NAME', 'Appointment_Date', 'COUNT_OF_APPOINTMENTS']].max())
print('-------------------------------------------------')
# Out:
# -------------------------------------------------
# Data description of attended remote consultation in 2019/02:
#        COUNT_OF_APPOINTMENTS
# count           55500.000000
# mean               56.616631
# std               157.111679
# min                 1.000000
# 5%                  1.000000
# 10%                 1.000000
# 25%                 3.000000
# 50%                10.000000
# 75%                39.000000
# 90%               134.000000
# 95%               267.000000
# max              3789.000000
# -------------------------------------------------
# Minimum:
# CCG_NAME                 NHS Airedale Wharfedale and Craven CCG
# Appointment_Date                                      01FEB2019
# COUNT_OF_APPOINTMENTS                                         1
# dtype: object
# -------------------------------------------------
# Maximum:
# CCG_NAME                 NHS Wyre Forest CCG
# Appointment_Date                   28FEB2019
# COUNT_OF_APPOINTMENTS                   3789
# ...

# %% [markdown]
# # Month/Year: 03/2019
#
# Exclusion:
#
#             1. Home Visit & Unknown
#             2. More than 28 Days & Unknown / Data Issue

# %%
csv_name = 'CCG_CSV_Mar_19.csv'
file_path = folder_path + csv_name
dataframe = pd.read_csv(file_path)
dataframe.drop('CCG_CODE', axis=1, inplace=True)
dataframe.drop('CCG_ONS_CODE', axis=1, inplace=True)
dataframe.drop('STP_CODE', axis=1, inplace=True)
dataframe.drop('HCP_TYPE', axis=1, inplace=True)
dataframe.drop('REGION_ONS_CODE', axis=1, inplace=True)

# %% [markdown]
# ## Data filtering & Analysis

# %%
# dna: did not attend
# f2f: face-to-face
# remote: Video Conference/Online & Telephone

remote_attended_tmp = dataframe[(dataframe['APPT_STATUS'] == 'Attended') 
                                & (dataframe['APPT_MODE'] != 'Home Visit') 
                                & (dataframe['APPT_MODE'] != 'Face-to-Face') 
                                & (dataframe['APPT_MODE'] != 'Unknown') 
                                & (dataframe['TIME_BETWEEN_BOOK_AND_APPT'] !='More than 28 Days')
                                & (dataframe['TIME_BETWEEN_BOOK_AND_APPT'] !='Unknown / Data Issue')
                                ]

remote_dna_tmp = dataframe[(dataframe['APPT_STATUS'] == 'DNA') 
                                & (dataframe['APPT_MODE'] != 'Home Visit') 
                                & (dataframe['APPT_MODE'] != 'Face-to-Face') 
                                & (dataframe['APPT_MODE'] != 'Unknown') 
                                & (dataframe['TIME_BETWEEN_BOOK_AND_APPT'] !='More than 28 Days')
                                & (dataframe['TIME_BETWEEN_BOOK_AND_APPT'] !='Unknown / Data Issue')
                                ]['COUNT_OF_APPOINTMENTS']

f2f_attended_tmp = dataframe[(dataframe['APPT_STATUS'] == 'Attended') 
                            & (dataframe['APPT_MODE'] == 'Face-to-Face')
                            & (dataframe['TIME_BETWEEN_BOOK_AND_APPT'] !='More than 28 Days')
                            & (dataframe['TIME_BETWEEN_BOOK_AND_APPT'] !='Unknown / Data Issue')                    
                            ]['COUNT_OF_APPOINTMENTS']

f2f_dna_tmp = dataframe[(dataframe['APPT_STATUS'] == 'DNA') 
                        & (dataframe['APPT_MODE'] == 'Face-to-Face') 
                        & (dataframe['TIME_BETWEEN_BOOK_AND_APPT'] !='More than 28 Days')
                        & (dataframe['TIME_BETWEEN_BOOK_AND_APPT'] !='Unknown / Data Issue')
                        ]['COUNT_OF_APPOINTMENTS']


# drop na
remote_attended_tmp = remote_attended_tmp.dropna()
remote_dna_tmp = remote_dna_tmp.dropna()
f2f_attended_tmp = f2f_attended_tmp.dropna()
f2f_dna_tmp = f2f_attended_tmp.dropna()

#count, mean, max, min, 5th, 10th, 25th, 50th, 75th, 90th, 95th
print('-------------------------------------------------')
print('Data description of attended remote consultation in 2019/03:')
print(remote_attended_tmp[['CCG_NAME', 'Appointment_Date', 'COUNT_OF_APPOINTMENTS']]
      .describe(percentiles=[.05, .10, .25, .50, .75, .90, .95]))
print('-------------------------------------------------')
print('Minimum:')
print(remote_attended_tmp[['CCG_NAME', 'Appointment_Date', 'COUNT_OF_APPOINTMENTS']].min())
print('-------------------------------------------------')
print('Maximum:')
print(remote_attended_tmp[['CCG_NAME', 'Appointment_Date', 'COUNT_OF_APPOINTMENTS']].max())
print('-------------------------------------------------')
# Out:
# -------------------------------------------------
# Data description of attended remote consultation in 2019/03:
#        COUNT_OF_APPOINTMENTS
# count           59129.000000
# mean               56.118351
# std               154.611418
# min                 1.000000
# 5%                  1.000000
# 10%                 1.000000
# 25%                 3.000000
# 50%                10.000000
# 75%                40.000000
# 90%               132.000000
# 95%               264.000000
# max              3613.000000
# -------------------------------------------------
# Minimum:
# CCG_NAME                 NHS Airedale Wharfedale and Craven CCG
# Appointment_Date                                      01MAR2019
# COUNT_OF_APPOINTMENTS                                         1
# dtype: object
# -------------------------------------------------
# Maximum:
# CCG_NAME                 NHS Wyre Forest CCG
# Appointment_Date                   31MAR2019
# COUNT_OF_APPOINTMENTS                   3613
# ...

# %% [markdown]
# # Month/Year: 04/2019
#
# Exclusion:
#
#             1. Home Visit & Unknown
#             2. More than 28 Days & Unknown / Data Issue

# %%
csv_name = 'CCG_CSV_Apr_19.csv'
file_path = folder_path + csv_name
dataframe = pd.read_csv(file_path)
dataframe.drop('CCG_CODE', axis=1, inplace=True)
dataframe.drop('CCG_ONS_CODE', axis=1, inplace=True)
dataframe.drop('STP_CODE', axis=1, inplace=True)
dataframe.drop('HCP_TYPE', axis=1, inplace=True)
dataframe.drop('REGION_ONS_CODE', axis=1, inplace=True)
print(dataframe.shape)
# Out:
# (382032, 7)

# %% [markdown]
# ## Data filtering & Analysis

# %%
# dna: did not attend
# f2f: face-to-face
# remote: Video Conference/Online & Telephone

remote_attended_tmp = dataframe[(dataframe['APPT_STATUS'] == 'Attended') 
                                & (dataframe['APPT_MODE'] != 'Home Visit') 
                                & (dataframe['APPT_MODE'] != 'Face-to-Face') 
                                & (dataframe['APPT_MODE'] != 'Unknown') 
                                & (dataframe['TIME_BETWEEN_BOOK_AND_APPT'] !='More than 28 Days')
                                & (dataframe['TIME_BETWEEN_BOOK_AND_APPT'] !='Unknown / Data Issue')
                                ]

remote_dna_tmp = dataframe[(dataframe['APPT_STATUS'] == 'DNA') 
                                & (dataframe['APPT_MODE'] != 'Home Visit') 
                                & (dataframe['APPT_MODE'] != 'Face-to-Face') 
                                & (dataframe['APPT_MODE'] != 'Unknown') 
                                & (dataframe['TIME_BETWEEN_BOOK_AND_APPT'] !='More than 28 Days')
                                & (dataframe['TIME_BETWEEN_BOOK_AND_APPT'] !='Unknown / Data Issue')
                                ]['COUNT_OF_APPOINTMENTS']

f2f_attended_tmp = dataframe[(dataframe['APPT_STATUS'] == 'Attended') 
                            & (dataframe['APPT_MODE'] == 'Face-to-Face')
                            & (dataframe['TIME_BETWEEN_BOOK_AND_APPT'] !='More than 28 Days')
                            & (dataframe['TIME_BETWEEN_BOOK_AND_APPT'] !='Unknown / Data Issue')                    
                            ]['COUNT_OF_APPOINTMENTS']

f2f_dna_tmp = dataframe[(dataframe['APPT_STATUS'] == 'DNA') 
                        & (dataframe['APPT_MODE'] == 'Face-to-Face') 
                        & (dataframe['TIME_BETWEEN_BOOK_AND_APPT'] !='More than 28 Days')
                        & (dataframe['TIME_BETWEEN_BOOK_AND_APPT'] !='Unknown / Data Issue')
                        ]['COUNT_OF_APPOINTMENTS']


# drop na
remote_attended_tmp = remote_attended_tmp.dropna()
remote_dna_tmp = remote_dna_tmp.dropna()
f2f_attended_tmp = f2f_attended_tmp.dropna()
f2f_dna_tmp = f2f_attended_tmp.dropna()

#count, mean, max, min, 5th, 10th, 25th, 50th, 75th, 90th, 95th
print('-------------------------------------------------')
print('Data description of attended remote consultation in 2019/04:')
print(remote_attended_tmp[['CCG_NAME', 'Appointment_Date', 'COUNT_OF_APPOINTMENTS']]
      .describe(percentiles=[.05, .10, .25, .50, .75, .90, .95]))
print('-------------------------------------------------')
print('Minimum:')
print(remote_attended_tmp[['CCG_NAME', 'Appointment_Date', 'COUNT_OF_APPOINTMENTS']].min())
print('-------------------------------------------------')
print('Maximum:')
print(remote_attended_tmp[['CCG_NAME', 'Appointment_Date', 'COUNT_OF_APPOINTMENTS']].max())
print('-------------------------------------------------')
# Out:
# -------------------------------------------------
# Data description of attended remote consultation in 2019/04:
#        COUNT_OF_APPOINTMENTS
# count           55667.000000
# mean               56.083119
# std               155.604613
# min                 1.000000
# 5%                  1.000000
# 10%                 1.000000
# 25%                 3.000000
# 50%                10.000000
# 75%                39.000000
# 90%               130.000000
# 95%               263.000000
# max              3648.000000
# -------------------------------------------------
# Minimum:
# CCG_NAME                 NHS Airedale Wharfedale and Craven CCG
# Appointment_Date                                      01APR2019
# COUNT_OF_APPOINTMENTS                                         1
# dtype: object
# -------------------------------------------------
# Maximum:
# CCG_NAME                 NHS Wyre Forest CCG
# Appointment_Date                   30APR2019
# COUNT_OF_APPOINTMENTS                   3648
# ...

# %% [markdown]
# # Month/Year: 05/2019
#
# Exclusion:
#
#             1. Home Visit & Unknown
#             2. More than 28 Days & Unknown / Data Issue

# %%
csv_name = 'CCG_CSV_May_19.csv'
file_path = folder_path + csv_name
dataframe = pd.read_csv(file_path)
dataframe.drop('CCG_CODE', axis=1, inplace=True)
dataframe.drop('CCG_ONS_CODE', axis=1, inplace=True)
dataframe.drop('STP_CODE', axis=1, inplace=True)
dataframe.drop('HCP_TYPE', axis=1, inplace=True)
dataframe.drop('REGION_ONS_CODE', axis=1, inplace=True)

# %% [markdown]
# ## Data filtering & Analysis

# %%
# dna: did not attend
# f2f: face-to-face
# remote: Video Conference/Online & Telephone

remote_attended_tmp = dataframe[(dataframe['APPT_STATUS'] == 'Attended') 
                                & (dataframe['APPT_MODE'] != 'Home Visit') 
                                & (dataframe['APPT_MODE'] != 'Face-to-Face') 
                                & (dataframe['APPT_MODE'] != 'Unknown') 
                                & (dataframe['TIME_BETWEEN_BOOK_AND_APPT'] !='More than 28 Days')
                                & (dataframe['TIME_BETWEEN_BOOK_AND_APPT'] !='Unknown / Data Issue')
                                ]

remote_dna_tmp = dataframe[(dataframe['APPT_STATUS'] == 'DNA') 
                                & (dataframe['APPT_MODE'] != 'Home Visit') 
                                & (dataframe['APPT_MODE'] != 'Face-to-Face') 
                                & (dataframe['APPT_MODE'] != 'Unknown') 
                                & (dataframe['TIME_BETWEEN_BOOK_AND_APPT'] !='More than 28 Days')
                                & (dataframe['TIME_BETWEEN_BOOK_AND_APPT'] !='Unknown / Data Issue')
                                ]['COUNT_OF_APPOINTMENTS']

f2f_attended_tmp = dataframe[(dataframe['APPT_STATUS'] == 'Attended') 
                            & (dataframe['APPT_MODE'] == 'Face-to-Face')
                            & (dataframe['TIME_BETWEEN_BOOK_AND_APPT'] !='More than 28 Days')
                            & (dataframe['TIME_BETWEEN_BOOK_AND_APPT'] !='Unknown / Data Issue')                    
                            ]['COUNT_OF_APPOINTMENTS']

f2f_dna_tmp = dataframe[(dataframe['APPT_STATUS'] == 'DNA') 
                        & (dataframe['APPT_MODE'] == 'Face-to-Face') 
                        & (dataframe['TIME_BETWEEN_BOOK_AND_APPT'] !='More than 28 Days')
                        & (dataframe['TIME_BETWEEN_BOOK_AND_APPT'] !='Unknown / Data Issue')
                        ]['COUNT_OF_APPOINTMENTS']


# drop na
remote_attended_tmp = remote_attended_tmp.dropna()
remote_dna_tmp = remote_dna_tmp.dropna()
f2f_attended_tmp = f2f_attended_tmp.dropna()
f2f_dna_tmp = f2f_attended_tmp.dropna()

#count, mean, max, min, 5th, 10th, 25th, 50th, 75th, 90th, 95th
print('-------------------------------------------------')
print('Data description of attended remote consultation in 2019/05:')
print(remote_attended_tmp[['CCG_NAME', 'Appointment_Date', 'COUNT_OF_APPOINTMENTS']]
      .describe(percentiles=[.05, .10, .25, .50, .75, .90, .95]))
print('-------------------------------------------------')
print('Minimum:')
print(remote_attended_tmp[['CCG_NAME', 'Appointment_Date', 'COUNT_OF_APPOINTMENTS']].min())
print('-------------------------------------------------')
print('Maximum:')
print(remote_attended_tmp[['CCG_NAME', 'Appointment_Date', 'COUNT_OF_APPOINTMENTS']].max())
print('-------------------------------------------------')
# Out:
# -------------------------------------------------
# Data description of attended remote consultation in 2019/05:
#        COUNT_OF_APPOINTMENTS
# count           58996.000000
# mean               54.228863
# std               147.583934
# min                 1.000000
# 5%                  1.000000
# 10%                 1.000000
# 25%                 3.000000
# 50%                10.000000
# 75%                40.000000
# 90%               127.000000
# 95%               250.000000
# max              3191.000000
# -------------------------------------------------
# Minimum:
# CCG_NAME                 NHS Airedale Wharfedale and Craven CCG
# Appointment_Date                                      01MAY2019
# COUNT_OF_APPOINTMENTS                                         1
# dtype: object
# -------------------------------------------------
# Maximum:
# CCG_NAME                 NHS Wyre Forest CCG
# Appointment_Date                   31MAY2019
# COUNT_OF_APPOINTMENTS                   3191
# ...

# %% [markdown]
# # Month/Year: 06/2019
#
# Exclusion:
#
#             1. Home Visit & Unknown
#             2. More than 28 Days & Unknown / Data Issue

# %%
csv_name = 'CCG_CSV_Jun_19.csv'
file_path = folder_path + csv_name
dataframe = pd.read_csv(file_path)
dataframe.drop('CCG_CODE', axis=1, inplace=True)
dataframe.drop('CCG_ONS_CODE', axis=1, inplace=True)
dataframe.drop('STP_CODE', axis=1, inplace=True)
dataframe.drop('HCP_TYPE', axis=1, inplace=True)
dataframe.drop('REGION_ONS_CODE', axis=1, inplace=True)

# %% [markdown]
# ## Data filtering & Analysis

# %%
# dna: did not attend
# f2f: face-to-face
# remote: Video Conference/Online & Telephone

remote_attended_tmp = dataframe[(dataframe['APPT_STATUS'] == 'Attended') 
                                & (dataframe['APPT_MODE'] != 'Home Visit') 
                                & (dataframe['APPT_MODE'] != 'Face-to-Face') 
                                & (dataframe['APPT_MODE'] != 'Unknown') 
                                & (dataframe['TIME_BETWEEN_BOOK_AND_APPT'] !='More than 28 Days')
                                & (dataframe['TIME_BETWEEN_BOOK_AND_APPT'] !='Unknown / Data Issue')
                                ]

remote_dna_tmp = dataframe[(dataframe['APPT_STATUS'] == 'DNA') 
                                & (dataframe['APPT_MODE'] != 'Home Visit') 
                                & (dataframe['APPT_MODE'] != 'Face-to-Face') 
                                & (dataframe['APPT_MODE'] != 'Unknown') 
                                & (dataframe['TIME_BETWEEN_BOOK_AND_APPT'] !='More than 28 Days')
                                & (dataframe['TIME_BETWEEN_BOOK_AND_APPT'] !='Unknown / Data Issue')
                                ]['COUNT_OF_APPOINTMENTS']

f2f_attended_tmp = dataframe[(dataframe['APPT_STATUS'] == 'Attended') 
                            & (dataframe['APPT_MODE'] == 'Face-to-Face')
                            & (dataframe['TIME_BETWEEN_BOOK_AND_APPT'] !='More than 28 Days')
                            & (dataframe['TIME_BETWEEN_BOOK_AND_APPT'] !='Unknown / Data Issue')                    
                            ]['COUNT_OF_APPOINTMENTS']

f2f_dna_tmp = dataframe[(dataframe['APPT_STATUS'] == 'DNA') 
                        & (dataframe['APPT_MODE'] == 'Face-to-Face') 
                        & (dataframe['TIME_BETWEEN_BOOK_AND_APPT'] !='More than 28 Days')
                        & (dataframe['TIME_BETWEEN_BOOK_AND_APPT'] !='Unknown / Data Issue')
                        ]['COUNT_OF_APPOINTMENTS']


# drop na
remote_attended_tmp = remote_attended_tmp.dropna()
remote_dna_tmp = remote_dna_tmp.dropna()
f2f_attended_tmp = f2f_attended_tmp.dropna()
f2f_dna_tmp = f2f_attended_tmp.dropna()

#count, mean, max, min, 5th, 10th, 25th, 50th, 75th, 90th, 95th
print('-------------------------------------------------')
print('Data description of attended remote consultation in 2019/06:')
print(remote_attended_tmp[['CCG_NAME', 'Appointment_Date', 'COUNT_OF_APPOINTMENTS']]
      .describe(percentiles=[.05, .10, .25, .50, .75, .90, .95]))
print('-------------------------------------------------')
print('Minimum:')
print(remote_attended_tmp[['CCG_NAME', 'Appointment_Date', 'COUNT_OF_APPOINTMENTS']].min())
print('-------------------------------------------------')
print('Maximum:')
print(remote_attended_tmp[['CCG_NAME', 'Appointment_Date', 'COUNT_OF_APPOINTMENTS']].max())
print('-------------------------------------------------')
# Out:
# -------------------------------------------------
# Data description of attended remote consultation in 2019/06:
#        COUNT_OF_APPOINTMENTS
# count           57126.000000
# mean               52.335416
# std               142.692111
# min                 1.000000
# 5%                  1.000000
# 10%                 1.000000
# 25%                 3.000000
# 50%                10.000000
# 75%                38.000000
# 90%               124.000000
# 95%               241.000000
# max              3509.000000
# -------------------------------------------------
# Minimum:
# CCG_NAME                 NHS Airedale Wharfedale and Craven CCG
# Appointment_Date                                      01JUN2019
# COUNT_OF_APPOINTMENTS                                         1
# dtype: object
# -------------------------------------------------
# Maximum:
# CCG_NAME                 NHS Wyre Forest CCG
# Appointment_Date                   30JUN2019
# COUNT_OF_APPOINTMENTS                   3509
# ...

# %% [markdown]
# # Month/Year: 07/2019
#
# Exclusion:
#
#             1. Home Visit & Unknown
#             2. More than 28 Days & Unknown / Data Issue

# %%
csv_name = 'CCG_CSV_Jul_19.csv'
file_path = folder_path + csv_name
dataframe = pd.read_csv(file_path)
dataframe.drop('CCG_CODE', axis=1, inplace=True)
dataframe.drop('CCG_ONS_CODE', axis=1, inplace=True)
dataframe.drop('STP_CODE', axis=1, inplace=True)
dataframe.drop('HCP_TYPE', axis=1, inplace=True)
dataframe.drop('REGION_ONS_CODE', axis=1, inplace=True)
print(dataframe.shape)
# Out:
# (438111, 7)

# %% [markdown]
# ## Data filtering & Analysis

# %%
# dna: did not attend
# f2f: face-to-face
# remote: Video Conference/Online & Telephone

remote_attended_tmp = dataframe[(dataframe['APPT_STATUS'] == 'Attended') 
                                & (dataframe['APPT_MODE'] != 'Home Visit') 
                                & (dataframe['APPT_MODE'] != 'Face-to-Face') 
                                & (dataframe['APPT_MODE'] != 'Unknown') 
                                & (dataframe['TIME_BETWEEN_BOOK_AND_APPT'] !='More than 28 Days')
                                & (dataframe['TIME_BETWEEN_BOOK_AND_APPT'] !='Unknown / Data Issue')
                                ]

remote_dna_tmp = dataframe[(dataframe['APPT_STATUS'] == 'DNA') 
                                & (dataframe['APPT_MODE'] != 'Home Visit') 
                                & (dataframe['APPT_MODE'] != 'Face-to-Face') 
                                & (dataframe['APPT_MODE'] != 'Unknown') 
                                & (dataframe['TIME_BETWEEN_BOOK_AND_APPT'] !='More than 28 Days')
                                & (dataframe['TIME_BETWEEN_BOOK_AND_APPT'] !='Unknown / Data Issue')
                                ]['COUNT_OF_APPOINTMENTS']

f2f_attended_tmp = dataframe[(dataframe['APPT_STATUS'] == 'Attended') 
                            & (dataframe['APPT_MODE'] == 'Face-to-Face')
                            & (dataframe['TIME_BETWEEN_BOOK_AND_APPT'] !='More than 28 Days')
                            & (dataframe['TIME_BETWEEN_BOOK_AND_APPT'] !='Unknown / Data Issue')                    
                            ]['COUNT_OF_APPOINTMENTS']

f2f_dna_tmp = dataframe[(dataframe['APPT_STATUS'] == 'DNA') 
                        & (dataframe['APPT_MODE'] == 'Face-to-Face') 
                        & (dataframe['TIME_BETWEEN_BOOK_AND_APPT'] !='More than 28 Days')
                        & (dataframe['TIME_BETWEEN_BOOK_AND_APPT'] !='Unknown / Data Issue')
                        ]['COUNT_OF_APPOINTMENTS']


# drop na
remote_attended_tmp = remote_attended_tmp.dropna()
remote_dna_tmp = remote_dna_tmp.dropna()
f2f_attended_tmp = f2f_attended_tmp.dropna()
f2f_dna_tmp = f2f_attended_tmp.dropna()

#count, mean, max, min, 5th, 10th, 25th, 50th, 75th, 90th, 95th
print('-------------------------------------------------')
print('Data description of attended remote consultation in 2019/07:')
print(remote_attended_tmp[['CCG_NAME', 'Appointment_Date', 'COUNT_OF_APPOINTMENTS']]
      .describe(percentiles=[.05, .10, .25, .50, .75, .90, .95]))
print('-------------------------------------------------')
print('Minimum:')
print(remote_attended_tmp[['CCG_NAME', 'Appointment_Date', 'COUNT_OF_APPOINTMENTS']].min())
print('-------------------------------------------------')
print('Maximum:')
print(remote_attended_tmp[['CCG_NAME', 'Appointment_Date', 'COUNT_OF_APPOINTMENTS']].max())
print('-------------------------------------------------')
# Out:
# -------------------------------------------------
# Data description of attended remote consultation in 2019/07:
#        COUNT_OF_APPOINTMENTS
# count           66712.000000
# mean               51.605678
# std               140.844525
# min                 1.000000
# 5%                  1.000000
# 10%                 1.000000
# 25%                 3.000000
# 50%                10.000000
# 75%                37.000000
# 90%               121.000000
# 95%               235.000000
# max              3449.000000
# -------------------------------------------------
# Minimum:
# CCG_NAME                 NHS Airedale Wharfedale and Craven CCG
# Appointment_Date                                      01JUL2019
# COUNT_OF_APPOINTMENTS                                         1
# dtype: object
# -------------------------------------------------
# Maximum:
# CCG_NAME                 NHS Wyre Forest CCG
# Appointment_Date                   31JUL2019
# COUNT_OF_APPOINTMENTS                   3449
# ...

# %% [markdown]
# # Month/Year: 08/2019
#
# Exclusion:
#
#             1. Home Visit & Unknown
#             2. More than 28 Days & Unknown / Data Issue

# %%
csv_name = 'CCG_CSV_Aug_19.csv'
file_path = folder_path + csv_name
dataframe = pd.read_csv(file_path)
dataframe.drop('CCG_CODE', axis=1, inplace=True)
dataframe.drop('CCG_ONS_CODE', axis=1, inplace=True)
dataframe.drop('STP_ONS_CODE', axis=1, inplace=True)
dataframe.drop('HCP_TYPE', axis=1, inplace=True)
dataframe.drop('REGION_ONS_CODE', axis=1, inplace=True)

# %% [markdown]
# ## Data filtering & Analysis

# %%
# dna: did not attend
# f2f: face-to-face
# remote: Video Conference/Online & Telephone

remote_attended_tmp = dataframe[(dataframe['APPT_STATUS'] == 'Attended') 
                                & (dataframe['APPT_MODE'] != 'Home Visit') 
                                & (dataframe['APPT_MODE'] != 'Face-to-Face') 
                                & (dataframe['APPT_MODE'] != 'Unknown') 
                                & (dataframe['TIME_BETWEEN_BOOK_AND_APPT'] !='More than 28 Days')
                                & (dataframe['TIME_BETWEEN_BOOK_AND_APPT'] !='Unknown / Data Issue')
                                ]

remote_dna_tmp = dataframe[(dataframe['APPT_STATUS'] == 'DNA') 
                                & (dataframe['APPT_MODE'] != 'Home Visit') 
                                & (dataframe['APPT_MODE'] != 'Face-to-Face') 
                                & (dataframe['APPT_MODE'] != 'Unknown') 
                                & (dataframe['TIME_BETWEEN_BOOK_AND_APPT'] !='More than 28 Days')
                                & (dataframe['TIME_BETWEEN_BOOK_AND_APPT'] !='Unknown / Data Issue')
                                ]['COUNT_OF_APPOINTMENTS']

f2f_attended_tmp = dataframe[(dataframe['APPT_STATUS'] == 'Attended') 
                            & (dataframe['APPT_MODE'] == 'Face-to-Face')
                            & (dataframe['TIME_BETWEEN_BOOK_AND_APPT'] !='More than 28 Days')
                            & (dataframe['TIME_BETWEEN_BOOK_AND_APPT'] !='Unknown / Data Issue')                    
                            ]['COUNT_OF_APPOINTMENTS']

f2f_dna_tmp = dataframe[(dataframe['APPT_STATUS'] == 'DNA') 
                        & (dataframe['APPT_MODE'] == 'Face-to-Face') 
                        & (dataframe['TIME_BETWEEN_BOOK_AND_APPT'] !='More than 28 Days')
                        & (dataframe['TIME_BETWEEN_BOOK_AND_APPT'] !='Unknown / Data Issue')
                        ]['COUNT_OF_APPOINTMENTS']


# drop na
remote_attended_tmp = remote_attended_tmp.dropna()
remote_dna_tmp = remote_dna_tmp.dropna()
f2f_attended_tmp = f2f_attended_tmp.dropna()
f2f_dna_tmp = f2f_attended_tmp.dropna()

#count, mean, max, min, 5th, 10th, 25th, 50th, 75th, 90th, 95th
print('-------------------------------------------------')
print('Data description of attended remote consultation in 2019/08:')
print(remote_attended_tmp[['CCG_NAME', 'Appointment_Date', 'COUNT_OF_APPOINTMENTS']]
      .describe(percentiles=[.05, .10, .25, .50, .75, .90, .95]))
print('-------------------------------------------------')
print('Minimum:')
print(remote_attended_tmp[['CCG_NAME', 'Appointment_Date', 'COUNT_OF_APPOINTMENTS']].min())
print('-------------------------------------------------')
print('Maximum:')
print(remote_attended_tmp[['CCG_NAME', 'Appointment_Date', 'COUNT_OF_APPOINTMENTS']].max())
print('-------------------------------------------------')
# Out:
# -------------------------------------------------
# Data description of attended remote consultation in 2019/08:
#        COUNT_OF_APPOINTMENTS
# count           40067.000000
# mean               75.191155
# std               223.012535
# min                 1.000000
# 5%                  1.000000
# 10%                 1.000000
# 25%                 4.000000
# 50%                12.000000
# 75%                44.000000
# 90%               158.000000
# 95%               345.000000
# max              3114.000000
# -------------------------------------------------
# Minimum:
# CCG_NAME                 NHS Barnsley CCG
# Appointment_Date                01AUG2019
# COUNT_OF_APPOINTMENTS                   1
# dtype: object
# -------------------------------------------------
# Maximum:
# CCG_NAME                 NHS Wirral CCG
# Appointment_Date              31AUG2019
# COUNT_OF_APPOINTMENTS              3114
# dtype: object
# -------------------------------------------------

# %% [markdown]
# # Month/Year: 09/2019
#
# Exclusion:
#
#             1. Home Visit & Unknown
#             2. More than 28 Days & Unknown / Data Issue

# %%
csv_name = 'CCG_CSV_Sep_19.csv'
file_path = folder_path + csv_name
dataframe = pd.read_csv(file_path)
dataframe.drop('CCG_CODE', axis=1, inplace=True)
dataframe.drop('CCG_ONS_CODE', axis=1, inplace=True)
dataframe.drop('STP_ONS_CODE', axis=1, inplace=True)
dataframe.drop('HCP_TYPE', axis=1, inplace=True)
dataframe.drop('REGION_ONS_CODE', axis=1, inplace=True)
print(dataframe.shape)
# Out:
# (282244, 6)

# %% [markdown]
# ## Data filtering & Analysis

# %%
# dna: did not attend
# f2f: face-to-face
# remote: Video Conference/Online & Telephone

remote_attended_tmp = dataframe[(dataframe['APPT_STATUS'] == 'Attended') 
                                & (dataframe['APPT_MODE'] != 'Home Visit') 
                                & (dataframe['APPT_MODE'] != 'Face-to-Face') 
                                & (dataframe['APPT_MODE'] != 'Unknown') 
                                & (dataframe['TIME_BETWEEN_BOOK_AND_APPT'] !='More than 28 Days')
                                & (dataframe['TIME_BETWEEN_BOOK_AND_APPT'] !='Unknown / Data Issue')
                                ]

remote_dna_tmp = dataframe[(dataframe['APPT_STATUS'] == 'DNA') 
                                & (dataframe['APPT_MODE'] != 'Home Visit') 
                                & (dataframe['APPT_MODE'] != 'Face-to-Face') 
                                & (dataframe['APPT_MODE'] != 'Unknown') 
                                & (dataframe['TIME_BETWEEN_BOOK_AND_APPT'] !='More than 28 Days')
                                & (dataframe['TIME_BETWEEN_BOOK_AND_APPT'] !='Unknown / Data Issue')
                                ]['COUNT_OF_APPOINTMENTS']

f2f_attended_tmp = dataframe[(dataframe['APPT_STATUS'] == 'Attended') 
                            & (dataframe['APPT_MODE'] == 'Face-to-Face')
                            & (dataframe['TIME_BETWEEN_BOOK_AND_APPT'] !='More than 28 Days')
                            & (dataframe['TIME_BETWEEN_BOOK_AND_APPT'] !='Unknown / Data Issue')                    
                            ]['COUNT_OF_APPOINTMENTS']

f2f_dna_tmp = dataframe[(dataframe['APPT_STATUS'] == 'DNA') 
                        & (dataframe['APPT_MODE'] == 'Face-to-Face') 
                        & (dataframe['TIME_BETWEEN_BOOK_AND_APPT'] !='More than 28 Days')
                        & (dataframe['TIME_BETWEEN_BOOK_AND_APPT'] !='Unknown / Data Issue')
                        ]['COUNT_OF_APPOINTMENTS']


# drop na
remote_attended_tmp = remote_attended_tmp.dropna()
remote_dna_tmp = remote_dna_tmp.dropna()
f2f_attended_tmp = f2f_attended_tmp.dropna()
f2f_dna_tmp = f2f_attended_tmp.dropna()

#count, mean, max, min, 5th, 10th, 25th, 50th, 75th, 90th, 95th
print('-------------------------------------------------')
print('Data description of attended remote consultation in 2019/09:')
print(remote_attended_tmp[['CCG_NAME', 'Appointment_Date', 'COUNT_OF_APPOINTMENTS']]
      .describe(percentiles=[.05, .10, .25, .50, .75, .90, .95]))
print('-------------------------------------------------')
print('Minimum:')
print(remote_attended_tmp[['CCG_NAME', 'Appointment_Date', 'COUNT_OF_APPOINTMENTS']].min())
print('-------------------------------------------------')
print('Maximum:')
print(remote_attended_tmp[['CCG_NAME', 'Appointment_Date', 'COUNT_OF_APPOINTMENTS']].max())
print('-------------------------------------------------')
# Out:
# -------------------------------------------------
# Data description of attended remote consultation in 2019/09:
#        COUNT_OF_APPOINTMENTS
# count           40137.000000
# mean               79.391285
# std               234.253578
# min                 1.000000
# 5%                  1.000000
# 10%                 1.000000
# 25%                 4.000000
# 50%                13.000000
# 75%                47.000000
# 90%               167.400000
# 95%               370.200000
# max              3328.000000
# -------------------------------------------------
# Minimum:
# CCG_NAME                 NHS Barnsley CCG
# Appointment_Date                01SEP2019
# COUNT_OF_APPOINTMENTS                   1
# dtype: object
# -------------------------------------------------
# Maximum:
# CCG_NAME                 NHS Wirral CCG
# Appointment_Date              30SEP2019
# COUNT_OF_APPOINTMENTS              3328
# dtype: object
# -------------------------------------------------

# %% [markdown]
# # Month/Year: 10/2019
#
# Exclusion:
#
#             1. Home Visit & Unknown
#             2. More than 28 Days & Unknown / Data Issue

# %%
csv_name = 'CCG_CSV_Oct_19.csv'
file_path = folder_path + csv_name
dataframe = pd.read_csv(file_path)
dataframe.drop('CCG_CODE', axis=1, inplace=True)
dataframe.drop('CCG_ONS_CODE', axis=1, inplace=True)
dataframe.drop('STP_ONS_CODE', axis=1, inplace=True)
dataframe.drop('HCP_TYPE', axis=1, inplace=True)
dataframe.drop('REGION_ONS_CODE', axis=1, inplace=True)

# %% [markdown]
# ## Data filtering & Analysis

# %%
# dna: did not attend
# f2f: face-to-face
# remote: Video Conference/Online & Telephone

remote_attended_tmp = dataframe[(dataframe['APPT_STATUS'] == 'Attended') 
                                & (dataframe['APPT_MODE'] != 'Home Visit') 
                                & (dataframe['APPT_MODE'] != 'Face-to-Face') 
                                & (dataframe['APPT_MODE'] != 'Unknown') 
                                & (dataframe['TIME_BETWEEN_BOOK_AND_APPT'] !='More than 28 Days')
                                & (dataframe['TIME_BETWEEN_BOOK_AND_APPT'] !='Unknown / Data Issue')
                                ]

remote_dna_tmp = dataframe[(dataframe['APPT_STATUS'] == 'DNA') 
                                & (dataframe['APPT_MODE'] != 'Home Visit') 
                                & (dataframe['APPT_MODE'] != 'Face-to-Face') 
                                & (dataframe['APPT_MODE'] != 'Unknown') 
                                & (dataframe['TIME_BETWEEN_BOOK_AND_APPT'] !='More than 28 Days')
                                & (dataframe['TIME_BETWEEN_BOOK_AND_APPT'] !='Unknown / Data Issue')
                                ]['COUNT_OF_APPOINTMENTS']

f2f_attended_tmp = dataframe[(dataframe['APPT_STATUS'] == 'Attended') 
                            & (dataframe['APPT_MODE'] == 'Face-to-Face')
                            & (dataframe['TIME_BETWEEN_BOOK_AND_APPT'] !='More than 28 Days')
                            & (dataframe['TIME_BETWEEN_BOOK_AND_APPT'] !='Unknown / Data Issue')                    
                            ]['COUNT_OF_APPOINTMENTS']

f2f_dna_tmp = dataframe[(dataframe['APPT_STATUS'] == 'DNA') 
                        & (dataframe['APPT_MODE'] == 'Face-to-Face') 
                        & (dataframe['TIME_BETWEEN_BOOK_AND_APPT'] !='More than 28 Days')
                        & (dataframe['TIME_BETWEEN_BOOK_AND_APPT'] !='Unknown / Data Issue')
                        ]['COUNT_OF_APPOINTMENTS']


# drop na
remote_attended_tmp = remote_attended_tmp.dropna()
remote_dna_tmp = remote_dna_tmp.dropna()
f2f_attended_tmp = f2f_attended_tmp.dropna()
f2f_dna_tmp = f2f_attended_tmp.dropna()

#count, mean, max, min, 5th, 10th, 25th, 50th, 75th, 90th, 95th
print('-------------------------------------------------')
print('Data description of attended remote consultation in 2019/10:')
print(remote_attended_tmp[['CCG_NAME', 'Appointment_Date', 'COUNT_OF_APPOINTMENTS']]
      .describe(percentiles=[.05, .10, .25, .50, .75, .90, .95]))
print('-------------------------------------------------')
print('Minimum:')
print(remote_attended_tmp[['CCG_NAME', 'Appointment_Date', 'COUNT_OF_APPOINTMENTS']].min())
print('-------------------------------------------------')
print('Maximum:')
print(remote_attended_tmp[['CCG_NAME', 'Appointment_Date', 'COUNT_OF_APPOINTMENTS']].max())
print('-------------------------------------------------')
# Out:
# -------------------------------------------------
# Data description of attended remote consultation in 2019/10:
#        COUNT_OF_APPOINTMENTS
# count           44308.000000
# mean               79.667532
# std               233.784259
# min                 1.000000
# 5%                  1.000000
# 10%                 1.000000
# 25%                 4.000000
# 50%                13.000000
# 75%                48.000000
# 90%               172.000000
# 95%               371.000000
# max              3418.000000
# -------------------------------------------------
# Minimum:
# CCG_NAME                 NHS Barnsley CCG
# Appointment_Date                01OCT2019
# COUNT_OF_APPOINTMENTS                   1
# dtype: object
# -------------------------------------------------
# Maximum:
# CCG_NAME                 NHS Wirral CCG
# Appointment_Date              31OCT2019
# COUNT_OF_APPOINTMENTS              3418
# dtype: object
# -------------------------------------------------

# %% [markdown]
# # Month/Year: 11/2019
#
# Exclusion:
#
#             1. Home Visit & Unknown
#             2. More than 28 Days & Unknown / Data Issue

# %%
csv_name = 'CCG_CSV_Nov_19.csv'
file_path = folder_path + csv_name
dataframe = pd.read_csv(file_path)
dataframe.drop('CCG_CODE', axis=1, inplace=True)
dataframe.drop('CCG_ONS_CODE', axis=1, inplace=True)
dataframe.drop('STP_ONS_CODE', axis=1, inplace=True)
dataframe.drop('HCP_TYPE', axis=1, inplace=True)
dataframe.drop('REGION_ONS_CODE', axis=1, inplace=True)

# %% [markdown]
# ## Data filtering & Analysis

# %%
# dna: did not attend
# f2f: face-to-face
# remote: Video Conference/Online & Telephone

remote_attended_tmp = dataframe[(dataframe['APPT_STATUS'] == 'Attended') 
                                & (dataframe['APPT_MODE'] != 'Home Visit') 
                                & (dataframe['APPT_MODE'] != 'Face-to-Face') 
                                & (dataframe['APPT_MODE'] != 'Unknown') 
                                & (dataframe['TIME_BETWEEN_BOOK_AND_APPT'] !='More than 28 Days')
                                & (dataframe['TIME_BETWEEN_BOOK_AND_APPT'] !='Unknown / Data Issue')
                                ]

remote_dna_tmp = dataframe[(dataframe['APPT_STATUS'] == 'DNA') 
                                & (dataframe['APPT_MODE'] != 'Home Visit') 
                                & (dataframe['APPT_MODE'] != 'Face-to-Face') 
                                & (dataframe['APPT_MODE'] != 'Unknown') 
                                & (dataframe['TIME_BETWEEN_BOOK_AND_APPT'] !='More than 28 Days')
                                & (dataframe['TIME_BETWEEN_BOOK_AND_APPT'] !='Unknown / Data Issue')
                                ]['COUNT_OF_APPOINTMENTS']

f2f_attended_tmp = dataframe[(dataframe['APPT_STATUS'] == 'Attended') 
                            & (dataframe['APPT_MODE'] == 'Face-to-Face')
                            & (dataframe['TIME_BETWEEN_BOOK_AND_APPT'] !='More than 28 Days')
                            & (dataframe['TIME_BETWEEN_BOOK_AND_APPT'] !='Unknown / Data Issue')                    
                            ]['COUNT_OF_APPOINTMENTS']

f2f_dna_tmp = dataframe[(dataframe['APPT_STATUS'] == 'DNA') 
                        & (dataframe['APPT_MODE'] == 'Face-to-Face') 
                        & (dataframe['TIME_BETWEEN_BOOK_AND_APPT'] !='More than 28 Days')
                        & (dataframe['TIME_BETWEEN_BOOK_AND_APPT'] !='Unknown / Data Issue')
                        ]['COUNT_OF_APPOINTMENTS']


# drop na
remote_attended_tmp = remote_attended_tmp.dropna()
remote_dna_tmp = remote_dna_tmp.dropna()
f2f_attended_tmp = f2f_attended_tmp.dropna()
f2f_dna_tmp = f2f_attended_tmp.dropna()

#count, mean, max, min, 5th, 10th, 25th, 50th, 75th, 90th, 95th
print('-------------------------------------------------')
print('Data description of attended remote consultation in 2019/11:')
print(remote_attended_tmp[['CCG_NAME', 'Appointment_Date', 'COUNT_OF_APPOINTMENTS']]
      .describe(percentiles=[.05, .10, .25, .50, .75, .90, .95]))
print('-------------------------------------------------')
print('Minimum:')
print(remote_attended_tmp[['CCG_NAME', 'Appointment_Date', 'COUNT_OF_APPOINTMENTS']].min())
print('-------------------------------------------------')
print('Maximum:')
print(remote_attended_tmp[['CCG_NAME', 'Appointment_Date', 'COUNT_OF_APPOINTMENTS']].max())
print('-------------------------------------------------')
# Out:
# -------------------------------------------------
# Data description of attended remote consultation in 2019/11:
#        COUNT_OF_APPOINTMENTS
# count           40964.000000
# mean               81.666390
# std               242.753114
# min                 1.000000
# 5%                  1.000000
# 10%                 1.000000
# 25%                 4.000000
# 50%                13.000000
# 75%                48.000000
# 90%               172.000000
# 95%               376.000000
# max              3519.000000
# -------------------------------------------------
# Minimum:
# CCG_NAME                 NHS Barnsley CCG
# Appointment_Date                01NOV2019
# COUNT_OF_APPOINTMENTS                   1
# dtype: object
# -------------------------------------------------
# Maximum:
# CCG_NAME                 NHS Wirral CCG
# Appointment_Date              30NOV2019
# COUNT_OF_APPOINTMENTS              3519
# dtype: object
# -------------------------------------------------

# %% [markdown]
# # Month/Year: 12/2019
#
# Exclusion:
#
#             1. Home Visit & Unknown
#             2. More than 28 Days & Unknown / Data Issue

# %%
csv_name = 'CCG_CSV_Dec_19.csv'
file_path = folder_path + csv_name
dataframe = pd.read_csv(file_path)
dataframe.drop('CCG_CODE', axis=1, inplace=True)
dataframe.drop('CCG_ONS_CODE', axis=1, inplace=True)
dataframe.drop('STP_ONS_CODE', axis=1, inplace=True)
dataframe.drop('HCP_TYPE', axis=1, inplace=True)
dataframe.drop('REGION_ONS_CODE', axis=1, inplace=True)

# %% [markdown]
# ## Data filtering & Analysis

# %%
# dna: did not attend
# f2f: face-to-face
# remote: Video Conference/Online & Telephone

remote_attended_tmp = dataframe[(dataframe['APPT_STATUS'] == 'Attended') 
                                & (dataframe['APPT_MODE'] != 'Home Visit') 
                                & (dataframe['APPT_MODE'] != 'Face-to-Face') 
                                & (dataframe['APPT_MODE'] != 'Unknown') 
                                & (dataframe['TIME_BETWEEN_BOOK_AND_APPT'] !='More than 28 Days')
                                & (dataframe['TIME_BETWEEN_BOOK_AND_APPT'] !='Unknown / Data Issue')
                                ]

remote_dna_tmp = dataframe[(dataframe['APPT_STATUS'] == 'DNA') 
                                & (dataframe['APPT_MODE'] != 'Home Visit') 
                                & (dataframe['APPT_MODE'] != 'Face-to-Face') 
                                & (dataframe['APPT_MODE'] != 'Unknown') 
                                & (dataframe['TIME_BETWEEN_BOOK_AND_APPT'] !='More than 28 Days')
                                & (dataframe['TIME_BETWEEN_BOOK_AND_APPT'] !='Unknown / Data Issue')
                                ]['COUNT_OF_APPOINTMENTS']

f2f_attended_tmp = dataframe[(dataframe['APPT_STATUS'] == 'Attended') 
                            & (dataframe['APPT_MODE'] == 'Face-to-Face')
                            & (dataframe['TIME_BETWEEN_BOOK_AND_APPT'] !='More than 28 Days')
                            & (dataframe['TIME_BETWEEN_BOOK_AND_APPT'] !='Unknown / Data Issue')                    
                            ]['COUNT_OF_APPOINTMENTS']

f2f_dna_tmp = dataframe[(dataframe['APPT_STATUS'] == 'DNA') 
                        & (dataframe['APPT_MODE'] == 'Face-to-Face') 
                        & (dataframe['TIME_BETWEEN_BOOK_AND_APPT'] !='More than 28 Days')
                        & (dataframe['TIME_BETWEEN_BOOK_AND_APPT'] !='Unknown / Data Issue')
                        ]['COUNT_OF_APPOINTMENTS']


# drop na
remote_attended_tmp = remote_attended_tmp.dropna()
remote_dna_tmp = remote_dna_tmp.dropna()
f2f_attended_tmp = f2f_attended_tmp.dropna()
f2f_dna_tmp = f2f_attended_tmp.dropna()

#count, mean, max, min, 5th, 10th, 25th, 50th, 75th, 90th, 95th
print('-------------------------------------------------')
print('Data description of attended remote consultation in 2019/12:')
print(remote_attended_tmp[['CCG_NAME', 'Appointment_Date', 'COUNT_OF_APPOINTMENTS']]
      .describe(percentiles=[.05, .10, .25, .50, .75, .90, .95]))
print('-------------------------------------------------')
print('Minimum:')
print(remote_attended_tmp[['CCG_NAME', 'Appointment_Date', 'COUNT_OF_APPOINTMENTS']].min())
print('-------------------------------------------------')
print('Maximum:')
print(remote_attended_tmp[['CCG_NAME', 'Appointment_Date', 'COUNT_OF_APPOINTMENTS']].max())
print('-------------------------------------------------')
# Out:
# -------------------------------------------------
# Data description of attended remote consultation in 2019/12:
#        COUNT_OF_APPOINTMENTS
# count           38279.000000
# mean               82.660336
# std               250.401159
# min                 1.000000
# 5%                  1.000000
# 10%                 1.000000
# 25%                 4.000000
# 50%                13.000000
# 75%                47.000000
# 90%               173.000000
# 95%               379.000000
# max              3559.000000
# -------------------------------------------------
# Minimum:
# CCG_NAME                 NHS Barnsley CCG
# Appointment_Date                01DEC2019
# COUNT_OF_APPOINTMENTS                   1
# dtype: object
# -------------------------------------------------
# Maximum:
# CCG_NAME                 NHS Wirral CCG
# Appointment_Date              31DEC2019
# COUNT_OF_APPOINTMENTS              3559
# dtype: object
# -------------------------------------------------
