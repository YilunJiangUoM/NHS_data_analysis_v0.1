# %% [markdown]
# # Import packages

# %%
import csv
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.ticker import FuncFormatter
import seaborn as sns

folder_path = '/Users/yilunjiang/Documents/PhD_21_25_Manchester/research_plan_repeat_visit/published_data/Appointments_GP_Daily_Jan22/'

# %% [markdown]
# # Import CSV file
#
# # Month/Year: 01/2019
#
# Exclusion:
#
#             1. Home Visit & Unknown
#             2. More than 28 Days & Unknown / Data Issue

# %%
csv_name = 'CCG_CSV_Jan_19.csv'
file_path = folder_path + csv_name
dataframe = pd.read_csv(file_path)
dataframe.drop('CCG_CODE', axis=1, inplace=True)
dataframe.drop('CCG_ONS_CODE', axis=1, inplace=True)
dataframe.drop('STP_CODE', axis=1, inplace=True)
dataframe.drop('HCP_TYPE', axis=1, inplace=True)
dataframe.drop('REGION_ONS_CODE', axis=1, inplace=True)

# %% [markdown]
# ## Data filtering & Analysis

# %%
# dna: did not attend
# f2f: face-to-face
# remote: Video Conference/Online & Telephone

remote_attended_tmp = dataframe[(dataframe['APPT_STATUS'] == 'Attended') 
                                & (dataframe['APPT_MODE'] != 'Home Visit') 
                                & (dataframe['APPT_MODE'] != 'Face-to-Face') 
                                & (dataframe['APPT_MODE'] != 'Unknown') 
                                & (dataframe['TIME_BETWEEN_BOOK_AND_APPT'] !='More than 28 Days')
                                & (dataframe['TIME_BETWEEN_BOOK_AND_APPT'] !='Unknown / Data Issue')
                                ].groupby('CCG_NAME').sum().reset_index()

remote_dna_tmp = dataframe[(dataframe['APPT_STATUS'] == 'DNA') 
                                & (dataframe['APPT_MODE'] != 'Home Visit') 
                                & (dataframe['APPT_MODE'] != 'Face-to-Face') 
                                & (dataframe['APPT_MODE'] != 'Unknown') 
                                & (dataframe['TIME_BETWEEN_BOOK_AND_APPT'] !='More than 28 Days')
                                & (dataframe['TIME_BETWEEN_BOOK_AND_APPT'] !='Unknown / Data Issue')
                                ].groupby('CCG_NAME').sum().reset_index()

f2f_attended_tmp = dataframe[(dataframe['APPT_STATUS'] == 'Attended') 
                            & (dataframe['APPT_MODE'] == 'Face-to-Face')
                            & (dataframe['TIME_BETWEEN_BOOK_AND_APPT'] !='More than 28 Days')
                            & (dataframe['TIME_BETWEEN_BOOK_AND_APPT'] !='Unknown / Data Issue')                    
                            ].groupby('CCG_NAME').sum().reset_index()

f2f_dna_tmp = dataframe[(dataframe['APPT_STATUS'] == 'DNA') 
                        & (dataframe['APPT_MODE'] == 'Face-to-Face') 
                        & (dataframe['TIME_BETWEEN_BOOK_AND_APPT'] !='More than 28 Days')
                        & (dataframe['TIME_BETWEEN_BOOK_AND_APPT'] !='Unknown / Data Issue')
                        ].groupby('CCG_NAME').sum().reset_index()


# drop na
remote_attended_tmp = remote_attended_tmp.dropna()
remote_dna_tmp = remote_dna_tmp.dropna()
f2f_attended_tmp = f2f_attended_tmp.dropna()
f2f_dna_tmp = f2f_attended_tmp.dropna()

#count, mean, max, min, 5th, 10th, 25th, 50th, 75th, 90th, 95th
print('-------------------------------------------------')
print('Data description of attended remote consultation in 2019/01:')
print(remote_attended_tmp
      .describe(percentiles=[.05, .10, .25, .50, .75, .90, .95]))
print('-------------------------------------------------')
print('Minimum:')
print(remote_attended_tmp.min())
print('-------------------------------------------------')
print('Maximum:')
print(remote_attended_tmp.max())
print('-------------------------------------------------')
print('CCG number:' + str(len(remote_attended_tmp)))
# Out:
# -------------------------------------------------
# Data description of attended remote consultation in 2019/01:
#        COUNT_OF_APPOINTMENTS
# count             190.000000
# mean            18179.310526
# std             17204.525760
# min               447.000000
# 5%               4357.600000
# 10%              5647.900000
# 25%              8342.000000
# 50%             13054.500000
# 75%             22447.000000
# 90%             36000.200000
# 95%             50408.050000
# max            139339.000000
# -------------------------------------------------
# Minimum:
# CCG_NAME                 NHS Airedale Wharfedale and Craven CCG
# COUNT_OF_APPOINTMENTS                                       447
# dtype: object
# -------------------------------------------------
# Maximum:
# CCG_NAME                 NHS Wyre Forest CCG
# COUNT_OF_APPOINTMENTS                 139339
# dtype: object
# -------------------------------------------------
# CCG number:190

# %% [markdown]
# # Month/Year: 02/2019
#
# Exclusion:
#
#             1. Home Visit & Unknown
#             2. More than 28 Days & Unknown / Data Issue

# %%
csv_name = 'CCG_CSV_Feb_19.csv'
file_path = folder_path + csv_name
dataframe = pd.read_csv(file_path)
dataframe.drop('CCG_CODE', axis=1, inplace=True)
dataframe.drop('CCG_ONS_CODE', axis=1, inplace=True)
dataframe.drop('STP_CODE', axis=1, inplace=True)
dataframe.drop('HCP_TYPE', axis=1, inplace=True)
dataframe.drop('REGION_ONS_CODE', axis=1, inplace=True)

# %% [markdown]
# ## Data filtering & Analysis

# %%
# dna: did not attend
# f2f: face-to-face
# remote: Video Conference/Online & Telephone

remote_attended_tmp = dataframe[(dataframe['APPT_STATUS'] == 'Attended') 
                                & (dataframe['APPT_MODE'] != 'Home Visit') 
                                & (dataframe['APPT_MODE'] != 'Face-to-Face') 
                                & (dataframe['APPT_MODE'] != 'Unknown') 
                                & (dataframe['TIME_BETWEEN_BOOK_AND_APPT'] !='More than 28 Days')
                                & (dataframe['TIME_BETWEEN_BOOK_AND_APPT'] !='Unknown / Data Issue')
                                ].groupby('CCG_NAME').sum().reset_index()

remote_dna_tmp = dataframe[(dataframe['APPT_STATUS'] == 'DNA') 
                                & (dataframe['APPT_MODE'] != 'Home Visit') 
                                & (dataframe['APPT_MODE'] != 'Face-to-Face') 
                                & (dataframe['APPT_MODE'] != 'Unknown') 
                                & (dataframe['TIME_BETWEEN_BOOK_AND_APPT'] !='More than 28 Days')
                                & (dataframe['TIME_BETWEEN_BOOK_AND_APPT'] !='Unknown / Data Issue')
                                ].groupby('CCG_NAME').sum().reset_index()

f2f_attended_tmp = dataframe[(dataframe['APPT_STATUS'] == 'Attended') 
                            & (dataframe['APPT_MODE'] == 'Face-to-Face')
                            & (dataframe['TIME_BETWEEN_BOOK_AND_APPT'] !='More than 28 Days')
                            & (dataframe['TIME_BETWEEN_BOOK_AND_APPT'] !='Unknown / Data Issue')                    
                            ].groupby('CCG_NAME').sum().reset_index()

f2f_dna_tmp = dataframe[(dataframe['APPT_STATUS'] == 'DNA') 
                        & (dataframe['APPT_MODE'] == 'Face-to-Face') 
                        & (dataframe['TIME_BETWEEN_BOOK_AND_APPT'] !='More than 28 Days')
                        & (dataframe['TIME_BETWEEN_BOOK_AND_APPT'] !='Unknown / Data Issue')
                        ].groupby('CCG_NAME').sum().reset_index()


# drop na
remote_attended_tmp = remote_attended_tmp.dropna()
remote_dna_tmp = remote_dna_tmp.dropna()
f2f_attended_tmp = f2f_attended_tmp.dropna()
f2f_dna_tmp = f2f_attended_tmp.dropna()

#count, mean, max, min, 5th, 10th, 25th, 50th, 75th, 90th, 95th
print('-------------------------------------------------')
print('Data description of attended remote consultation in 2019/02:')
print(remote_attended_tmp
      .describe(percentiles=[.05, .10, .25, .50, .75, .90, .95]))
print('-------------------------------------------------')
print('Minimum:')
print(remote_attended_tmp.min())
print('-------------------------------------------------')
print('Maximum:')
print(remote_attended_tmp.max())
print('-------------------------------------------------')
print('CCG number:' + str(len(remote_attended_tmp)))
# Out:
# -------------------------------------------------
# Data description of attended remote consultation in 2019/02:
#        COUNT_OF_APPOINTMENTS
# count             190.000000
# mean            16538.015789
# std             15783.617895
# min               434.000000
# 5%               3632.800000
# 10%              5044.100000
# 25%              7628.250000
# 50%             11809.500000
# 75%             20027.000000
# 90%             34224.500000
# 95%             46058.300000
# max            129758.000000
# -------------------------------------------------
# Minimum:
# CCG_NAME                 NHS Airedale Wharfedale and Craven CCG
# COUNT_OF_APPOINTMENTS                                       434
# dtype: object
# -------------------------------------------------
# Maximum:
# CCG_NAME                 NHS Wyre Forest CCG
# COUNT_OF_APPOINTMENTS                 129758
# dtype: object
# -------------------------------------------------
# CCG number:190

# %% [markdown]
# # Month/Year: 03/2019
#
# Exclusion:
#
#             1. Home Visit & Unknown
#             2. More than 28 Days & Unknown / Data Issue

# %%
csv_name = 'CCG_CSV_Mar_19.csv'
file_path = folder_path + csv_name
dataframe = pd.read_csv(file_path)
dataframe.drop('CCG_CODE', axis=1, inplace=True)
dataframe.drop('CCG_ONS_CODE', axis=1, inplace=True)
dataframe.drop('STP_CODE', axis=1, inplace=True)
dataframe.drop('HCP_TYPE', axis=1, inplace=True)
dataframe.drop('REGION_ONS_CODE', axis=1, inplace=True)

# %% [markdown]
# ## Data filtering & Analysis

# %%
# dna: did not attend
# f2f: face-to-face
# remote: Video Conference/Online & Telephone

remote_attended_tmp = dataframe[(dataframe['APPT_STATUS'] == 'Attended') 
                                & (dataframe['APPT_MODE'] != 'Home Visit') 
                                & (dataframe['APPT_MODE'] != 'Face-to-Face') 
                                & (dataframe['APPT_MODE'] != 'Unknown') 
                                & (dataframe['TIME_BETWEEN_BOOK_AND_APPT'] !='More than 28 Days')
                                & (dataframe['TIME_BETWEEN_BOOK_AND_APPT'] !='Unknown / Data Issue')
                                ].groupby('CCG_NAME').sum().reset_index()

remote_dna_tmp = dataframe[(dataframe['APPT_STATUS'] == 'DNA') 
                                & (dataframe['APPT_MODE'] != 'Home Visit') 
                                & (dataframe['APPT_MODE'] != 'Face-to-Face') 
                                & (dataframe['APPT_MODE'] != 'Unknown') 
                                & (dataframe['TIME_BETWEEN_BOOK_AND_APPT'] !='More than 28 Days')
                                & (dataframe['TIME_BETWEEN_BOOK_AND_APPT'] !='Unknown / Data Issue')
                                ].groupby('CCG_NAME').sum().reset_index()

f2f_attended_tmp = dataframe[(dataframe['APPT_STATUS'] == 'Attended') 
                            & (dataframe['APPT_MODE'] == 'Face-to-Face')
                            & (dataframe['TIME_BETWEEN_BOOK_AND_APPT'] !='More than 28 Days')
                            & (dataframe['TIME_BETWEEN_BOOK_AND_APPT'] !='Unknown / Data Issue')                    
                            ].groupby('CCG_NAME').sum().reset_index()

f2f_dna_tmp = dataframe[(dataframe['APPT_STATUS'] == 'DNA') 
                        & (dataframe['APPT_MODE'] == 'Face-to-Face') 
                        & (dataframe['TIME_BETWEEN_BOOK_AND_APPT'] !='More than 28 Days')
                        & (dataframe['TIME_BETWEEN_BOOK_AND_APPT'] !='Unknown / Data Issue')
                        ].groupby('CCG_NAME').sum().reset_index()


# drop na
remote_attended_tmp = remote_attended_tmp.dropna()
remote_dna_tmp = remote_dna_tmp.dropna()
f2f_attended_tmp = f2f_attended_tmp.dropna()
f2f_dna_tmp = f2f_attended_tmp.dropna()

#count, mean, max, min, 5th, 10th, 25th, 50th, 75th, 90th, 95th
print('-------------------------------------------------')
print('Data description of attended remote consultation in 2019/03:')
print(remote_attended_tmp
      .describe(percentiles=[.05, .10, .25, .50, .75, .90, .95]))
print('-------------------------------------------------')
print('Minimum:')
print(remote_attended_tmp.min())
print('-------------------------------------------------')
print('Maximum:')
print(remote_attended_tmp.max())
print('-------------------------------------------------')
print('CCG number:' + str(len(remote_attended_tmp)))
# Out:
# -------------------------------------------------
# Data description of attended remote consultation in 2019/03:
#        COUNT_OF_APPOINTMENTS
# count             190.000000
# mean            17464.326316
# std             16596.126810
# min               439.000000
# 5%               4047.850000
# 10%              5464.100000
# 25%              8084.250000
# 50%             12428.000000
# 75%             20831.500000
# 90%             35685.700000
# 95%             49432.750000
# max            136927.000000
# -------------------------------------------------
# Minimum:
# CCG_NAME                 NHS Airedale Wharfedale and Craven CCG
# COUNT_OF_APPOINTMENTS                                       439
# dtype: object
# -------------------------------------------------
# Maximum:
# CCG_NAME                 NHS Wyre Forest CCG
# COUNT_OF_APPOINTMENTS                 136927
# dtype: object
# -------------------------------------------------
# CCG number:190

# %% [markdown]
# # Month/Year: 04/2019
#
# Exclusion:
#
#             1. Home Visit & Unknown
#             2. More than 28 Days & Unknown / Data Issue

# %%
csv_name = 'CCG_CSV_Apr_19.csv'
file_path = folder_path + csv_name
dataframe = pd.read_csv(file_path)
dataframe.drop('CCG_CODE', axis=1, inplace=True)
dataframe.drop('CCG_ONS_CODE', axis=1, inplace=True)
dataframe.drop('STP_CODE', axis=1, inplace=True)
dataframe.drop('HCP_TYPE', axis=1, inplace=True)
dataframe.drop('REGION_ONS_CODE', axis=1, inplace=True)

# %% [markdown]
# ## Data filtering & Analysis

# %%
# dna: did not attend
# f2f: face-to-face
# remote: Video Conference/Online & Telephone

remote_attended_tmp = dataframe[(dataframe['APPT_STATUS'] == 'Attended') 
                                & (dataframe['APPT_MODE'] != 'Home Visit') 
                                & (dataframe['APPT_MODE'] != 'Face-to-Face') 
                                & (dataframe['APPT_MODE'] != 'Unknown') 
                                & (dataframe['TIME_BETWEEN_BOOK_AND_APPT'] !='More than 28 Days')
                                & (dataframe['TIME_BETWEEN_BOOK_AND_APPT'] !='Unknown / Data Issue')
                                ].groupby('CCG_NAME').sum().reset_index()

remote_dna_tmp = dataframe[(dataframe['APPT_STATUS'] == 'DNA') 
                                & (dataframe['APPT_MODE'] != 'Home Visit') 
                                & (dataframe['APPT_MODE'] != 'Face-to-Face') 
                                & (dataframe['APPT_MODE'] != 'Unknown') 
                                & (dataframe['TIME_BETWEEN_BOOK_AND_APPT'] !='More than 28 Days')
                                & (dataframe['TIME_BETWEEN_BOOK_AND_APPT'] !='Unknown / Data Issue')
                                ].groupby('CCG_NAME').sum().reset_index()

f2f_attended_tmp = dataframe[(dataframe['APPT_STATUS'] == 'Attended') 
                            & (dataframe['APPT_MODE'] == 'Face-to-Face')
                            & (dataframe['TIME_BETWEEN_BOOK_AND_APPT'] !='More than 28 Days')
                            & (dataframe['TIME_BETWEEN_BOOK_AND_APPT'] !='Unknown / Data Issue')                    
                            ].groupby('CCG_NAME').sum().reset_index()

f2f_dna_tmp = dataframe[(dataframe['APPT_STATUS'] == 'DNA') 
                        & (dataframe['APPT_MODE'] == 'Face-to-Face') 
                        & (dataframe['TIME_BETWEEN_BOOK_AND_APPT'] !='More than 28 Days')
                        & (dataframe['TIME_BETWEEN_BOOK_AND_APPT'] !='Unknown / Data Issue')
                        ].groupby('CCG_NAME').sum().reset_index()


# drop na
remote_attended_tmp = remote_attended_tmp.dropna()
remote_dna_tmp = remote_dna_tmp.dropna()
f2f_attended_tmp = f2f_attended_tmp.dropna()
f2f_dna_tmp = f2f_attended_tmp.dropna()

#count, mean, max, min, 5th, 10th, 25th, 50th, 75th, 90th, 95th
print('-------------------------------------------------')
print('Data description of attended remote consultation in 2019/04:')
print(remote_attended_tmp
      .describe(percentiles=[.05, .10, .25, .50, .75, .90, .95]))
print('-------------------------------------------------')
print('Minimum:')
print(remote_attended_tmp.min())
print('-------------------------------------------------')
print('Maximum:')
print(remote_attended_tmp.max())
print('-------------------------------------------------')
print('CCG number:' + str(len(remote_attended_tmp)))
# Out:
# -------------------------------------------------
# Data description of attended remote consultation in 2019/04:
#        COUNT_OF_APPOINTMENTS
# count             190.000000
# mean            16431.468421
# std             15705.029976
# min               362.000000
# 5%               3771.100000
# 10%              4977.500000
# 25%              7750.250000
# 50%             11823.500000
# 75%             19364.750000
# 90%             32572.100000
# 95%             45426.200000
# max            130268.000000
# -------------------------------------------------
# Minimum:
# CCG_NAME                 NHS Airedale Wharfedale and Craven CCG
# COUNT_OF_APPOINTMENTS                                       362
# dtype: object
# -------------------------------------------------
# Maximum:
# CCG_NAME                 NHS Wyre Forest CCG
# COUNT_OF_APPOINTMENTS                 130268
# dtype: object
# -------------------------------------------------
# CCG number:190

# %% [markdown]
# # Month/Year: 05/2019
#
# Exclusion:
#
#             1. Home Visit & Unknown
#             2. More than 28 Days & Unknown / Data Issue

# %%
csv_name = 'CCG_CSV_May_19.csv'
file_path = folder_path + csv_name
dataframe = pd.read_csv(file_path)
dataframe.drop('CCG_CODE', axis=1, inplace=True)
dataframe.drop('CCG_ONS_CODE', axis=1, inplace=True)
dataframe.drop('STP_CODE', axis=1, inplace=True)
dataframe.drop('HCP_TYPE', axis=1, inplace=True)
dataframe.drop('REGION_ONS_CODE', axis=1, inplace=True)

# %% [markdown]
# ## Data filtering & Analysis

# %%
# dna: did not attend
# f2f: face-to-face
# remote: Video Conference/Online & Telephone

remote_attended_tmp = dataframe[(dataframe['APPT_STATUS'] == 'Attended') 
                                & (dataframe['APPT_MODE'] != 'Home Visit') 
                                & (dataframe['APPT_MODE'] != 'Face-to-Face') 
                                & (dataframe['APPT_MODE'] != 'Unknown') 
                                & (dataframe['TIME_BETWEEN_BOOK_AND_APPT'] !='More than 28 Days')
                                & (dataframe['TIME_BETWEEN_BOOK_AND_APPT'] !='Unknown / Data Issue')
                                ].groupby('CCG_NAME').sum().reset_index()

remote_dna_tmp = dataframe[(dataframe['APPT_STATUS'] == 'DNA') 
                                & (dataframe['APPT_MODE'] != 'Home Visit') 
                                & (dataframe['APPT_MODE'] != 'Face-to-Face') 
                                & (dataframe['APPT_MODE'] != 'Unknown') 
                                & (dataframe['TIME_BETWEEN_BOOK_AND_APPT'] !='More than 28 Days')
                                & (dataframe['TIME_BETWEEN_BOOK_AND_APPT'] !='Unknown / Data Issue')
                                ].groupby('CCG_NAME').sum().reset_index()

f2f_attended_tmp = dataframe[(dataframe['APPT_STATUS'] == 'Attended') 
                            & (dataframe['APPT_MODE'] == 'Face-to-Face')
                            & (dataframe['TIME_BETWEEN_BOOK_AND_APPT'] !='More than 28 Days')
                            & (dataframe['TIME_BETWEEN_BOOK_AND_APPT'] !='Unknown / Data Issue')                    
                            ].groupby('CCG_NAME').sum().reset_index()

f2f_dna_tmp = dataframe[(dataframe['APPT_STATUS'] == 'DNA') 
                        & (dataframe['APPT_MODE'] == 'Face-to-Face') 
                        & (dataframe['TIME_BETWEEN_BOOK_AND_APPT'] !='More than 28 Days')
                        & (dataframe['TIME_BETWEEN_BOOK_AND_APPT'] !='Unknown / Data Issue')
                        ].groupby('CCG_NAME').sum().reset_index()


# drop na
remote_attended_tmp = remote_attended_tmp.dropna()
remote_dna_tmp = remote_dna_tmp.dropna()
f2f_attended_tmp = f2f_attended_tmp.dropna()
f2f_dna_tmp = f2f_attended_tmp.dropna()

#count, mean, max, min, 5th, 10th, 25th, 50th, 75th, 90th, 95th
print('-------------------------------------------------')
print('Data description of attended remote consultation in 2019/05:')
print(remote_attended_tmp
      .describe(percentiles=[.05, .10, .25, .50, .75, .90, .95]))
print('-------------------------------------------------')
print('Minimum:')
print(remote_attended_tmp.min())
print('-------------------------------------------------')
print('Maximum:')
print(remote_attended_tmp.max())
print('-------------------------------------------------')
print('CCG number:' + str(len(remote_attended_tmp)))
# Out:
# -------------------------------------------------
# Data description of attended remote consultation in 2019/05:
#        COUNT_OF_APPOINTMENTS
# count             190.000000
# mean            16838.347368
# std             16005.074053
# min               944.000000
# 5%               3957.900000
# 10%              5135.300000
# 25%              7792.000000
# 50%             11752.500000
# 75%             19912.000000
# 90%             33619.200000
# 95%             47583.700000
# max            132520.000000
# -------------------------------------------------
# Minimum:
# CCG_NAME                 NHS Airedale Wharfedale and Craven CCG
# COUNT_OF_APPOINTMENTS                                       944
# dtype: object
# -------------------------------------------------
# Maximum:
# CCG_NAME                 NHS Wyre Forest CCG
# COUNT_OF_APPOINTMENTS                 132520
# dtype: object
# -------------------------------------------------
# CCG number:190

# %% [markdown]
# # Month/Year: 06/2019
#
# Exclusion:
#
#             1. Home Visit & Unknown
#             2. More than 28 Days & Unknown / Data Issue

# %%
csv_name = 'CCG_CSV_Jun_19.csv'
file_path = folder_path + csv_name
dataframe = pd.read_csv(file_path)
dataframe.drop('CCG_CODE', axis=1, inplace=True)
dataframe.drop('CCG_ONS_CODE', axis=1, inplace=True)
dataframe.drop('STP_CODE', axis=1, inplace=True)
dataframe.drop('HCP_TYPE', axis=1, inplace=True)
dataframe.drop('REGION_ONS_CODE', axis=1, inplace=True)

# %% [markdown]
# ## Data filtering & Analysis

# %%
# dna: did not attend
# f2f: face-to-face
# remote: Video Conference/Online & Telephone

remote_attended_tmp = dataframe[(dataframe['APPT_STATUS'] == 'Attended') 
                                & (dataframe['APPT_MODE'] != 'Home Visit') 
                                & (dataframe['APPT_MODE'] != 'Face-to-Face') 
                                & (dataframe['APPT_MODE'] != 'Unknown') 
                                & (dataframe['TIME_BETWEEN_BOOK_AND_APPT'] !='More than 28 Days')
                                & (dataframe['TIME_BETWEEN_BOOK_AND_APPT'] !='Unknown / Data Issue')
                                ].groupby('CCG_NAME').sum().reset_index()

remote_dna_tmp = dataframe[(dataframe['APPT_STATUS'] == 'DNA') 
                                & (dataframe['APPT_MODE'] != 'Home Visit') 
                                & (dataframe['APPT_MODE'] != 'Face-to-Face') 
                                & (dataframe['APPT_MODE'] != 'Unknown') 
                                & (dataframe['TIME_BETWEEN_BOOK_AND_APPT'] !='More than 28 Days')
                                & (dataframe['TIME_BETWEEN_BOOK_AND_APPT'] !='Unknown / Data Issue')
                                ].groupby('CCG_NAME').sum().reset_index()

f2f_attended_tmp = dataframe[(dataframe['APPT_STATUS'] == 'Attended') 
                            & (dataframe['APPT_MODE'] == 'Face-to-Face')
                            & (dataframe['TIME_BETWEEN_BOOK_AND_APPT'] !='More than 28 Days')
                            & (dataframe['TIME_BETWEEN_BOOK_AND_APPT'] !='Unknown / Data Issue')                    
                            ].groupby('CCG_NAME').sum().reset_index()

f2f_dna_tmp = dataframe[(dataframe['APPT_STATUS'] == 'DNA') 
                        & (dataframe['APPT_MODE'] == 'Face-to-Face') 
                        & (dataframe['TIME_BETWEEN_BOOK_AND_APPT'] !='More than 28 Days')
                        & (dataframe['TIME_BETWEEN_BOOK_AND_APPT'] !='Unknown / Data Issue')
                        ].groupby('CCG_NAME').sum().reset_index()


# drop na
remote_attended_tmp = remote_attended_tmp.dropna()
remote_dna_tmp = remote_dna_tmp.dropna()
f2f_attended_tmp = f2f_attended_tmp.dropna()
f2f_dna_tmp = f2f_attended_tmp.dropna()

#count, mean, max, min, 5th, 10th, 25th, 50th, 75th, 90th, 95th
print('-------------------------------------------------')
print('Data description of attended remote consultation in 2019/06:')
print(remote_attended_tmp
      .describe(percentiles=[.05, .10, .25, .50, .75, .90, .95]))
print('-------------------------------------------------')
print('Minimum:')
print(remote_attended_tmp.min())
print('-------------------------------------------------')
print('Maximum:')
print(remote_attended_tmp.max())
print('-------------------------------------------------')
print('CCG number:' + str(len(remote_attended_tmp)))
# Out:
# -------------------------------------------------
# Data description of attended remote consultation in 2019/06:
#        COUNT_OF_APPOINTMENTS
# count             190.000000
# mean            15735.331579
# std             14879.354381
# min              1608.000000
# 5%               3783.100000
# 10%              4783.900000
# 25%              7431.000000
# 50%             11020.500000
# 75%             18484.250000
# 90%             29875.000000
# 95%             44873.900000
# max            126462.000000
# -------------------------------------------------
# Minimum:
# CCG_NAME                 NHS Airedale Wharfedale and Craven CCG
# COUNT_OF_APPOINTMENTS                                      1608
# dtype: object
# -------------------------------------------------
# Maximum:
# CCG_NAME                 NHS Wyre Forest CCG
# COUNT_OF_APPOINTMENTS                 126462
# dtype: object
# -------------------------------------------------
# CCG number:190

# %% [markdown]
# # Month/Year: 07/2019
#
# Exclusion:
#
#             1. Home Visit & Unknown
#             2. More than 28 Days & Unknown / Data Issue

# %%
csv_name = 'CCG_CSV_Jul_19.csv'
file_path = folder_path + csv_name
dataframe = pd.read_csv(file_path)
dataframe.drop('CCG_CODE', axis=1, inplace=True)
dataframe.drop('CCG_ONS_CODE', axis=1, inplace=True)
dataframe.drop('STP_CODE', axis=1, inplace=True)
dataframe.drop('HCP_TYPE', axis=1, inplace=True)
dataframe.drop('REGION_ONS_CODE', axis=1, inplace=True)

# %% [markdown]
# ## Data filtering & Analysis

# %%
# dna: did not attend
# f2f: face-to-face
# remote: Video Conference/Online & Telephone

remote_attended_tmp = dataframe[(dataframe['APPT_STATUS'] == 'Attended') 
                                & (dataframe['APPT_MODE'] != 'Home Visit') 
                                & (dataframe['APPT_MODE'] != 'Face-to-Face') 
                                & (dataframe['APPT_MODE'] != 'Unknown') 
                                & (dataframe['TIME_BETWEEN_BOOK_AND_APPT'] !='More than 28 Days')
                                & (dataframe['TIME_BETWEEN_BOOK_AND_APPT'] !='Unknown / Data Issue')
                                ].groupby('CCG_NAME').sum().reset_index()

remote_dna_tmp = dataframe[(dataframe['APPT_STATUS'] == 'DNA') 
                                & (dataframe['APPT_MODE'] != 'Home Visit') 
                                & (dataframe['APPT_MODE'] != 'Face-to-Face') 
                                & (dataframe['APPT_MODE'] != 'Unknown') 
                                & (dataframe['TIME_BETWEEN_BOOK_AND_APPT'] !='More than 28 Days')
                                & (dataframe['TIME_BETWEEN_BOOK_AND_APPT'] !='Unknown / Data Issue')
                                ].groupby('CCG_NAME').sum().reset_index()

f2f_attended_tmp = dataframe[(dataframe['APPT_STATUS'] == 'Attended') 
                            & (dataframe['APPT_MODE'] == 'Face-to-Face')
                            & (dataframe['TIME_BETWEEN_BOOK_AND_APPT'] !='More than 28 Days')
                            & (dataframe['TIME_BETWEEN_BOOK_AND_APPT'] !='Unknown / Data Issue')                    
                            ].groupby('CCG_NAME').sum().reset_index()

f2f_dna_tmp = dataframe[(dataframe['APPT_STATUS'] == 'DNA') 
                        & (dataframe['APPT_MODE'] == 'Face-to-Face') 
                        & (dataframe['TIME_BETWEEN_BOOK_AND_APPT'] !='More than 28 Days')
                        & (dataframe['TIME_BETWEEN_BOOK_AND_APPT'] !='Unknown / Data Issue')
                        ].groupby('CCG_NAME').sum().reset_index()


# drop na
remote_attended_tmp = remote_attended_tmp.dropna()
remote_dna_tmp = remote_dna_tmp.dropna()
f2f_attended_tmp = f2f_attended_tmp.dropna()
f2f_dna_tmp = f2f_attended_tmp.dropna()

#count, mean, max, min, 5th, 10th, 25th, 50th, 75th, 90th, 95th
print('-------------------------------------------------')
print('Data description of attended remote consultation in 2019/07:')
print(remote_attended_tmp
      .describe(percentiles=[.05, .10, .25, .50, .75, .90, .95]))
print('-------------------------------------------------')
print('Minimum:')
print(remote_attended_tmp.min())
print('-------------------------------------------------')
print('Maximum:')
print(remote_attended_tmp.max())
print('-------------------------------------------------')
print('CCG number:' + str(len(remote_attended_tmp)))
# Out:
# -------------------------------------------------
# Data description of attended remote consultation in 2019/07:
#        COUNT_OF_APPOINTMENTS
# count             190.000000
# mean            18119.568421
# std             16908.912358
# min              1729.000000
# 5%               4647.200000
# 10%              5653.600000
# 25%              8703.000000
# 50%             13064.500000
# 75%             21082.000000
# 90%             33878.900000
# 95%             50391.100000
# max            141938.000000
# -------------------------------------------------
# Minimum:
# CCG_NAME                 NHS Airedale Wharfedale and Craven CCG
# COUNT_OF_APPOINTMENTS                                      1729
# dtype: object
# -------------------------------------------------
# Maximum:
# CCG_NAME                 NHS Wyre Forest CCG
# COUNT_OF_APPOINTMENTS                 141938
# dtype: object
# -------------------------------------------------
# CCG number:190

# %% [markdown]
# # Month/Year: 08/2019
#
# Exclusion:
#
#             1. Home Visit & Unknown
#             2. More than 28 Days & Unknown / Data Issue

# %%
csv_name = 'CCG_CSV_Aug_19.csv'
file_path = folder_path + csv_name
dataframe = pd.read_csv(file_path)
dataframe.drop('CCG_CODE', axis=1, inplace=True)
dataframe.drop('CCG_ONS_CODE', axis=1, inplace=True)
dataframe.drop('STP_ONS_CODE', axis=1, inplace=True)
dataframe.drop('HCP_TYPE', axis=1, inplace=True)
dataframe.drop('REGION_ONS_CODE', axis=1, inplace=True)

# %% [markdown]
# ## Data filtering & Analysis

# %%
# dna: did not attend
# f2f: face-to-face
# remote: Video Conference/Online & Telephone

remote_attended_tmp = dataframe[(dataframe['APPT_STATUS'] == 'Attended') 
                                & (dataframe['APPT_MODE'] != 'Home Visit') 
                                & (dataframe['APPT_MODE'] != 'Face-to-Face') 
                                & (dataframe['APPT_MODE'] != 'Unknown') 
                                & (dataframe['TIME_BETWEEN_BOOK_AND_APPT'] !='More than 28 Days')
                                & (dataframe['TIME_BETWEEN_BOOK_AND_APPT'] !='Unknown / Data Issue')
                                ].groupby('CCG_NAME').sum().reset_index()

remote_dna_tmp = dataframe[(dataframe['APPT_STATUS'] == 'DNA') 
                                & (dataframe['APPT_MODE'] != 'Home Visit') 
                                & (dataframe['APPT_MODE'] != 'Face-to-Face') 
                                & (dataframe['APPT_MODE'] != 'Unknown') 
                                & (dataframe['TIME_BETWEEN_BOOK_AND_APPT'] !='More than 28 Days')
                                & (dataframe['TIME_BETWEEN_BOOK_AND_APPT'] !='Unknown / Data Issue')
                                ].groupby('CCG_NAME').sum().reset_index()

f2f_attended_tmp = dataframe[(dataframe['APPT_STATUS'] == 'Attended') 
                            & (dataframe['APPT_MODE'] == 'Face-to-Face')
                            & (dataframe['TIME_BETWEEN_BOOK_AND_APPT'] !='More than 28 Days')
                            & (dataframe['TIME_BETWEEN_BOOK_AND_APPT'] !='Unknown / Data Issue')                    
                            ].groupby('CCG_NAME').sum().reset_index()

f2f_dna_tmp = dataframe[(dataframe['APPT_STATUS'] == 'DNA') 
                        & (dataframe['APPT_MODE'] == 'Face-to-Face') 
                        & (dataframe['TIME_BETWEEN_BOOK_AND_APPT'] !='More than 28 Days')
                        & (dataframe['TIME_BETWEEN_BOOK_AND_APPT'] !='Unknown / Data Issue')
                        ].groupby('CCG_NAME').sum().reset_index()


# drop na
remote_attended_tmp = remote_attended_tmp.dropna()
remote_dna_tmp = remote_dna_tmp.dropna()
f2f_attended_tmp = f2f_attended_tmp.dropna()
f2f_dna_tmp = f2f_attended_tmp.dropna()

#count, mean, max, min, 5th, 10th, 25th, 50th, 75th, 90th, 95th
print('-------------------------------------------------')
print('Data description of attended remote consultation in 2019/08:')
print(remote_attended_tmp
      .describe(percentiles=[.05, .10, .25, .50, .75, .90, .95]))
print('-------------------------------------------------')
print('Minimum:')
print(remote_attended_tmp.min())
print('-------------------------------------------------')
print('Maximum:')
print(remote_attended_tmp.max())
print('-------------------------------------------------')
print('CCG number:' + str(len(remote_attended_tmp)))
# Out:
# -------------------------------------------------
# Data description of attended remote consultation in 2019/08:
#        COUNT_OF_APPOINTMENTS
# count             105.000000
# mean            28692.228571
# std             25974.884543
# min              2225.000000
# 5%               5044.200000
# 10%              6176.000000
# 25%              9015.000000
# 50%             18531.000000
# 75%             43090.000000
# 90%             67444.400000
# 95%             73536.200000
# max            125009.000000
# -------------------------------------------------
# Minimum:
# CCG_NAME                 NHS Barnsley CCG
# COUNT_OF_APPOINTMENTS                2225
# dtype: object
# -------------------------------------------------
# Maximum:
# CCG_NAME                 NHS Wirral CCG
# COUNT_OF_APPOINTMENTS            125009
# dtype: object
# -------------------------------------------------
# CCG number:105

# %% [markdown]
# # Month/Year: 09/2019
#
# Exclusion:
#
#             1. Home Visit & Unknown
#             2. More than 28 Days & Unknown / Data Issue

# %%
csv_name = 'CCG_CSV_Sep_19.csv'
file_path = folder_path + csv_name
dataframe = pd.read_csv(file_path)
dataframe.drop('CCG_CODE', axis=1, inplace=True)
dataframe.drop('CCG_ONS_CODE', axis=1, inplace=True)
dataframe.drop('STP_ONS_CODE', axis=1, inplace=True)
dataframe.drop('HCP_TYPE', axis=1, inplace=True)
dataframe.drop('REGION_ONS_CODE', axis=1, inplace=True)

# %% [markdown]
# ## Data filtering & Analysis

# %%
# dna: did not attend
# f2f: face-to-face
# remote: Video Conference/Online & Telephone

remote_attended_tmp = dataframe[(dataframe['APPT_STATUS'] == 'Attended') 
                                & (dataframe['APPT_MODE'] != 'Home Visit') 
                                & (dataframe['APPT_MODE'] != 'Face-to-Face') 
                                & (dataframe['APPT_MODE'] != 'Unknown') 
                                & (dataframe['TIME_BETWEEN_BOOK_AND_APPT'] !='More than 28 Days')
                                & (dataframe['TIME_BETWEEN_BOOK_AND_APPT'] !='Unknown / Data Issue')
                                ].groupby('CCG_NAME').sum().reset_index()

remote_dna_tmp = dataframe[(dataframe['APPT_STATUS'] == 'DNA') 
                                & (dataframe['APPT_MODE'] != 'Home Visit') 
                                & (dataframe['APPT_MODE'] != 'Face-to-Face') 
                                & (dataframe['APPT_MODE'] != 'Unknown') 
                                & (dataframe['TIME_BETWEEN_BOOK_AND_APPT'] !='More than 28 Days')
                                & (dataframe['TIME_BETWEEN_BOOK_AND_APPT'] !='Unknown / Data Issue')
                                ].groupby('CCG_NAME').sum().reset_index()

f2f_attended_tmp = dataframe[(dataframe['APPT_STATUS'] == 'Attended') 
                            & (dataframe['APPT_MODE'] == 'Face-to-Face')
                            & (dataframe['TIME_BETWEEN_BOOK_AND_APPT'] !='More than 28 Days')
                            & (dataframe['TIME_BETWEEN_BOOK_AND_APPT'] !='Unknown / Data Issue')                    
                            ].groupby('CCG_NAME').sum().reset_index()

f2f_dna_tmp = dataframe[(dataframe['APPT_STATUS'] == 'DNA') 
                        & (dataframe['APPT_MODE'] == 'Face-to-Face') 
                        & (dataframe['TIME_BETWEEN_BOOK_AND_APPT'] !='More than 28 Days')
                        & (dataframe['TIME_BETWEEN_BOOK_AND_APPT'] !='Unknown / Data Issue')
                        ].groupby('CCG_NAME').sum().reset_index()


# drop na
remote_attended_tmp = remote_attended_tmp.dropna()
remote_dna_tmp = remote_dna_tmp.dropna()
f2f_attended_tmp = f2f_attended_tmp.dropna()
f2f_dna_tmp = f2f_attended_tmp.dropna()

#count, mean, max, min, 5th, 10th, 25th, 50th, 75th, 90th, 95th
print('-------------------------------------------------')
print('Data description of attended remote consultation in 2019/09:')
print(remote_attended_tmp
      .describe(percentiles=[.05, .10, .25, .50, .75, .90, .95]))
print('-------------------------------------------------')
print('Minimum:')
print(remote_attended_tmp.min())
print('-------------------------------------------------')
print('Maximum:')
print(remote_attended_tmp.max())
print('-------------------------------------------------')
print('CCG number:' + str(len(remote_attended_tmp)))
# Out:
# -------------------------------------------------
# Data description of attended remote consultation in 2019/09:
#        COUNT_OF_APPOINTMENTS
# count             105.000000
# mean            30347.885714
# std             27621.990879
# min              2297.000000
# 5%               5545.200000
# 10%              6436.200000
# 25%              9155.000000
# 50%             19550.000000
# 75%             44700.000000
# 90%             71059.200000
# 95%             80467.800000
# max            132898.000000
# -------------------------------------------------
# Minimum:
# CCG_NAME                 NHS Barnsley CCG
# COUNT_OF_APPOINTMENTS                2297
# dtype: object
# -------------------------------------------------
# Maximum:
# CCG_NAME                 NHS Wirral CCG
# COUNT_OF_APPOINTMENTS            132898
# dtype: object
# -------------------------------------------------
# CCG number:105

# %% [markdown]
# # Month/Year: 10/2019
#
# Exclusion:
#
#             1. Home Visit & Unknown
#             2. More than 28 Days & Unknown / Data Issue

# %%
csv_name = 'CCG_CSV_Oct_19.csv'
file_path = folder_path + csv_name
dataframe = pd.read_csv(file_path)
dataframe.drop('CCG_CODE', axis=1, inplace=True)
dataframe.drop('CCG_ONS_CODE', axis=1, inplace=True)
dataframe.drop('STP_ONS_CODE', axis=1, inplace=True)
dataframe.drop('HCP_TYPE', axis=1, inplace=True)
dataframe.drop('REGION_ONS_CODE', axis=1, inplace=True)

# %% [markdown]
# ## Data filtering & Analysis

# %%
# dna: did not attend
# f2f: face-to-face
# remote: Video Conference/Online & Telephone

remote_attended_tmp = dataframe[(dataframe['APPT_STATUS'] == 'Attended') 
                                & (dataframe['APPT_MODE'] != 'Home Visit') 
                                & (dataframe['APPT_MODE'] != 'Face-to-Face') 
                                & (dataframe['APPT_MODE'] != 'Unknown') 
                                & (dataframe['TIME_BETWEEN_BOOK_AND_APPT'] !='More than 28 Days')
                                & (dataframe['TIME_BETWEEN_BOOK_AND_APPT'] !='Unknown / Data Issue')
                                ].groupby('CCG_NAME').sum().reset_index()

remote_dna_tmp = dataframe[(dataframe['APPT_STATUS'] == 'DNA') 
                                & (dataframe['APPT_MODE'] != 'Home Visit') 
                                & (dataframe['APPT_MODE'] != 'Face-to-Face') 
                                & (dataframe['APPT_MODE'] != 'Unknown') 
                                & (dataframe['TIME_BETWEEN_BOOK_AND_APPT'] !='More than 28 Days')
                                & (dataframe['TIME_BETWEEN_BOOK_AND_APPT'] !='Unknown / Data Issue')
                                ].groupby('CCG_NAME').sum().reset_index()

f2f_attended_tmp = dataframe[(dataframe['APPT_STATUS'] == 'Attended') 
                            & (dataframe['APPT_MODE'] == 'Face-to-Face')
                            & (dataframe['TIME_BETWEEN_BOOK_AND_APPT'] !='More than 28 Days')
                            & (dataframe['TIME_BETWEEN_BOOK_AND_APPT'] !='Unknown / Data Issue')                    
                            ].groupby('CCG_NAME').sum().reset_index()

f2f_dna_tmp = dataframe[(dataframe['APPT_STATUS'] == 'DNA') 
                        & (dataframe['APPT_MODE'] == 'Face-to-Face') 
                        & (dataframe['TIME_BETWEEN_BOOK_AND_APPT'] !='More than 28 Days')
                        & (dataframe['TIME_BETWEEN_BOOK_AND_APPT'] !='Unknown / Data Issue')
                        ].groupby('CCG_NAME').sum().reset_index()


# drop na
remote_attended_tmp = remote_attended_tmp.dropna()
remote_dna_tmp = remote_dna_tmp.dropna()
f2f_attended_tmp = f2f_attended_tmp.dropna()
f2f_dna_tmp = f2f_attended_tmp.dropna()

#count, mean, max, min, 5th, 10th, 25th, 50th, 75th, 90th, 95th
print('-------------------------------------------------')
print('Data description of attended remote consultation in 2019/10:')
print(remote_attended_tmp
      .describe(percentiles=[.05, .10, .25, .50, .75, .90, .95]))
print('-------------------------------------------------')
print('Minimum:')
print(remote_attended_tmp.min())
print('-------------------------------------------------')
print('Maximum:')
print(remote_attended_tmp.max())
print('-------------------------------------------------')
print('CCG number:' + str(len(remote_attended_tmp)))
# Out:
# -------------------------------------------------
# Data description of attended remote consultation in 2019/10:
#        COUNT_OF_APPOINTMENTS
# count             105.000000
# mean            33618.180952
# std             30737.870440
# min              2669.000000
# 5%               5927.400000
# 10%              6870.800000
# 25%             10084.000000
# 50%             20850.000000
# 75%             49268.000000
# 90%             79204.200000
# 95%             89409.000000
# max            144266.000000
# -------------------------------------------------
# Minimum:
# CCG_NAME                 NHS Barnsley CCG
# COUNT_OF_APPOINTMENTS                2669
# dtype: object
# -------------------------------------------------
# Maximum:
# CCG_NAME                 NHS Wirral CCG
# COUNT_OF_APPOINTMENTS            144266
# dtype: object
# -------------------------------------------------
# CCG number:105

# %% [markdown]
# # Month/Year: 11/2019
#
# Exclusion:
#
#             1. Home Visit & Unknown
#             2. More than 28 Days & Unknown / Data Issue

# %%
csv_name = 'CCG_CSV_Nov_19.csv'
file_path = folder_path + csv_name
dataframe = pd.read_csv(file_path)
dataframe.drop('CCG_CODE', axis=1, inplace=True)
dataframe.drop('CCG_ONS_CODE', axis=1, inplace=True)
dataframe.drop('STP_ONS_CODE', axis=1, inplace=True)
dataframe.drop('HCP_TYPE', axis=1, inplace=True)
dataframe.drop('REGION_ONS_CODE', axis=1, inplace=True)

# %% [markdown]
# ## Data filtering & Analysis

# %%
# dna: did not attend
# f2f: face-to-face
# remote: Video Conference/Online & Telephone

remote_attended_tmp = dataframe[(dataframe['APPT_STATUS'] == 'Attended') 
                                & (dataframe['APPT_MODE'] != 'Home Visit') 
                                & (dataframe['APPT_MODE'] != 'Face-to-Face') 
                                & (dataframe['APPT_MODE'] != 'Unknown') 
                                & (dataframe['TIME_BETWEEN_BOOK_AND_APPT'] !='More than 28 Days')
                                & (dataframe['TIME_BETWEEN_BOOK_AND_APPT'] !='Unknown / Data Issue')
                                ].groupby('CCG_NAME').sum().reset_index()

remote_dna_tmp = dataframe[(dataframe['APPT_STATUS'] == 'DNA') 
                                & (dataframe['APPT_MODE'] != 'Home Visit') 
                                & (dataframe['APPT_MODE'] != 'Face-to-Face') 
                                & (dataframe['APPT_MODE'] != 'Unknown') 
                                & (dataframe['TIME_BETWEEN_BOOK_AND_APPT'] !='More than 28 Days')
                                & (dataframe['TIME_BETWEEN_BOOK_AND_APPT'] !='Unknown / Data Issue')
                                ].groupby('CCG_NAME').sum().reset_index()

f2f_attended_tmp = dataframe[(dataframe['APPT_STATUS'] == 'Attended') 
                            & (dataframe['APPT_MODE'] == 'Face-to-Face')
                            & (dataframe['TIME_BETWEEN_BOOK_AND_APPT'] !='More than 28 Days')
                            & (dataframe['TIME_BETWEEN_BOOK_AND_APPT'] !='Unknown / Data Issue')                    
                            ].groupby('CCG_NAME').sum().reset_index()

f2f_dna_tmp = dataframe[(dataframe['APPT_STATUS'] == 'DNA') 
                        & (dataframe['APPT_MODE'] == 'Face-to-Face') 
                        & (dataframe['TIME_BETWEEN_BOOK_AND_APPT'] !='More than 28 Days')
                        & (dataframe['TIME_BETWEEN_BOOK_AND_APPT'] !='Unknown / Data Issue')
                        ].groupby('CCG_NAME').sum().reset_index()


# drop na
remote_attended_tmp = remote_attended_tmp.dropna()
remote_dna_tmp = remote_dna_tmp.dropna()
f2f_attended_tmp = f2f_attended_tmp.dropna()
f2f_dna_tmp = f2f_attended_tmp.dropna()

#count, mean, max, min, 5th, 10th, 25th, 50th, 75th, 90th, 95th
print('-------------------------------------------------')
print('Data description of attended remote consultation in 2019/11:')
print(remote_attended_tmp
      .describe(percentiles=[.05, .10, .25, .50, .75, .90, .95]))
print('-------------------------------------------------')
print('Minimum:')
print(remote_attended_tmp.min())
print('-------------------------------------------------')
print('Maximum:')
print(remote_attended_tmp.max())
print('-------------------------------------------------')
print('CCG number:' + str(len(remote_attended_tmp)))
# Out:
# -------------------------------------------------
# Data description of attended remote consultation in 2019/11:
#        COUNT_OF_APPOINTMENTS
# count             105.000000
# mean            31860.780952
# std             29121.094066
# min              2694.000000
# 5%               5664.200000
# 10%              6619.800000
# 25%              9679.000000
# 50%             19693.000000
# 75%             47871.000000
# 90%             74052.600000
# 95%             83401.400000
# max            130928.000000
# -------------------------------------------------
# Minimum:
# CCG_NAME                 NHS Barnsley CCG
# COUNT_OF_APPOINTMENTS                2694
# dtype: object
# -------------------------------------------------
# Maximum:
# CCG_NAME                 NHS Wirral CCG
# COUNT_OF_APPOINTMENTS            130928
# dtype: object
# -------------------------------------------------
# CCG number:105

# %% [markdown]
# # Month/Year: 12/2019
#
# Exclusion:
#
#             1. Home Visit & Unknown
#             2. More than 28 Days & Unknown / Data Issue

# %%
csv_name = 'CCG_CSV_Dec_19.csv'
file_path = folder_path + csv_name
dataframe = pd.read_csv(file_path)
dataframe.drop('CCG_CODE', axis=1, inplace=True)
dataframe.drop('CCG_ONS_CODE', axis=1, inplace=True)
dataframe.drop('STP_ONS_CODE', axis=1, inplace=True)
dataframe.drop('HCP_TYPE', axis=1, inplace=True)
dataframe.drop('REGION_ONS_CODE', axis=1, inplace=True)

# %% [markdown]
# ## Data filtering & Analysis

# %%
# dna: did not attend
# f2f: face-to-face
# remote: Video Conference/Online & Telephone

remote_attended_tmp = dataframe[(dataframe['APPT_STATUS'] == 'Attended') 
                                & (dataframe['APPT_MODE'] != 'Home Visit') 
                                & (dataframe['APPT_MODE'] != 'Face-to-Face') 
                                & (dataframe['APPT_MODE'] != 'Unknown') 
                                & (dataframe['TIME_BETWEEN_BOOK_AND_APPT'] !='More than 28 Days')
                                & (dataframe['TIME_BETWEEN_BOOK_AND_APPT'] !='Unknown / Data Issue')
                                ].groupby('CCG_NAME').sum().reset_index()

remote_dna_tmp = dataframe[(dataframe['APPT_STATUS'] == 'DNA') 
                                & (dataframe['APPT_MODE'] != 'Home Visit') 
                                & (dataframe['APPT_MODE'] != 'Face-to-Face') 
                                & (dataframe['APPT_MODE'] != 'Unknown') 
                                & (dataframe['TIME_BETWEEN_BOOK_AND_APPT'] !='More than 28 Days')
                                & (dataframe['TIME_BETWEEN_BOOK_AND_APPT'] !='Unknown / Data Issue')
                                ].groupby('CCG_NAME').sum().reset_index()

f2f_attended_tmp = dataframe[(dataframe['APPT_STATUS'] == 'Attended') 
                            & (dataframe['APPT_MODE'] == 'Face-to-Face')
                            & (dataframe['TIME_BETWEEN_BOOK_AND_APPT'] !='More than 28 Days')
                            & (dataframe['TIME_BETWEEN_BOOK_AND_APPT'] !='Unknown / Data Issue')                    
                            ].groupby('CCG_NAME').sum().reset_index()

f2f_dna_tmp = dataframe[(dataframe['APPT_STATUS'] == 'DNA') 
                        & (dataframe['APPT_MODE'] == 'Face-to-Face') 
                        & (dataframe['TIME_BETWEEN_BOOK_AND_APPT'] !='More than 28 Days')
                        & (dataframe['TIME_BETWEEN_BOOK_AND_APPT'] !='Unknown / Data Issue')
                        ].groupby('CCG_NAME').sum().reset_index()


# drop na
remote_attended_tmp = remote_attended_tmp.dropna()
remote_dna_tmp = remote_dna_tmp.dropna()
f2f_attended_tmp = f2f_attended_tmp.dropna()
f2f_dna_tmp = f2f_attended_tmp.dropna()

#count, mean, max, min, 5th, 10th, 25th, 50th, 75th, 90th, 95th
print('-------------------------------------------------')
print('Data description of attended remote consultation in 2019/12:')
print(remote_attended_tmp
      .describe(percentiles=[.05, .10, .25, .50, .75, .90, .95]))
print('-------------------------------------------------')
print('Minimum:')
print(remote_attended_tmp.min())
print('-------------------------------------------------')
print('Maximum:')
print(remote_attended_tmp.max())
print('-------------------------------------------------')
print('CCG number:' + str(len(remote_attended_tmp)))
# Out:
# -------------------------------------------------
# Data description of attended remote consultation in 2019/12:
#        COUNT_OF_APPOINTMENTS
# count             105.000000
# mean            30134.809524
# std             27373.508176
# min              2505.000000
# 5%               5360.600000
# 10%              6042.800000
# 25%              9128.000000
# 50%             18080.000000
# 75%             45869.000000
# 90%             70585.400000
# 95%             78879.800000
# max            120948.000000
# -------------------------------------------------
# Minimum:
# CCG_NAME                 NHS Barnsley CCG
# COUNT_OF_APPOINTMENTS                2505
# dtype: object
# -------------------------------------------------
# Maximum:
# CCG_NAME                 NHS Wirral CCG
# COUNT_OF_APPOINTMENTS            120948
# dtype: object
# -------------------------------------------------
# CCG number:105
