# %% [markdown]
# # Import packages and define folder path

# %%
import csv
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.ticker import FuncFormatter
import seaborn as sns

# modify folder path
folder_path = 'Your folder path'

# %% [markdown]
# # Import CSV file
#
# # Month/Year: 01/2021
#
# Exclusion:
#
#             1. Home Visit & Unknown
#             2. More than 28 Days & Unknown / Data Issue

# %%
csv_name = 'CCG_CSV_Jan_21.csv'
file_path = folder_path + csv_name
dataframe = pd.read_csv(file_path)
dataframe.drop('CCG_CODE', axis=1, inplace=True)
dataframe.drop('CCG_ONS_CODE', axis=1, inplace=True)
dataframe.drop('STP_ONS_CODE', axis=1, inplace=True)
dataframe.drop('HCP_TYPE', axis=1, inplace=True)
#dataframe.drop('REGION_ONS_CODE', axis=1, inplace=True)

# %% [markdown]
# ## Data filtering & Analysis

# %%
# dna: did not attend
# f2f: face-to-face
# remote: Video Conference/Online & Telephone

remote_attended_tmp = dataframe[(dataframe['APPT_STATUS'] == 'Attended') 
                                & (dataframe['APPT_MODE'] != 'Home Visit') 
                                & (dataframe['APPT_MODE'] != 'Face-to-Face') 
                                & (dataframe['APPT_MODE'] != 'Unknown') 
                                & (dataframe['TIME_BETWEEN_BOOK_AND_APPT'] !='More than 28 Days')
                                & (dataframe['TIME_BETWEEN_BOOK_AND_APPT'] !='Unknown / Data Issue')
                                ]

remote_dna_tmp = dataframe[(dataframe['APPT_STATUS'] == 'DNA') 
                                & (dataframe['APPT_MODE'] != 'Home Visit') 
                                & (dataframe['APPT_MODE'] != 'Face-to-Face') 
                                & (dataframe['APPT_MODE'] != 'Unknown') 
                                & (dataframe['TIME_BETWEEN_BOOK_AND_APPT'] !='More than 28 Days')
                                & (dataframe['TIME_BETWEEN_BOOK_AND_APPT'] !='Unknown / Data Issue')
                                ]['COUNT_OF_APPOINTMENTS']

f2f_attended_tmp = dataframe[(dataframe['APPT_STATUS'] == 'Attended') 
                            & (dataframe['APPT_MODE'] == 'Face-to-Face')
                            & (dataframe['TIME_BETWEEN_BOOK_AND_APPT'] !='More than 28 Days')
                            & (dataframe['TIME_BETWEEN_BOOK_AND_APPT'] !='Unknown / Data Issue')                    
                            ]['COUNT_OF_APPOINTMENTS']

f2f_dna_tmp = dataframe[(dataframe['APPT_STATUS'] == 'DNA') 
                        & (dataframe['APPT_MODE'] == 'Face-to-Face') 
                        & (dataframe['TIME_BETWEEN_BOOK_AND_APPT'] !='More than 28 Days')
                        & (dataframe['TIME_BETWEEN_BOOK_AND_APPT'] !='Unknown / Data Issue')
                        ]['COUNT_OF_APPOINTMENTS']


# drop na

remote_attended_tmp = remote_attended_tmp.dropna()
remote_dna_tmp = remote_dna_tmp.dropna()
f2f_attended_tmp = f2f_attended_tmp.dropna()
f2f_dna_tmp = f2f_attended_tmp.dropna()

#count, mean, max, min, 5th, 10th, 25th, 50th, 75th, 90th, 95th
print('-------------------------------------------------')
print('Data description of attended remote consultation in 2021/01:')
print(remote_attended_tmp[['CCG_NAME', 'Appointment_Date', 'COUNT_OF_APPOINTMENTS']]
      .describe(percentiles=[.05, .10, .25, .50, .75, .90, .95]))
print('-------------------------------------------------')
print('Minimum:')
print(remote_attended_tmp[['CCG_NAME', 'Appointment_Date', 'COUNT_OF_APPOINTMENTS']].min())
print('-------------------------------------------------')
print('Maximum:')
print(remote_attended_tmp[['CCG_NAME', 'Appointment_Date', 'COUNT_OF_APPOINTMENTS']].max())
print('-------------------------------------------------')
# Out:
# -------------------------------------------------
# Data description of attended remote consultation in 2021/01:
#        COUNT_OF_APPOINTMENTS
# count           40996.000000
# mean              223.160747
# std               658.353645
# min                 1.000000
# 5%                  1.000000
# 10%                 2.000000
# 25%                 6.000000
# 50%                31.000000
# 75%               147.000000
# 90%               522.500000
# 95%              1044.250000
# max             11264.000000
# -------------------------------------------------
# Minimum:
# CCG_NAME                 NHS Barnsley CCG
# Appointment_Date                01JAN2021
# COUNT_OF_APPOINTMENTS                   1
# dtype: object
# -------------------------------------------------
# Maximum:
# CCG_NAME                 NHS Wirral CCG
# Appointment_Date              31JAN2021
# COUNT_OF_APPOINTMENTS             11264
# dtype: object
# -------------------------------------------------

# %% [markdown]
# # Month/Year: 02/2021
#
# Exclusion:
#
#             1. Home Visit & Unknown
#             2. More than 28 Days & Unknown / Data Issue

# %%
csv_name = 'CCG_CSV_Feb_21.csv'
file_path = folder_path + csv_name
dataframe = pd.read_csv(file_path)
dataframe.drop('CCG_CODE', axis=1, inplace=True)
dataframe.drop('CCG_ONS_CODE', axis=1, inplace=True)
dataframe.drop('STP_ONS_CODE', axis=1, inplace=True)
dataframe.drop('HCP_TYPE', axis=1, inplace=True)
dataframe.drop('REGION_ONS_CODE', axis=1, inplace=True)

# %% [markdown]
# ## Data filtering & Analysis

# %%
# dna: did not attend
# f2f: face-to-face
# remote: Video Conference/Online & Telephone

remote_attended_tmp = dataframe[(dataframe['APPT_STATUS'] == 'Attended') 
                                & (dataframe['APPT_MODE'] != 'Home Visit') 
                                & (dataframe['APPT_MODE'] != 'Face-to-Face') 
                                & (dataframe['APPT_MODE'] != 'Unknown') 
                                & (dataframe['TIME_BETWEEN_BOOK_AND_APPT'] !='More than 28 Days')
                                & (dataframe['TIME_BETWEEN_BOOK_AND_APPT'] !='Unknown / Data Issue')
                                ]

remote_dna_tmp = dataframe[(dataframe['APPT_STATUS'] == 'DNA') 
                                & (dataframe['APPT_MODE'] != 'Home Visit') 
                                & (dataframe['APPT_MODE'] != 'Face-to-Face') 
                                & (dataframe['APPT_MODE'] != 'Unknown') 
                                & (dataframe['TIME_BETWEEN_BOOK_AND_APPT'] !='More than 28 Days')
                                & (dataframe['TIME_BETWEEN_BOOK_AND_APPT'] !='Unknown / Data Issue')
                                ]['COUNT_OF_APPOINTMENTS']

f2f_attended_tmp = dataframe[(dataframe['APPT_STATUS'] == 'Attended') 
                            & (dataframe['APPT_MODE'] == 'Face-to-Face')
                            & (dataframe['TIME_BETWEEN_BOOK_AND_APPT'] !='More than 28 Days')
                            & (dataframe['TIME_BETWEEN_BOOK_AND_APPT'] !='Unknown / Data Issue')                    
                            ]['COUNT_OF_APPOINTMENTS']

f2f_dna_tmp = dataframe[(dataframe['APPT_STATUS'] == 'DNA') 
                        & (dataframe['APPT_MODE'] == 'Face-to-Face') 
                        & (dataframe['TIME_BETWEEN_BOOK_AND_APPT'] !='More than 28 Days')
                        & (dataframe['TIME_BETWEEN_BOOK_AND_APPT'] !='Unknown / Data Issue')
                        ]['COUNT_OF_APPOINTMENTS']

# drop na

remote_attended_tmp = remote_attended_tmp.dropna()
remote_dna_tmp = remote_dna_tmp.dropna()
f2f_attended_tmp = f2f_attended_tmp.dropna()
f2f_dna_tmp = f2f_attended_tmp.dropna()

#count, min, max, 5th, 10th, 25th, 50th, 75th, 90th, 95th
print('-------------------------------------------------')
print('Data description of attended remote consultation in 2021/02:')
print(remote_attended_tmp[['CCG_NAME', 'Appointment_Date', 'COUNT_OF_APPOINTMENTS']]
      .describe(percentiles=[.05, .10, .25, .50, .75, .90, .95]))
print('-------------------------------------------------')
print('Minimum:')
print(remote_attended_tmp[['CCG_NAME', 'Appointment_Date', 'COUNT_OF_APPOINTMENTS']].min())
print('-------------------------------------------------')
print('Maximum:')
print(remote_attended_tmp[['CCG_NAME', 'Appointment_Date', 'COUNT_OF_APPOINTMENTS']].max())
print('-------------------------------------------------')
# Out:
# -------------------------------------------------
# Data description of attended remote consultation in 2021/02:
#        COUNT_OF_APPOINTMENTS
# count           40513.000000
# mean              226.320045
# std               648.444934
# min                 1.000000
# 5%                  1.000000
# 10%                 2.000000
# 25%                 6.000000
# 50%                31.000000
# 75%               153.000000
# 90%               547.000000
# 95%              1055.000000
# max             10697.000000
# -------------------------------------------------
# Minimum:
# CCG_NAME                 NHS Barnsley CCG
# Appointment_Date                01FEB2021
# COUNT_OF_APPOINTMENTS                   1
# dtype: object
# -------------------------------------------------
# Maximum:
# CCG_NAME                 NHS Wirral CCG
# Appointment_Date              28FEB2021
# COUNT_OF_APPOINTMENTS             10697
# dtype: object
# -------------------------------------------------

# %% [markdown]
# # Month/Year: 03/2021
#
# Exclusion:
#
#             1. Home Visit & Unknown
#             2. More than 28 Days & Unknown / Data Issue

# %%
csv_name = 'CCG_CSV_Mar_21.csv'
file_path = folder_path + csv_name
dataframe = pd.read_csv(file_path)
dataframe.drop('CCG_CODE', axis=1, inplace=True)
dataframe.drop('CCG_ONS_CODE', axis=1, inplace=True)
dataframe.drop('STP_ONS_CODE', axis=1, inplace=True)
dataframe.drop('HCP_TYPE', axis=1, inplace=True)
dataframe.drop('REGION_ONS_CODE', axis=1, inplace=True)

# %% [markdown]
# ## Data filtering & Analysis

# %%
# dna: did not attend
# f2f: face-to-face
# remote: Video Conference/Online & Telephone

remote_attended_tmp = dataframe[(dataframe['APPT_STATUS'] == 'Attended') 
                                & (dataframe['APPT_MODE'] != 'Home Visit') 
                                & (dataframe['APPT_MODE'] != 'Face-to-Face') 
                                & (dataframe['APPT_MODE'] != 'Unknown') 
                                & (dataframe['TIME_BETWEEN_BOOK_AND_APPT'] !='More than 28 Days')
                                & (dataframe['TIME_BETWEEN_BOOK_AND_APPT'] !='Unknown / Data Issue')
                                ]

remote_dna_tmp = dataframe[(dataframe['APPT_STATUS'] == 'DNA') 
                                & (dataframe['APPT_MODE'] != 'Home Visit') 
                                & (dataframe['APPT_MODE'] != 'Face-to-Face') 
                                & (dataframe['APPT_MODE'] != 'Unknown') 
                                & (dataframe['TIME_BETWEEN_BOOK_AND_APPT'] !='More than 28 Days')
                                & (dataframe['TIME_BETWEEN_BOOK_AND_APPT'] !='Unknown / Data Issue')
                                ]['COUNT_OF_APPOINTMENTS']

f2f_attended_tmp = dataframe[(dataframe['APPT_STATUS'] == 'Attended') 
                            & (dataframe['APPT_MODE'] == 'Face-to-Face')
                            & (dataframe['TIME_BETWEEN_BOOK_AND_APPT'] !='More than 28 Days')
                            & (dataframe['TIME_BETWEEN_BOOK_AND_APPT'] !='Unknown / Data Issue')                    
                            ]['COUNT_OF_APPOINTMENTS']

f2f_dna_tmp = dataframe[(dataframe['APPT_STATUS'] == 'DNA') 
                        & (dataframe['APPT_MODE'] == 'Face-to-Face') 
                        & (dataframe['TIME_BETWEEN_BOOK_AND_APPT'] !='More than 28 Days')
                        & (dataframe['TIME_BETWEEN_BOOK_AND_APPT'] !='Unknown / Data Issue')
                        ]['COUNT_OF_APPOINTMENTS']

# drop na

remote_attended_tmp = remote_attended_tmp.dropna()
remote_dna_tmp = remote_dna_tmp.dropna()
f2f_attended_tmp = f2f_attended_tmp.dropna()
f2f_dna_tmp = f2f_attended_tmp.dropna()

#count, min, max, 5th, 10th, 25th, 50th, 75th, 90th, 95th
print('-------------------------------------------------')
print('Data description of attended remote consultation in 2021/03:')
print(remote_attended_tmp[['CCG_NAME', 'Appointment_Date', 'COUNT_OF_APPOINTMENTS']]
      .describe(percentiles=[.05, .10, .25, .50, .75, .90, .95]))
print('-------------------------------------------------')
print('Minimum:')
print(remote_attended_tmp[['CCG_NAME', 'Appointment_Date', 'COUNT_OF_APPOINTMENTS']].min())
print('-------------------------------------------------')
print('Maximum:')
print(remote_attended_tmp[['CCG_NAME', 'Appointment_Date', 'COUNT_OF_APPOINTMENTS']].max())
print('-------------------------------------------------')
# Out:
# -------------------------------------------------
# Data description of attended remote consultation in 2021/03:
#        COUNT_OF_APPOINTMENTS
# count           46769.000000
# mean              233.654023
# std               645.576611
# min                 1.000000
# 5%                  1.000000
# 10%                 2.000000
# 25%                 6.000000
# 50%                35.000000
# 75%               167.000000
# 90%               572.000000
# 95%              1074.000000
# max             10172.000000
# -------------------------------------------------
# Minimum:
# CCG_NAME                 NHS Barnsley CCG
# Appointment_Date                01MAR2021
# COUNT_OF_APPOINTMENTS                   1
# dtype: object
# -------------------------------------------------
# Maximum:
# CCG_NAME                 NHS Wirral CCG
# Appointment_Date              31MAR2021
# COUNT_OF_APPOINTMENTS             10172
# dtype: object
# -------------------------------------------------

# %% [markdown]
# # Month/Year: 04/2021
#
# Exclusion:
#
#             1. Home Visit & Unknown
#             2. More than 28 Days & Unknown / Data Issue

# %%
csv_name = 'CCG_CSV_Apr_21.csv'
file_path = folder_path + csv_name
dataframe = pd.read_csv(file_path)
dataframe.drop('CCG_CODE', axis=1, inplace=True)
dataframe.drop('CCG_ONS_CODE', axis=1, inplace=True)
dataframe.drop('STP_ONS_CODE', axis=1, inplace=True)
dataframe.drop('HCP_TYPE', axis=1, inplace=True)
dataframe.drop('REGION_ONS_CODE', axis=1, inplace=True)

# %% [markdown]
# ## Data filtering & Analysis

# %%
# dna: did not attend
# f2f: face-to-face
# remote: Video Conference/Online & Telephone

remote_attended_tmp = dataframe[(dataframe['APPT_STATUS'] == 'Attended') 
                                & (dataframe['APPT_MODE'] != 'Home Visit') 
                                & (dataframe['APPT_MODE'] != 'Face-to-Face') 
                                & (dataframe['APPT_MODE'] != 'Unknown') 
                                & (dataframe['TIME_BETWEEN_BOOK_AND_APPT'] !='More than 28 Days')
                                & (dataframe['TIME_BETWEEN_BOOK_AND_APPT'] !='Unknown / Data Issue')
                                ]

remote_dna_tmp = dataframe[(dataframe['APPT_STATUS'] == 'DNA') 
                                & (dataframe['APPT_MODE'] != 'Home Visit') 
                                & (dataframe['APPT_MODE'] != 'Face-to-Face') 
                                & (dataframe['APPT_MODE'] != 'Unknown') 
                                & (dataframe['TIME_BETWEEN_BOOK_AND_APPT'] !='More than 28 Days')
                                & (dataframe['TIME_BETWEEN_BOOK_AND_APPT'] !='Unknown / Data Issue')
                                ]['COUNT_OF_APPOINTMENTS']

f2f_attended_tmp = dataframe[(dataframe['APPT_STATUS'] == 'Attended') 
                            & (dataframe['APPT_MODE'] == 'Face-to-Face')
                            & (dataframe['TIME_BETWEEN_BOOK_AND_APPT'] !='More than 28 Days')
                            & (dataframe['TIME_BETWEEN_BOOK_AND_APPT'] !='Unknown / Data Issue')                    
                            ]['COUNT_OF_APPOINTMENTS']

f2f_dna_tmp = dataframe[(dataframe['APPT_STATUS'] == 'DNA') 
                        & (dataframe['APPT_MODE'] == 'Face-to-Face') 
                        & (dataframe['TIME_BETWEEN_BOOK_AND_APPT'] !='More than 28 Days')
                        & (dataframe['TIME_BETWEEN_BOOK_AND_APPT'] !='Unknown / Data Issue')
                        ]['COUNT_OF_APPOINTMENTS']

# drop na

remote_attended_tmp = remote_attended_tmp.dropna()
remote_dna_tmp = remote_dna_tmp.dropna()
f2f_attended_tmp = f2f_attended_tmp.dropna()
f2f_dna_tmp = f2f_attended_tmp.dropna()

#count, min, max, 5th, 10th, 25th, 50th, 75th, 90th, 95th
print('-------------------------------------------------')
print('Data description of attended remote consultation in 2021/04:')
print(remote_attended_tmp[['CCG_NAME', 'Appointment_Date', 'COUNT_OF_APPOINTMENTS']]
      .describe(percentiles=[.05, .10, .25, .50, .75, .90, .95]))
print('-------------------------------------------------')
print('Minimum:')
print(remote_attended_tmp[['CCG_NAME', 'Appointment_Date', 'COUNT_OF_APPOINTMENTS']].min())
print('-------------------------------------------------')
print('Maximum:')
print(remote_attended_tmp[['CCG_NAME', 'Appointment_Date', 'COUNT_OF_APPOINTMENTS']].max())
print('-------------------------------------------------')
# Out:
# -------------------------------------------------
# Data description of attended remote consultation in 2021/04:
#        COUNT_OF_APPOINTMENTS
# count           41189.000000
# mean              224.616937
# std               618.017760
# min                 1.000000
# 5%                  1.000000
# 10%                 2.000000
# 25%                 6.000000
# 50%                39.000000
# 75%               166.000000
# 90%               529.000000
# 95%              1019.000000
# max              9670.000000
# -------------------------------------------------
# Minimum:
# CCG_NAME                 NHS Barnsley CCG
# Appointment_Date                01APR2021
# COUNT_OF_APPOINTMENTS                   1
# dtype: object
# -------------------------------------------------
# Maximum:
# CCG_NAME                 NHS Wirral CCG
# Appointment_Date              30APR2021
# COUNT_OF_APPOINTMENTS              9670
# dtype: object
# -------------------------------------------------

# %% [markdown]
# # Month/Year: 05/2021
#
# Exclusion:
#
#             1. Home Visit & Unknown
#             2. More than 28 Days & Unknown / Data Issue

# %%
csv_name = 'CCG_CSV_May_21.csv'
file_path = folder_path + csv_name
dataframe = pd.read_csv(file_path)
dataframe.drop('CCG_CODE', axis=1, inplace=True)
dataframe.drop('CCG_ONS_CODE', axis=1, inplace=True)
dataframe.drop('STP_ONS_CODE', axis=1, inplace=True)
dataframe.drop('HCP_TYPE', axis=1, inplace=True)
dataframe.drop('REGION_ONS_CODE', axis=1, inplace=True)

# %% [markdown]
# ## Data filtering & Analysis

# %%
# dna: did not attend
# f2f: face-to-face
# remote: Video Conference/Online & Telephone

remote_attended_tmp = dataframe[(dataframe['APPT_STATUS'] == 'Attended') 
                                & (dataframe['APPT_MODE'] != 'Home Visit') 
                                & (dataframe['APPT_MODE'] != 'Face-to-Face') 
                                & (dataframe['APPT_MODE'] != 'Unknown') 
                                & (dataframe['TIME_BETWEEN_BOOK_AND_APPT'] !='More than 28 Days')
                                & (dataframe['TIME_BETWEEN_BOOK_AND_APPT'] !='Unknown / Data Issue')
                                ]

remote_dna_tmp = dataframe[(dataframe['APPT_STATUS'] == 'DNA') 
                                & (dataframe['APPT_MODE'] != 'Home Visit') 
                                & (dataframe['APPT_MODE'] != 'Face-to-Face') 
                                & (dataframe['APPT_MODE'] != 'Unknown') 
                                & (dataframe['TIME_BETWEEN_BOOK_AND_APPT'] !='More than 28 Days')
                                & (dataframe['TIME_BETWEEN_BOOK_AND_APPT'] !='Unknown / Data Issue')
                                ]['COUNT_OF_APPOINTMENTS']

f2f_attended_tmp = dataframe[(dataframe['APPT_STATUS'] == 'Attended') 
                            & (dataframe['APPT_MODE'] == 'Face-to-Face')
                            & (dataframe['TIME_BETWEEN_BOOK_AND_APPT'] !='More than 28 Days')
                            & (dataframe['TIME_BETWEEN_BOOK_AND_APPT'] !='Unknown / Data Issue')                    
                            ]['COUNT_OF_APPOINTMENTS']

f2f_dna_tmp = dataframe[(dataframe['APPT_STATUS'] == 'DNA') 
                        & (dataframe['APPT_MODE'] == 'Face-to-Face') 
                        & (dataframe['TIME_BETWEEN_BOOK_AND_APPT'] !='More than 28 Days')
                        & (dataframe['TIME_BETWEEN_BOOK_AND_APPT'] !='Unknown / Data Issue')
                        ]['COUNT_OF_APPOINTMENTS']

# drop na

remote_attended_tmp = remote_attended_tmp.dropna()
remote_dna_tmp = remote_dna_tmp.dropna()
f2f_attended_tmp = f2f_attended_tmp.dropna()
f2f_dna_tmp = f2f_attended_tmp.dropna()

#count, min, max, 5th, 10th, 25th, 50th, 75th, 90th, 95th
print('-------------------------------------------------')
print('Data description of attended remote consultation in 2021/05:')
print(remote_attended_tmp[['CCG_NAME', 'Appointment_Date', 'COUNT_OF_APPOINTMENTS']]
      .describe(percentiles=[.05, .10, .25, .50, .75, .90, .95]))
print('-------------------------------------------------')
print('Minimum:')
print(remote_attended_tmp[['CCG_NAME', 'Appointment_Date', 'COUNT_OF_APPOINTMENTS']].min())
print('-------------------------------------------------')
print('Maximum:')
print(remote_attended_tmp[['CCG_NAME', 'Appointment_Date', 'COUNT_OF_APPOINTMENTS']].max())
print('-------------------------------------------------')
# Out:
# -------------------------------------------------
# Data description of attended remote consultation in 2021/05:
#        COUNT_OF_APPOINTMENTS
# count           40330.000000
# mean              223.665162
# std               618.301737
# min                 1.000000
# 5%                  1.000000
# 10%                 2.000000
# 25%                 6.000000
# 50%                37.000000
# 75%               165.000000
# 90%               532.000000
# 95%               999.000000
# max              9807.000000
# -------------------------------------------------
# Minimum:
# CCG_NAME                 NHS Barnsley CCG
# Appointment_Date                01MAY2021
# COUNT_OF_APPOINTMENTS                   1
# dtype: object
# -------------------------------------------------
# Maximum:
# CCG_NAME                 NHS Wirral CCG
# Appointment_Date              31MAY2021
# COUNT_OF_APPOINTMENTS              9807
# dtype: object
# -------------------------------------------------

# %% [markdown]
# # Month/Year: 06/2021
#
# Exclusion:
#
#             1. Home Visit & Unknown
#             2. More than 28 Days & Unknown / Data Issue

# %%
csv_name = 'CCG_CSV_Jun_21.csv'
file_path = folder_path + csv_name
dataframe = pd.read_csv(file_path)
dataframe.drop('CCG_CODE', axis=1, inplace=True)
dataframe.drop('CCG_ONS_CODE', axis=1, inplace=True)
dataframe.drop('STP_ONS_CODE', axis=1, inplace=True)
dataframe.drop('HCP_TYPE', axis=1, inplace=True)
dataframe.drop('REGION_ONS_CODE', axis=1, inplace=True)

# %% [markdown]
# ## Data filtering & Analysis

# %%
# dna: did not attend
# f2f: face-to-face
# remote: Video Conference/Online & Telephone

remote_attended_tmp = dataframe[(dataframe['APPT_STATUS'] == 'Attended') 
                                & (dataframe['APPT_MODE'] != 'Home Visit') 
                                & (dataframe['APPT_MODE'] != 'Face-to-Face') 
                                & (dataframe['APPT_MODE'] != 'Unknown') 
                                & (dataframe['TIME_BETWEEN_BOOK_AND_APPT'] !='More than 28 Days')
                                & (dataframe['TIME_BETWEEN_BOOK_AND_APPT'] !='Unknown / Data Issue')
                                ]

remote_dna_tmp = dataframe[(dataframe['APPT_STATUS'] == 'DNA') 
                                & (dataframe['APPT_MODE'] != 'Home Visit') 
                                & (dataframe['APPT_MODE'] != 'Face-to-Face') 
                                & (dataframe['APPT_MODE'] != 'Unknown') 
                                & (dataframe['TIME_BETWEEN_BOOK_AND_APPT'] !='More than 28 Days')
                                & (dataframe['TIME_BETWEEN_BOOK_AND_APPT'] !='Unknown / Data Issue')
                                ]['COUNT_OF_APPOINTMENTS']

f2f_attended_tmp = dataframe[(dataframe['APPT_STATUS'] == 'Attended') 
                            & (dataframe['APPT_MODE'] == 'Face-to-Face')
                            & (dataframe['TIME_BETWEEN_BOOK_AND_APPT'] !='More than 28 Days')
                            & (dataframe['TIME_BETWEEN_BOOK_AND_APPT'] !='Unknown / Data Issue')                    
                            ]['COUNT_OF_APPOINTMENTS']

f2f_dna_tmp = dataframe[(dataframe['APPT_STATUS'] == 'DNA') 
                        & (dataframe['APPT_MODE'] == 'Face-to-Face') 
                        & (dataframe['TIME_BETWEEN_BOOK_AND_APPT'] !='More than 28 Days')
                        & (dataframe['TIME_BETWEEN_BOOK_AND_APPT'] !='Unknown / Data Issue')
                        ]['COUNT_OF_APPOINTMENTS']

# drop na

remote_attended_tmp = remote_attended_tmp.dropna()
remote_dna_tmp = remote_dna_tmp.dropna()
f2f_attended_tmp = f2f_attended_tmp.dropna()
f2f_dna_tmp = f2f_attended_tmp.dropna()

#count, min, max, 5th, 10th, 25th, 50th, 75th, 90th, 95th
print('-------------------------------------------------')
print('Data description of attended remote consultation in 2021/06:')
print(remote_attended_tmp[['CCG_NAME', 'Appointment_Date', 'COUNT_OF_APPOINTMENTS']]
      .describe(percentiles=[.05, .10, .25, .50, .75, .90, .95]))
print('-------------------------------------------------')
print('Minimum:')
print(remote_attended_tmp[['CCG_NAME', 'Appointment_Date', 'COUNT_OF_APPOINTMENTS']].min())
print('-------------------------------------------------')
print('Maximum:')
print(remote_attended_tmp[['CCG_NAME', 'Appointment_Date', 'COUNT_OF_APPOINTMENTS']].max())
print('-------------------------------------------------')
# Out:
# -------------------------------------------------
# Data description of attended remote consultation in 2021/06:
#        COUNT_OF_APPOINTMENTS
# count           45375.000000
# mean              222.632375
# std               613.230332
# min                 1.000000
# 5%                  1.000000
# 10%                 2.000000
# 25%                 6.000000
# 50%                41.000000
# 75%               166.000000
# 90%               519.000000
# 95%               994.300000
# max              9576.000000
# -------------------------------------------------
# Minimum:
# CCG_NAME                 NHS Barnsley CCG
# Appointment_Date                01JUN2021
# COUNT_OF_APPOINTMENTS                   1
# dtype: object
# -------------------------------------------------
# Maximum:
# CCG_NAME                 NHS Wirral CCG
# Appointment_Date              30JUN2021
# COUNT_OF_APPOINTMENTS              9576
# dtype: object
# -------------------------------------------------

# %% [markdown]
# # Month/Year: 07/2021
#
# Exclusion:
#
#             1. Home Visit & Unknown
#             2. More than 28 Days & Unknown / Data Issue

# %%
csv_name = 'CCG_CSV_Jul_21.csv'
file_path = folder_path + csv_name
dataframe = pd.read_csv(file_path)
dataframe.drop('CCG_CODE', axis=1, inplace=True)
dataframe.drop('CCG_ONS_CODE', axis=1, inplace=True)
dataframe.drop('STP_ONS_CODE', axis=1, inplace=True)
dataframe.drop('HCP_TYPE', axis=1, inplace=True)
dataframe.drop('REGION_ONS_CODE', axis=1, inplace=True)

# %% [markdown]
# ## Data filtering & Analysis

# %%
# dna: did not attend
# f2f: face-to-face
# remote: Video Conference/Online & Telephone

remote_attended_tmp = dataframe[(dataframe['APPT_STATUS'] == 'Attended') 
                                & (dataframe['APPT_MODE'] != 'Home Visit') 
                                & (dataframe['APPT_MODE'] != 'Face-to-Face') 
                                & (dataframe['APPT_MODE'] != 'Unknown') 
                                & (dataframe['TIME_BETWEEN_BOOK_AND_APPT'] !='More than 28 Days')
                                & (dataframe['TIME_BETWEEN_BOOK_AND_APPT'] !='Unknown / Data Issue')
                                ]

remote_dna_tmp = dataframe[(dataframe['APPT_STATUS'] == 'DNA') 
                                & (dataframe['APPT_MODE'] != 'Home Visit') 
                                & (dataframe['APPT_MODE'] != 'Face-to-Face') 
                                & (dataframe['APPT_MODE'] != 'Unknown') 
                                & (dataframe['TIME_BETWEEN_BOOK_AND_APPT'] !='More than 28 Days')
                                & (dataframe['TIME_BETWEEN_BOOK_AND_APPT'] !='Unknown / Data Issue')
                                ]['COUNT_OF_APPOINTMENTS']

f2f_attended_tmp = dataframe[(dataframe['APPT_STATUS'] == 'Attended') 
                            & (dataframe['APPT_MODE'] == 'Face-to-Face')
                            & (dataframe['TIME_BETWEEN_BOOK_AND_APPT'] !='More than 28 Days')
                            & (dataframe['TIME_BETWEEN_BOOK_AND_APPT'] !='Unknown / Data Issue')                    
                            ]['COUNT_OF_APPOINTMENTS']

f2f_dna_tmp = dataframe[(dataframe['APPT_STATUS'] == 'DNA') 
                        & (dataframe['APPT_MODE'] == 'Face-to-Face') 
                        & (dataframe['TIME_BETWEEN_BOOK_AND_APPT'] !='More than 28 Days')
                        & (dataframe['TIME_BETWEEN_BOOK_AND_APPT'] !='Unknown / Data Issue')
                        ]['COUNT_OF_APPOINTMENTS']

# drop na

remote_attended_tmp = remote_attended_tmp.dropna()
remote_dna_tmp = remote_dna_tmp.dropna()
f2f_attended_tmp = f2f_attended_tmp.dropna()
f2f_dna_tmp = f2f_attended_tmp.dropna()

#count, min, max, 5th, 10th, 25th, 50th, 75th, 90th, 95th
print('-------------------------------------------------')
print('Data description of attended remote consultation in 2021/07:')
print(remote_attended_tmp[['CCG_NAME', 'Appointment_Date', 'COUNT_OF_APPOINTMENTS']]
      .describe(percentiles=[.05, .10, .25, .50, .75, .90, .95]))
print('-------------------------------------------------')
print('Minimum:')
print(remote_attended_tmp[['CCG_NAME', 'Appointment_Date', 'COUNT_OF_APPOINTMENTS']].min())
print('-------------------------------------------------')
print('Maximum:')
print(remote_attended_tmp[['CCG_NAME', 'Appointment_Date', 'COUNT_OF_APPOINTMENTS']].max())
print('-------------------------------------------------')
# Out:
# -------------------------------------------------
# Data description of attended remote consultation in 2021/07:
#        COUNT_OF_APPOINTMENTS
# count           45928.000000
# mean              208.145489
# std               574.867897
# min                 1.000000
# 5%                  1.000000
# 10%                 2.000000
# 25%                 6.000000
# 50%                39.000000
# 75%               153.000000
# 90%               488.000000
# 95%               925.000000
# max              9259.000000
# -------------------------------------------------
# Minimum:
# CCG_NAME                 NHS Barnsley CCG
# Appointment_Date                01JUL2021
# COUNT_OF_APPOINTMENTS                   1
# dtype: object
# -------------------------------------------------
# Maximum:
# CCG_NAME                 NHS Wirral CCG
# Appointment_Date              31JUL2021
# COUNT_OF_APPOINTMENTS              9259
# dtype: object
# -------------------------------------------------

# %% [markdown]
# # Month/Year: 08/2021
#
# Exclusion:
#
#             1. Home Visit & Unknown
#             2. More than 28 Days & Unknown / Data Issue

# %%
csv_name = 'CCG_CSV_Aug_21.csv'
file_path = folder_path + csv_name
dataframe = pd.read_csv(file_path)
dataframe.drop('CCG_CODE', axis=1, inplace=True)
dataframe.drop('CCG_ONS_CODE', axis=1, inplace=True)
dataframe.drop('STP_ONS_CODE', axis=1, inplace=True)
dataframe.drop('HCP_TYPE', axis=1, inplace=True)
dataframe.drop('REGION_ONS_CODE', axis=1, inplace=True)

# %% [markdown]
# ## Data filtering & Analysis

# %%
# dna: did not attend
# f2f: face-to-face
# remote: Video Conference/Online & Telephone

remote_attended_tmp = dataframe[(dataframe['APPT_STATUS'] == 'Attended') 
                                & (dataframe['APPT_MODE'] != 'Home Visit') 
                                & (dataframe['APPT_MODE'] != 'Face-to-Face') 
                                & (dataframe['APPT_MODE'] != 'Unknown') 
                                & (dataframe['TIME_BETWEEN_BOOK_AND_APPT'] !='More than 28 Days')
                                & (dataframe['TIME_BETWEEN_BOOK_AND_APPT'] !='Unknown / Data Issue')
                                ]

remote_dna_tmp = dataframe[(dataframe['APPT_STATUS'] == 'DNA') 
                                & (dataframe['APPT_MODE'] != 'Home Visit') 
                                & (dataframe['APPT_MODE'] != 'Face-to-Face') 
                                & (dataframe['APPT_MODE'] != 'Unknown') 
                                & (dataframe['TIME_BETWEEN_BOOK_AND_APPT'] !='More than 28 Days')
                                & (dataframe['TIME_BETWEEN_BOOK_AND_APPT'] !='Unknown / Data Issue')
                                ]['COUNT_OF_APPOINTMENTS']

f2f_attended_tmp = dataframe[(dataframe['APPT_STATUS'] == 'Attended') 
                            & (dataframe['APPT_MODE'] == 'Face-to-Face')
                            & (dataframe['TIME_BETWEEN_BOOK_AND_APPT'] !='More than 28 Days')
                            & (dataframe['TIME_BETWEEN_BOOK_AND_APPT'] !='Unknown / Data Issue')                    
                            ]['COUNT_OF_APPOINTMENTS']

f2f_dna_tmp = dataframe[(dataframe['APPT_STATUS'] == 'DNA') 
                        & (dataframe['APPT_MODE'] == 'Face-to-Face') 
                        & (dataframe['TIME_BETWEEN_BOOK_AND_APPT'] !='More than 28 Days')
                        & (dataframe['TIME_BETWEEN_BOOK_AND_APPT'] !='Unknown / Data Issue')
                        ]['COUNT_OF_APPOINTMENTS']

# drop na

remote_attended_tmp = remote_attended_tmp.dropna()
remote_dna_tmp = remote_dna_tmp.dropna()
f2f_attended_tmp = f2f_attended_tmp.dropna()
f2f_dna_tmp = f2f_attended_tmp.dropna()

#count, min, max, 5th, 10th, 25th, 50th, 75th, 90th, 95th
print('-------------------------------------------------')
print('Data description of attended remote consultation in 2021/08:')
print(remote_attended_tmp[['CCG_NAME', 'Appointment_Date', 'COUNT_OF_APPOINTMENTS']]
      .describe(percentiles=[.05, .10, .25, .50, .75, .90, .95]))
print('-------------------------------------------------')
print('Minimum:')
print(remote_attended_tmp[['CCG_NAME', 'Appointment_Date', 'COUNT_OF_APPOINTMENTS']].min())
print('-------------------------------------------------')
print('Maximum:')
print(remote_attended_tmp[['CCG_NAME', 'Appointment_Date', 'COUNT_OF_APPOINTMENTS']].max())
print('-------------------------------------------------')
# Out:
# -------------------------------------------------
# Data description of attended remote consultation in 2021/08:
#        COUNT_OF_APPOINTMENTS
# count           43587.000000
# mean              199.421227
# std               561.798911
# min                 1.000000
# 5%                  1.000000
# 10%                 2.000000
# 25%                 6.000000
# 50%                37.000000
# 75%               143.000000
# 90%               457.000000
# 95%               876.000000
# max              8745.000000
# -------------------------------------------------
# Minimum:
# CCG_NAME                 NHS Barnsley CCG
# Appointment_Date                01AUG2021
# COUNT_OF_APPOINTMENTS                   1
# dtype: object
# -------------------------------------------------
# Maximum:
# CCG_NAME                 NHS Wirral CCG
# Appointment_Date              31AUG2021
# COUNT_OF_APPOINTMENTS              8745
# dtype: object
# -------------------------------------------------

# %% [markdown]
# # Month/Year: 09/2021
#
# Exclusion:
#
#             1. Home Visit & Unknown
#             2. More than 28 Days & Unknown / Data Issue

# %%
csv_name = 'CCG_CSV_Sep_21.csv'
file_path = folder_path + csv_name
dataframe = pd.read_csv(file_path)
dataframe.drop('CCG_CODE', axis=1, inplace=True)
dataframe.drop('CCG_ONS_CODE', axis=1, inplace=True)
dataframe.drop('STP_ONS_CODE', axis=1, inplace=True)
dataframe.drop('HCP_TYPE', axis=1, inplace=True)
dataframe.drop('REGION_ONS_CODE', axis=1, inplace=True)

# %% [markdown]
# ## Data filtering & Analysis

# %%
# dna: did not attend
# f2f: face-to-face
# remote: Video Conference/Online & Telephone

remote_attended_tmp = dataframe[(dataframe['APPT_STATUS'] == 'Attended') 
                                & (dataframe['APPT_MODE'] != 'Home Visit') 
                                & (dataframe['APPT_MODE'] != 'Face-to-Face') 
                                & (dataframe['APPT_MODE'] != 'Unknown') 
                                & (dataframe['TIME_BETWEEN_BOOK_AND_APPT'] !='More than 28 Days')
                                & (dataframe['TIME_BETWEEN_BOOK_AND_APPT'] !='Unknown / Data Issue')
                                ]

remote_dna_tmp = dataframe[(dataframe['APPT_STATUS'] == 'DNA') 
                                & (dataframe['APPT_MODE'] != 'Home Visit') 
                                & (dataframe['APPT_MODE'] != 'Face-to-Face') 
                                & (dataframe['APPT_MODE'] != 'Unknown') 
                                & (dataframe['TIME_BETWEEN_BOOK_AND_APPT'] !='More than 28 Days')
                                & (dataframe['TIME_BETWEEN_BOOK_AND_APPT'] !='Unknown / Data Issue')
                                ]['COUNT_OF_APPOINTMENTS']

f2f_attended_tmp = dataframe[(dataframe['APPT_STATUS'] == 'Attended') 
                            & (dataframe['APPT_MODE'] == 'Face-to-Face')
                            & (dataframe['TIME_BETWEEN_BOOK_AND_APPT'] !='More than 28 Days')
                            & (dataframe['TIME_BETWEEN_BOOK_AND_APPT'] !='Unknown / Data Issue')                    
                            ]['COUNT_OF_APPOINTMENTS']

f2f_dna_tmp = dataframe[(dataframe['APPT_STATUS'] == 'DNA') 
                        & (dataframe['APPT_MODE'] == 'Face-to-Face') 
                        & (dataframe['TIME_BETWEEN_BOOK_AND_APPT'] !='More than 28 Days')
                        & (dataframe['TIME_BETWEEN_BOOK_AND_APPT'] !='Unknown / Data Issue')
                        ]['COUNT_OF_APPOINTMENTS']

# drop na

remote_attended_tmp = remote_attended_tmp.dropna()
remote_dna_tmp = remote_dna_tmp.dropna()
f2f_attended_tmp = f2f_attended_tmp.dropna()
f2f_dna_tmp = f2f_attended_tmp.dropna()

#count, min, max, 5th, 10th, 25th, 50th, 75th, 90th, 95th
print('-------------------------------------------------')
print('Data description of attended remote consultation in 2021/09:')
print(remote_attended_tmp[['CCG_NAME', 'Appointment_Date', 'COUNT_OF_APPOINTMENTS']]
      .describe(percentiles=[.05, .10, .25, .50, .75, .90, .95]))
print('-------------------------------------------------')
print('Minimum:')
print(remote_attended_tmp[['CCG_NAME', 'Appointment_Date', 'COUNT_OF_APPOINTMENTS']].min())
print('-------------------------------------------------')
print('Maximum:')
print(remote_attended_tmp[['CCG_NAME', 'Appointment_Date', 'COUNT_OF_APPOINTMENTS']].max())
print('-------------------------------------------------')
# Out:
# -------------------------------------------------
# Data description of attended remote consultation in 2021/09:
#        COUNT_OF_APPOINTMENTS
# count           46217.000000
# mean              206.585542
# std               575.603662
# min                 1.000000
# 5%                  1.000000
# 10%                 2.000000
# 25%                 6.000000
# 50%                39.000000
# 75%               150.000000
# 90%               478.000000
# 95%               912.000000
# max              9051.000000
# -------------------------------------------------
# Minimum:
# CCG_NAME                 NHS Barnsley CCG
# Appointment_Date                01SEP2021
# COUNT_OF_APPOINTMENTS                   1
# dtype: object
# -------------------------------------------------
# Maximum:
# CCG_NAME                 NHS Wirral CCG
# Appointment_Date              30SEP2021
# COUNT_OF_APPOINTMENTS              9051
# dtype: object
# -------------------------------------------------

# %% [markdown]
# # Month/Year: 10/2021
#
# Exclusion:
#
#             1. Home Visit & Unknown
#             2. More than 28 Days & Unknown / Data Issue

# %%
csv_name = 'CCG_CSV_Oct_21.csv'
file_path = folder_path + csv_name
dataframe = pd.read_csv(file_path)
dataframe.drop('CCG_CODE', axis=1, inplace=True)
dataframe.drop('CCG_ONS_CODE', axis=1, inplace=True)
dataframe.drop('STP_ONS_CODE', axis=1, inplace=True)
dataframe.drop('HCP_TYPE', axis=1, inplace=True)
dataframe.drop('REGION_ONS_CODE', axis=1, inplace=True)

# %% [markdown]
# ## Data filtering & Analysis

# %%
# dna: did not attend
# f2f: face-to-face
# remote: Video Conference/Online & Telephone

remote_attended_tmp = dataframe[(dataframe['APPT_STATUS'] == 'Attended') 
                                & (dataframe['APPT_MODE'] != 'Home Visit') 
                                & (dataframe['APPT_MODE'] != 'Face-to-Face') 
                                & (dataframe['APPT_MODE'] != 'Unknown') 
                                & (dataframe['TIME_BETWEEN_BOOK_AND_APPT'] !='More than 28 Days')
                                & (dataframe['TIME_BETWEEN_BOOK_AND_APPT'] !='Unknown / Data Issue')
                                ]

remote_dna_tmp = dataframe[(dataframe['APPT_STATUS'] == 'DNA') 
                                & (dataframe['APPT_MODE'] != 'Home Visit') 
                                & (dataframe['APPT_MODE'] != 'Face-to-Face') 
                                & (dataframe['APPT_MODE'] != 'Unknown') 
                                & (dataframe['TIME_BETWEEN_BOOK_AND_APPT'] !='More than 28 Days')
                                & (dataframe['TIME_BETWEEN_BOOK_AND_APPT'] !='Unknown / Data Issue')
                                ]['COUNT_OF_APPOINTMENTS']

f2f_attended_tmp = dataframe[(dataframe['APPT_STATUS'] == 'Attended') 
                            & (dataframe['APPT_MODE'] == 'Face-to-Face')
                            & (dataframe['TIME_BETWEEN_BOOK_AND_APPT'] !='More than 28 Days')
                            & (dataframe['TIME_BETWEEN_BOOK_AND_APPT'] !='Unknown / Data Issue')                    
                            ]['COUNT_OF_APPOINTMENTS']

f2f_dna_tmp = dataframe[(dataframe['APPT_STATUS'] == 'DNA') 
                        & (dataframe['APPT_MODE'] == 'Face-to-Face') 
                        & (dataframe['TIME_BETWEEN_BOOK_AND_APPT'] !='More than 28 Days')
                        & (dataframe['TIME_BETWEEN_BOOK_AND_APPT'] !='Unknown / Data Issue')
                        ]['COUNT_OF_APPOINTMENTS']

# drop na

remote_attended_tmp = remote_attended_tmp.dropna()
remote_dna_tmp = remote_dna_tmp.dropna()
f2f_attended_tmp = f2f_attended_tmp.dropna()
f2f_dna_tmp = f2f_attended_tmp.dropna()

#count, min, max, 5th, 10th, 25th, 50th, 75th, 90th, 95th
print('-------------------------------------------------')
print('Data description of attended remote consultation in 2021/10:')
print(remote_attended_tmp[['CCG_NAME', 'Appointment_Date', 'COUNT_OF_APPOINTMENTS']]
      .describe(percentiles=[.05, .10, .25, .50, .75, .90, .95]))
print('-------------------------------------------------')
print('Minimum:')
print(remote_attended_tmp[['CCG_NAME', 'Appointment_Date', 'COUNT_OF_APPOINTMENTS']].min())
print('-------------------------------------------------')
print('Maximum:')
print(remote_attended_tmp[['CCG_NAME', 'Appointment_Date', 'COUNT_OF_APPOINTMENTS']].max())
print('-------------------------------------------------')
# Out:
# -------------------------------------------------
# Data description of attended remote consultation in 2021/10:
#        COUNT_OF_APPOINTMENTS
# count           45349.000000
# mean              198.669585
# std               564.860946
# min                 1.000000
# 5%                  1.000000
# 10%                 2.000000
# 25%                 6.000000
# 50%                34.000000
# 75%               138.000000
# 90%               460.200000
# 95%               888.000000
# max              8916.000000
# -------------------------------------------------
# Minimum:
# CCG_NAME                 NHS Barnsley CCG
# Appointment_Date                01OCT2021
# COUNT_OF_APPOINTMENTS                   1
# dtype: object
# -------------------------------------------------
# Maximum:
# CCG_NAME                 NHS Wirral CCG
# Appointment_Date              31OCT2021
# COUNT_OF_APPOINTMENTS              8916
# dtype: object
# -------------------------------------------------

# %% [markdown]
# # Month/Year: 11/2021
#
# Exclusion:
#
#             1. Home Visit & Unknown
#             2. More than 28 Days & Unknown / Data Issue

# %%
csv_name = 'CCG_CSV_Nov_21.csv'
file_path = folder_path + csv_name
dataframe = pd.read_csv(file_path)
dataframe.drop('CCG_CODE', axis=1, inplace=True)
dataframe.drop('CCG_ONS_CODE', axis=1, inplace=True)
dataframe.drop('STP_ONS_CODE', axis=1, inplace=True)
dataframe.drop('HCP_TYPE', axis=1, inplace=True)
dataframe.drop('REGION_ONS_CODE', axis=1, inplace=True)

# %% [markdown]
# ## Data filtering & Analysis

# %%
# dna: did not attend
# f2f: face-to-face
# remote: Video Conference/Online & Telephone

remote_attended_tmp = dataframe[(dataframe['APPT_STATUS'] == 'Attended') 
                                & (dataframe['APPT_MODE'] != 'Home Visit') 
                                & (dataframe['APPT_MODE'] != 'Face-to-Face') 
                                & (dataframe['APPT_MODE'] != 'Unknown') 
                                & (dataframe['TIME_BETWEEN_BOOK_AND_APPT'] !='More than 28 Days')
                                & (dataframe['TIME_BETWEEN_BOOK_AND_APPT'] !='Unknown / Data Issue')
                                ]

remote_dna_tmp = dataframe[(dataframe['APPT_STATUS'] == 'DNA') 
                                & (dataframe['APPT_MODE'] != 'Home Visit') 
                                & (dataframe['APPT_MODE'] != 'Face-to-Face') 
                                & (dataframe['APPT_MODE'] != 'Unknown') 
                                & (dataframe['TIME_BETWEEN_BOOK_AND_APPT'] !='More than 28 Days')
                                & (dataframe['TIME_BETWEEN_BOOK_AND_APPT'] !='Unknown / Data Issue')
                                ]['COUNT_OF_APPOINTMENTS']

f2f_attended_tmp = dataframe[(dataframe['APPT_STATUS'] == 'Attended') 
                            & (dataframe['APPT_MODE'] == 'Face-to-Face')
                            & (dataframe['TIME_BETWEEN_BOOK_AND_APPT'] !='More than 28 Days')
                            & (dataframe['TIME_BETWEEN_BOOK_AND_APPT'] !='Unknown / Data Issue')                    
                            ]['COUNT_OF_APPOINTMENTS']

f2f_dna_tmp = dataframe[(dataframe['APPT_STATUS'] == 'DNA') 
                        & (dataframe['APPT_MODE'] == 'Face-to-Face') 
                        & (dataframe['TIME_BETWEEN_BOOK_AND_APPT'] !='More than 28 Days')
                        & (dataframe['TIME_BETWEEN_BOOK_AND_APPT'] !='Unknown / Data Issue')
                        ]['COUNT_OF_APPOINTMENTS']

# drop na

remote_attended_tmp = remote_attended_tmp.dropna()
remote_dna_tmp = remote_dna_tmp.dropna()
f2f_attended_tmp = f2f_attended_tmp.dropna()
f2f_dna_tmp = f2f_attended_tmp.dropna()

#count, min, max, 5th, 10th, 25th, 50th, 75th, 90th, 95th
print('-------------------------------------------------')
print('Data description of attended remote consultation in 2021/11:')
print(remote_attended_tmp[['CCG_NAME', 'Appointment_Date', 'COUNT_OF_APPOINTMENTS']]
      .describe(percentiles=[.05, .10, .25, .50, .75, .90, .95]))
print('-------------------------------------------------')
print('Minimum:')
print(remote_attended_tmp[['CCG_NAME', 'Appointment_Date', 'COUNT_OF_APPOINTMENTS']].min())
print('-------------------------------------------------')
print('Maximum:')
print(remote_attended_tmp[['CCG_NAME', 'Appointment_Date', 'COUNT_OF_APPOINTMENTS']].max())
print('-------------------------------------------------')
# Out:
# -------------------------------------------------
# Data description of attended remote consultation in 2021/11:
#        COUNT_OF_APPOINTMENTS
# count           46618.000000
# mean              203.972092
# std               569.245837
# min                 1.000000
# 5%                  1.000000
# 10%                 2.000000
# 25%                 6.000000
# 50%                37.000000
# 75%               147.000000
# 90%               470.000000
# 95%               905.150000
# max              8878.000000
# -------------------------------------------------
# Minimum:
# CCG_NAME                 NHS Barnsley CCG
# Appointment_Date                01NOV2021
# COUNT_OF_APPOINTMENTS                   1
# dtype: object
# -------------------------------------------------
# Maximum:
# CCG_NAME                 NHS Wirral CCG
# Appointment_Date              30NOV2021
# COUNT_OF_APPOINTMENTS              8878
# dtype: object
# -------------------------------------------------

# %% [markdown]
# # Month/Year: 12/2021
#
# Exclusion:
#
#             1. Home Visit & Unknown
#             2. More than 28 Days & Unknown / Data Issue

# %%
csv_name = 'CCG_CSV_Dec_21.csv'
file_path = folder_path + csv_name
dataframe = pd.read_csv(file_path)
dataframe.drop('CCG_CODE', axis=1, inplace=True)
dataframe.drop('CCG_ONS_CODE', axis=1, inplace=True)
dataframe.drop('STP_ONS_CODE', axis=1, inplace=True)
dataframe.drop('HCP_TYPE', axis=1, inplace=True)
dataframe.drop('REGION_ONS_CODE', axis=1, inplace=True)

# %% [markdown]
# ## Data filtering & Analysis

# %%
# dna: did not attend
# f2f: face-to-face
# remote: Video Conference/Online & Telephone

remote_attended_tmp = dataframe[(dataframe['APPT_STATUS'] == 'Attended') 
                                & (dataframe['APPT_MODE'] != 'Home Visit') 
                                & (dataframe['APPT_MODE'] != 'Face-to-Face') 
                                & (dataframe['APPT_MODE'] != 'Unknown') 
                                & (dataframe['TIME_BETWEEN_BOOK_AND_APPT'] !='More than 28 Days')
                                & (dataframe['TIME_BETWEEN_BOOK_AND_APPT'] !='Unknown / Data Issue')
                                ]

remote_dna_tmp = dataframe[(dataframe['APPT_STATUS'] == 'DNA') 
                                & (dataframe['APPT_MODE'] != 'Home Visit') 
                                & (dataframe['APPT_MODE'] != 'Face-to-Face') 
                                & (dataframe['APPT_MODE'] != 'Unknown') 
                                & (dataframe['TIME_BETWEEN_BOOK_AND_APPT'] !='More than 28 Days')
                                & (dataframe['TIME_BETWEEN_BOOK_AND_APPT'] !='Unknown / Data Issue')
                                ]['COUNT_OF_APPOINTMENTS']

f2f_attended_tmp = dataframe[(dataframe['APPT_STATUS'] == 'Attended') 
                            & (dataframe['APPT_MODE'] == 'Face-to-Face')
                            & (dataframe['TIME_BETWEEN_BOOK_AND_APPT'] !='More than 28 Days')
                            & (dataframe['TIME_BETWEEN_BOOK_AND_APPT'] !='Unknown / Data Issue')                    
                            ]['COUNT_OF_APPOINTMENTS']

f2f_dna_tmp = dataframe[(dataframe['APPT_STATUS'] == 'DNA') 
                        & (dataframe['APPT_MODE'] == 'Face-to-Face') 
                        & (dataframe['TIME_BETWEEN_BOOK_AND_APPT'] !='More than 28 Days')
                        & (dataframe['TIME_BETWEEN_BOOK_AND_APPT'] !='Unknown / Data Issue')
                        ]['COUNT_OF_APPOINTMENTS']

# drop na

remote_attended_tmp = remote_attended_tmp.dropna()
remote_dna_tmp = remote_dna_tmp.dropna()
f2f_attended_tmp = f2f_attended_tmp.dropna()
f2f_dna_tmp = f2f_attended_tmp.dropna()

#count, min, max, 5th, 10th, 25th, 50th, 75th, 90th, 95th
print('-------------------------------------------------')
print('Data description of attended remote consultation in 2021/12:')
print(remote_attended_tmp[['CCG_NAME', 'Appointment_Date', 'COUNT_OF_APPOINTMENTS']]
      .describe(percentiles=[.05, .10, .25, .50, .75, .90, .95]))
print('-------------------------------------------------')
print('Minimum:')
print(remote_attended_tmp[['CCG_NAME', 'Appointment_Date', 'COUNT_OF_APPOINTMENTS']].min())
print('-------------------------------------------------')
print('Maximum:')
print(remote_attended_tmp[['CCG_NAME', 'Appointment_Date', 'COUNT_OF_APPOINTMENTS']].max())
print('-------------------------------------------------')
# Out:
# -------------------------------------------------
# Data description of attended remote consultation in 2021/12:
#        COUNT_OF_APPOINTMENTS
# count           43873.000000
# mean              188.734734
# std               549.561377
# min                 1.000000
# 5%                  1.000000
# 10%                 2.000000
# 25%                 6.000000
# 50%                34.000000
# 75%               128.000000
# 90%               416.000000
# 95%               836.000000
# max              8723.000000
# -------------------------------------------------
# Minimum:
# CCG_NAME                 NHS Barnsley CCG
# Appointment_Date                01DEC2021
# COUNT_OF_APPOINTMENTS                   1
# dtype: object
# -------------------------------------------------
# Maximum:
# CCG_NAME                 NHS Wirral CCG
# Appointment_Date              31DEC2021
# COUNT_OF_APPOINTMENTS              8723
# dtype: object
# -------------------------------------------------
